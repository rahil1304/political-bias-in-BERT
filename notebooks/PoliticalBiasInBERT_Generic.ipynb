# %%
# !pip install transformers
# !pip install datasets --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 5.3 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 44.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 61.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.24.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.6.1-py3-none-any.whl (441 kB)
#      |████████████████████████████████| 441 kB 5.3 MB/s
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 46.7 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.10.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 37.5 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.13.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Collecting dill<0.3.6
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 3.8 MB/s
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 41.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.10.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 30.3 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, dill, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
# Successfully installed datasets-2.6.1 dill-0.3.5.1 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.1.0

# %%
from transformers import TFAutoModelForMaskedLM

model_checkpoint = "distilbert-base-uncased"
model = TFAutoModelForMaskedLM.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363M [00:00<?, ?B/s]
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForMaskedLM: ['activation_13']
# - This IS expected if you are initializing TFDistilBertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertForMaskedLM were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForMaskedLM for predictions without further training.

# %%
model(model.dummy_inputs)  # Build the model
model.summary()
# Out:
# Model: "tf_distil_bert_for_masked_lm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  distilbert (TFDistilBertMai  multiple                 66362880
#  nLayer)
#
#  vocab_transform (Dense)     multiple                  590592
#
#  vocab_layer_norm (LayerNorm  multiple                 1536
#  alization)
#
#  vocab_projector (TFDistilBe  multiple                 23866170
#  rtLMHead)
#
# =================================================================
# Total params: 66,985,530
# Trainable params: 66,985,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
text = "This is a great [MASK], I prefer [MASK]."

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
import numpy as np
import tensorflow as tf

inputs = tokenizer(text, return_tensors="np")
token_logits = model(**inputs).logits
# Find the location of [MASK] and extract its logits
mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
mask_token_logits = token_logits[0, mask_token_index, :]
# Pick the [MASK] candidates with the highest logits
# We negate the array before argsort to get the largest, not the smallest, logits
top_5_tokens = np.argsort(-mask_token_logits)[:5].tolist()

for token in top_5_tokens:
    print(f">>> {text.replace(tokenizer.mask_token, tokenizer.decode([token]))}")
# Out:
# >>> This is a great idea, I prefer idea.
# >>> This is a great deal, I prefer deal.
# >>> This is a great adventure, I prefer adventure.
# >>> This is a great job, I prefer job.
# >>> This is a great opportunity, I prefer opportunity.

# %%
# LOAD DATASET
# import pandas as pd
# df = pd.read_parquet('all_2020_US_Election_News.parquet', engine='pyarrow')

# %%
# MOUNT DRIVE
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
# %cd /content/drive/My Drive/Independent Study/
df = pd.read_parquet('all_2020_US_Election_News.parquet', engine='pyarrow')

# LOADING DATASET IN HUGGING FACE FORM
# from datasets import load_dataset
# df = load_dataset("parquet", data_files={'all_2020_US_Election_News.parquet'})
# Out:
# /content/drive/My Drive/Independent Study

# %%
# Saving the base model
model.save_weights('./checkpoints/my_base_BERT_model')

# %%
df.iloc[3]['text']
# Out:
# 'Senate showdown over pandemic relief stalls as Pelosi preps Democratic bill The Senate\'s efforts to advance a bipartisan proposal have stalled.\n\nThe Senate\'s second attempt to advance a massive $2 trillion bill to provide economic relief amid the COVID-19 pandemic failed Monday afternoon, demonstrating an inability to strike a bipartisan agreement on the Coronavirus Aid, Relief, and Economic Security Act.\n\nThe vote failed 49-46, falling well short of the 60 votes needed to advance to debate on the bill, which represents the third phase of congressional aid to respond to the crisis.\n\nAfter the vote, Senate Majority Mitch McConnell warned that the Senate might not be able to pass a bill until Friday or Saturday, blasting Democrats for "mindless obstruction."\n\n"While the public is waiting for us to act, while people losing their jobs, losing their income and shutting down the economy which we\'ve had to do to deal with this public health crisis, they\'re fiddling around with Senate procedure that could, if one senator objected, take us all the way to the end of the week to solve this problem," McConnell fumed. "The American people have had just enough of this nonsense. They wonder where we are. They\'re looking to us to solve this problem!"\n\nPrior to the vote, Republicans complained Democrats have turned negotiations into a leftwing episode of Supermarket Sweep.\n\nMcConnell called the GOP proposal a compromise package that would provide tens of billions of dollars to hospitals, provide checks to millions of families, prevent layoffs and provide historic relief to small businesses.\n\nWhy are Democrats filibustering the bipartisan bill they helped write? McConnell wondered, ticking through a Democratic wish list that he said was preventing an agreement, including tax credits for solar energy and wind energy provisions to force employers to give special new treatment for big labor, and new emissions standards for airlines.\n\nAre you kidding me? This is the moment to debate new regulations that have nothing whatsoever to do whatsoever with this crisis? Thats what theyre up to over there. The American people need to know it, McConnell, R-Ky., said. Democrats wont let us fund hospitals or save small businesses unless they get to dust off the Green New Deal.\n\nThey ought to be embarrassed, he said. This is not a juicy political opportunity, this is a national emergency.\n\nSenate Majority Leader Mitch McConnell speaks on the Senate floor at the Capitol, in Washington, Saturday, March 21, 2020. AP\n\nSenate Minority Leader Chuck Schumer continued to meet with Treasury Secretary Steven Mnuchin Monday morning, responding to McConnell on the Senate floor while stressing negotiations are ongoing.\n\nSecretary of the Treasury Steven Mnuchin walks to the meeting with Senate Minority Leader Chuck Schumer during negotiations on a coronavirus disease (COVID-19) relief package on Capitol in Washington, March 23, 2020. Joshua Roberts/Reuters\n\nThese are trying times for all of us, but the scourge of this disease will pass. The American people, as always, will prevail, Schumer, D-N.Y., said. The Senate continues to negotiate what will likely be the largest emergency funding bill in history.\n\nWere very close to reaching a deal, very close, and our goal is to reach a deal today, and were hopeful  even confident, that we will meet that goal, Schumer said.\n\nSenate Minority Leader Chuck Schumer speaks on the Senate floor at the Capitol, in Washington, March 21, 2020. Senate Television via AP\n\nSchumer acknowledged that the bill has moved in the Democratic direction in regard to unemployment insurance, but protested that it still includes something most Americans dont want to see: large corporate bailouts with almost no strings attached.\n\nMaybe the majority leader thinks its unfair to ask protections for workers and labor to companies that are getting hundreds of billions of dollars, Schumer said. We think its very fair to ask for ...

# %%
def label_leaning(row):
  if row['publication'] == 'ABC News' or row['publication'] == 'CBS News' or row['publication'] == 'CNN' or row['publication'] == 'MSNBC' or row['publication'] == 'The Washington Post' or row['publication'] == 'Al Jazeera English' or row['publication'] == 'Google News' or row['publication'] == 'Buzzfeed':
    return 'L'
  elif row['publication'] in ['Fox News', 'Breitbart News', 'The Washington Times']:
    return 'R'
  return 'C'

df['leaning'] = df.apply (lambda row: label_leaning(row), axis=1)

# %%
df2 = pd.DataFrame().assign(text=df['text'], leaning=df['leaning'])
df2 = df2.dropna()

df2.size
# Out:
# 277754

# %%
dataset = df2

# %%
dataset.to_csv (r'export_dataframe.csv', index = False, header=True)

# %%
# LOADING L DATASET IN HUGGING FACE FORM
from datasets import load_dataset
# %cd /content/drive/My Drive/Independent Study/

# dataset = load_dataset("csv", data_files={'export_L_dataframe.csv'})
dataset = load_dataset("csv", data_files={'export_dataframe.csv'})
# Out:
# /content/drive/My Drive/Independent Study
# WARNING:datasets.builder:Using custom data configuration default-8f4aade152310acc
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-8f4aade152310acc/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-8f4aade152310acc/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset = dataset['train']

# %%
# Range for export_L_dataframe 
# train = dataset.shuffle(seed=42).select(range(25000))
# test = dataset.shuffle(seed=42).select(range(25000, 50000))
# unsupervised = dataset.shuffle(seed=42).select(range(50000, len(dataset)))

# Range for export_R_dataframe 
train = dataset.shuffle(seed=42).select(range(20000))
test = dataset.shuffle(seed=42).select(range(20000, 40000))
unsupervised = dataset.shuffle(seed=42).select(range(40000, len(dataset)))
# Out:
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/csv/default-8f4aade152310acc/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-116151c801ade3f3.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/csv/default-8f4aade152310acc/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-116151c801ade3f3.arrow

# %%
# pip install datasets
my_dataset_dict = {
    "train": train,
    "test": test,
    "unsupervised": unsupervised
    }

# %%
len(my_dataset_dict['unsupervised'])
# Out:
# 98877

# %%
my_dataset_dict['train'][1]
# Out:
# {'text': 'John Heilemann joins Lawrence ODonnell to discuss why President Trump is shutting down the coronavirus task force and the goal post shifting of the administrations coronavirus death projections.',
#  'leaning': 'L'}

# %%
def tokenize_function(examples):
    result = tokenizer(examples["text"])
    if tokenizer.is_fast:
        result["word_ids"] = [result.word_ids(i) for i in range(len(result["input_ids"]))]
    return result

# my_dataset_dict = my_dataset_dict.dropna()
# my_dataset_dict = my_dataset_dict['train']['tr'].tolist()
# texts_encodings = tokenizer(texts, truncation=True, padding=True)

# Use batched=True to activate fast multithreading!
train_tokenized_datasets = my_dataset_dict['train'].map(
    tokenize_function, batched=True, remove_columns=["text", "leaning"]
)
test_tokenized_datasets = my_dataset_dict['test'].map(
    tokenize_function, batched=True, remove_columns=["text", "leaning"]
)
unsupervised_tokenized_datasets = my_dataset_dict['unsupervised'].map(
    tokenize_function, batched=True, remove_columns=["text", "leaning"]
)
# Out:
#   0%|          | 0/20 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (542 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/20 [00:00<?, ?ba/s]
#   0%|          | 0/99 [00:00<?, ?ba/s]

# %%
print(len(train_tokenized_datasets), len(test_tokenized_datasets), len(unsupervised_tokenized_datasets))
# Out:
# 20000 20000 98877

# %%
tokenized_dataset = {
    "train": train_tokenized_datasets,
    "test": test_tokenized_datasets,
    "unsupervised": unsupervised_tokenized_datasets
}

# %%
tokenized_dataset
# Out:
# {'train': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 20000
#  }), 'test': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 20000
#  }), 'unsupervised': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 98877
#  })}

# %%
print(tokenizer.model_max_length)
chunk_size = 128
# Out:
# 512

# %%
# Slicing produces a list of lists for each feature
tokenized_samples = tokenized_dataset["train"][:3]

for idx, sample in enumerate(tokenized_samples["input_ids"]):
    print(f"'>>> Review {idx} length: {len(sample)}'")
# Out:
# '>>> Review 0 length: 66'
# '>>> Review 1 length: 37'
# '>>> Review 2 length: 542'

# %%
concatenated_examples = {
    k: sum(tokenized_samples[k], []) for k in tokenized_samples.keys()
}
total_length = len(concatenated_examples["input_ids"])
print(f"'>>> Concatenated reviews length: {total_length}'")
# Out:
# '>>> Concatenated reviews length: 645'

# %%
chunks = {
    k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
    for k, t in concatenated_examples.items()
}

for chunk in chunks["input_ids"]:
    print(f"'>>> Chunk length: {len(chunk)}'")
# Out:
# '>>> Chunk length: 128'
# '>>> Chunk length: 128'
# '>>> Chunk length: 128'
# '>>> Chunk length: 128'
# '>>> Chunk length: 128'
# '>>> Chunk length: 5'

# %%
def group_texts(examples):
    # Concatenate all texts
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    # Compute length of concatenated texts
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the last chunk if it's smaller than chunk_size
    total_length = (total_length // chunk_size) * chunk_size
    # Split by chunks of max_len
    result = {
        k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
        for k, t in concatenated_examples.items()
    }
    # Create a new labels column
    result["labels"] = result["input_ids"].copy()
    return result

# %%
tokenized_dataset
# Out:
# {'train': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 20000
#  }), 'test': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 20000
#  }), 'unsupervised': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids'],
#      num_rows: 98877
#  })}

# %%
train_datasets = tokenized_dataset['train'].map(group_texts, batched=True)
test_datasets = tokenized_dataset['test'].map(group_texts, batched=True)
unsupervised_datasets = tokenized_dataset['unsupervised'].map(group_texts, batched=True)

datasets = {
     "train": train_datasets,
    "test": test_datasets,
    "unsupervised": unsupervised_datasets
}
# Out:
#   0%|          | 0/20 [00:00<?, ?ba/s]
#   0%|          | 0/20 [00:00<?, ?ba/s]
#   0%|          | 0/99 [00:00<?, ?ba/s]

# %%
datasets
# Out:
# {'train': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids', 'labels'],
#      num_rows: 134166
#  }), 'test': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids', 'labels'],
#      num_rows: 131458
#  }), 'unsupervised': Dataset({
#      features: ['input_ids', 'attention_mask', 'word_ids', 'labels'],
#      num_rows: 653004
#  })}

# %%
tokenizer.decode(datasets["train"][1]["input_ids"])
# Out:
# "raised record sums of money in his failed bid to unseat gop senator lindsey graham, to lead the democratic national committee, the transition team announced thursday. harrison was one of a number of dnc officers announced by the transition team on thursday, including three women who were considered on mr. biden's shortlist for vice president. atlanta mayor keisha lance bottoms has been selected for vice chair of civic engagement and voter protection, michigan governor gretchen whitmer for vice chair and senator tammy duckworth for vice chair. the other selections were representative filemon vela jr. for vice chair, jason rae for secretary, virginia mcgregor"

# %%
tokenizer.decode(datasets["train"][1]["labels"])
# Out:
# "raised record sums of money in his failed bid to unseat gop senator lindsey graham, to lead the democratic national committee, the transition team announced thursday. harrison was one of a number of dnc officers announced by the transition team on thursday, including three women who were considered on mr. biden's shortlist for vice president. atlanta mayor keisha lance bottoms has been selected for vice chair of civic engagement and voter protection, michigan governor gretchen whitmer for vice chair and senator tammy duckworth for vice chair. the other selections were representative filemon vela jr. for vice chair, jason rae for secretary, virginia mcgregor"

# %% [markdown]
# ## **Fine-tuning DistilBERT with the Trainer API**

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %%
samples = [datasets["train"][i] for i in range(2)]
for sample in samples:
    _ = sample.pop("word_ids")

for chunk in data_collator(samples)["input_ids"]:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# '>>> [CLS] at dnc, cuomo calls covid - 19'man - made [MASK]'new york [MASK]. andrew [MASK]omo says the [MASK] of covid wrath 19 [MASK] the us is a " man - made threat bytro own negligence, " and blamed the trump administration [MASK] its [MASK] response. ( aug. 17 ) ap [SEP] [CLS] john heilemann [MASK] [MASK] odonnell to discuss why president [MASK] is shutting down the coronavirus [MASK] force and the goal post shifting of [MASK] administrations coronavirus [MASK] projections. [SEP] [CLS] president - [MASK] joe biden has chosen jaime harrison [MASK] the former democratic u. s. senate candidate from [MASK] [MASK] who'
#
# '>>> raised record sums [MASK] money in his failed researcher [MASK] unseat gop senator lindsey graham, to lead the democratic national committee, the transition team announced thursday. harrison was one of a [MASK] of dnc officers announced by the transition [MASK] on thursday, including three women who [MASK] considered on [MASK]. [MASK]en'[MASK] shortlist for [MASK] president. schemes mayor keisha lance bottoms has been selected for vice chair of [MASK] [MASK] and voter protection, michigan [MASK] gretchen [MASK]hitmer for vice [MASK] and senator [MASK] duckworth for vice chair. [MASK] other women [MASK] representative file mets vela jr. for vice [MASK], jason rae for secretary, virginia mcgregor'

# %%
import collections
import numpy as np

from transformers.data.data_collator import tf_default_data_collator

wwm_probability = 0.2

def whole_word_masking_data_collator(features):
    for feature in features:
        word_ids = feature.pop("word_ids")

        # Create a map between words and corresponding token indices
        mapping = collections.defaultdict(list)
        current_word_index = -1
        current_word = None
        for idx, word_id in enumerate(word_ids):
            if word_id is not None:
                if word_id != current_word:
                    current_word = word_id
                    current_word_index += 1
                mapping[current_word_index].append(idx)

        # Randomly mask words
        mask = np.random.binomial(1, wwm_probability, (len(mapping),))
        input_ids = feature["input_ids"]
        labels = feature["labels"]
        new_labels = [-100] * len(labels)
        for word_id in np.where(mask)[0]:
            word_id = word_id.item()
            for idx in mapping[word_id]:
                new_labels[idx] = labels[idx]
                input_ids[idx] = tokenizer.mask_token_id

    return tf_default_data_collator(features)

# %%
samples = [datasets["train"][i] for i in range(2)]
batch = whole_word_masking_data_collator(samples)

for chunk in batch["input_ids"]:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# '>>> [CLS] at dnc, cuomo [MASK] covid - 19'man - made threat'new york gov. [MASK] cuomo says the persistence of covid - 19 in the us is a " man - made threat [MASK] our own negligence, " [MASK] blamed [MASK] trump administration for its weak [MASK]. ( aug [MASK] 17 ) [MASK] [SEP] [CLS] john heilemann joins lawrence odonnell to discuss why president trump is shutting [MASK] the coronavirus task [MASK] [MASK] the [MASK] [MASK] shifting of the [MASK] coronavirus death [MASK]. [SEP] [CLS] president - elect joe biden has chosen jaime harrison, the former democratic u [MASK] s [MASK] senate candidate [MASK] south carolina who'
#
# '>>> raised record sums of money in his failed [MASK] to [MASK] [MASK] [MASK] gop [MASK] lindsey [MASK], to lead the democratic [MASK] committee, the transition team announced thursday. harrison was one of a number of dnc officers announced by the transition team on thursday, including [MASK] [MASK] who were considered on mr. biden'[MASK] [MASK] [MASK] for vice president. atlanta mayor keisha lance bottoms has been selected [MASK] [MASK] chair of civic engagement and voter [MASK], michigan [MASK] gretchen whitmer for [MASK] chair and senator tammy duckworth for vice chair. the [MASK] selections were representative [MASK] [MASK] vela jr. [MASK] vice chair, jason rae [MASK] secretary, virginia mcgregor'

# %%
train_size = 10_000
test_size = int(0.2 * train_size)

downsampled_dataset = datasets["train"].train_test_split(
    train_size=train_size, test_size=test_size, seed=42
)
downsampled_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 10000
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 2000
#     })
# })

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %%
tf_train_dataset = downsampled_dataset["train"].to_tf_dataset(
    columns=["input_ids", "attention_mask", "labels"],
    collate_fn=data_collator,
    shuffle=True,
    batch_size=32,
)

tf_eval_dataset = downsampled_dataset["test"].to_tf_dataset(
    columns=["input_ids", "attention_mask", "labels"],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=32,
)

# %%
from transformers import create_optimizer
# from transformers.keras_callbacks import PushToHubCallback
import tensorflow as tf

num_train_steps = len(tf_train_dataset)
optimizer, schedule = create_optimizer(
    init_lr=2e-5,
    num_warmup_steps=1_000,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.01,
)
model.compile(optimizer=optimizer)

# Train in mixed-precision float16
tf.keras.mixed_precision.set_global_policy("mixed_float16")

# callback = PushToHubCallback(
#     output_dir=f"L-Leaning-finetuned-BERT", tokenizer=tokenizer
# )
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# The dtype policy mixed_float16 may run slowly because this machine does not have a GPU. Only Nvidia GPUs with compute capability of at least 7.0 run quickly with mixed_float16.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %%
import math

eval_loss = model.evaluate(tf_eval_dataset)
print(f"Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 63/63 [==============================] - 809s 13s/step - loss: 3.1710
# Perplexity: 23.83

# %%
# model.fit(tf_train_dataset, validation_data=tf_eval_dataset, callbacks=[callback])
model.fit(tf_train_dataset, validation_data=tf_eval_dataset, epochs = 1)
# Out:
# 313/313 [==============================] - 12029s 38s/step - loss: 2.9300 - val_loss: 2.5905

# %%
model.summary()
# Out:
# Model: "tf_distil_bert_for_masked_lm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  distilbert (TFDistilBertMai  multiple                 66362880
#  nLayer)
#
#  vocab_transform (Dense)     multiple                  590592
#
#  vocab_layer_norm (LayerNorm  multiple                 1536
#  alization)
#
#  vocab_projector (TFDistilBe  multiple                 23866170
#  rtLMHead)
#
# =================================================================
# Total params: 66,985,530
# Trainable params: 66,985,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
eval_loss = model.evaluate(tf_eval_dataset)
print(f"Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 63/63 [==============================] - 803s 13s/step - loss: 2.6478
# Perplexity: 14.12

# %%
# Saving the model
model.save_weights('./checkpoints/complete_BERT_target')
# model.save_weights('./checkpoints/my_r_leaning_BERT_new')

# %% [markdown]
# ## Using the Fine-tuned model

# %% [markdown]
# ### Loading Pre-trained models and mounting drive

# %%
# !pip install transformers

# Create a new model instance
from transformers import TFAutoModelForMaskedLM

model_checkpoint = "distilbert-base-uncased"
model = TFAutoModelForMaskedLM.from_pretrained(model_checkpoint)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForMaskedLM: ['activation_13']
# - This IS expected if you are initializing TFDistilBertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertForMaskedLM were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForMaskedLM for predictions without further training.

# %%
# MOUNT DRIVE
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Independent Study/

# Restore the weights
# model.load_weights('./checkpoints/complete_BERT_target')
# model.load_weights('./checkpoints/my_l_leaning_BERT')

# Loading R leaning model
# right_leaning_model.load_weights('./checkpoints/my_r_leaning_BERT')

# Loading the base model
# base_model.load_weights('./checkpoints/my_base_BERT_model')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Independent Study
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-16-f6db6fa9694e> in <module>
#       6 # Restore the weights
#       7 # model.load_weights('./checkpoints/complete_BERT_target')
# ----> 8 model.load_weights('./checkpoints/my_l_leaning_BERT')
#       9
#      10 # Loading R leaning model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      29       'Failed to find any '
#      30       'matching files for') in error_message:
# ---> 31     raise errors_impl.NotFoundError(None, None, error_message)
#      32   elif 'Sliced checkpoints are not supported' in error_message or (
#      33       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./checkpoints/my_l_leaning_BERT

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
## Testing
import numpy as np
text = "Trump [MASK] the mask mandate after reducing coronavirus cases."

inputs = tokenizer(text, return_tensors="np")
token_logits = model(**inputs).logits
# Find the location of [MASK] and extract its logits
mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
mask_token_logits = token_logits[0, mask_token_index, :]
# Pick the [MASK] candidates with the highest logits
# We negate the array before argsort to get the largest, not the smallest, logits
top_5_tokens = np.argsort(-mask_token_logits)[:5].tolist()

for token in top_5_tokens:
    print(f">>> {text.replace(tokenizer.mask_token, tokenizer.decode([token]))}")
# Out:
# >>> Trump renewed the mask mandate after reducing coronavirus cases.
# >>> Trump extended the mask mandate after reducing coronavirus cases.
# >>> Trump expanded the mask mandate after reducing coronavirus cases.
# >>> Trump dropped the mask mandate after reducing coronavirus cases.
# >>> Trump withdrew the mask mandate after reducing coronavirus cases.

# %%
## TESTING
text1 = "[MASK] celebrated the victory of Obama in 2012."
text2 = "[MASK] decided to remove their mask during the press conference."

inputs = tokenizer(text1, return_tensors="np")
token_logits = left_leaning_model(**inputs).logits
# Find the location of [MASK] and extract its logits
mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
mask_token_logits = token_logits[0, mask_token_index, :]
# Pick the [MASK] candidates with the highest logits
# We negate the array before argsort to get the largest, not the smallest, logits
all_tokens = np.argsort(-mask_token_logits).tolist()

word_probability_dict = {}
for index, val in enumerate(mask_token_logits):
  word = tokenizer.decode([index])
  word_probability_dict[word] = val.numpy()

word_list = []
print("Democrats prob. score:", word_probability_dict['democrats'])
print("Republicans prob. score:", word_probability_dict['republicans'])
print("Trump prob. score:", word_probability_dict['trump'])
# Out:
# Democrats prob. score: 3.035
# Republicans prob. score: 2.74
# Trump prob. score: 5.066

# %%
# LEFT LEANING TARGET
# Sentence 1 = "[MASK] celebrated the victory of Obama in 2012."
# Democrats prob. score: 3.035
# Republicans prob. score: 2.74
# Trump prob. score: 5.066
# Sentence 2 = "[MASK] decided to remove their mask during the press conference."
# Democrats prob. score: 3.371
# Republicans prob. score: 3.607
# Trump prob. score: 5.73



# RIGHT SCORE NEW
# Democrats prob. score: 3.9590755
# Republicans prob. score: 3.3995123
# Trump prob. score: 5.840903

# LEFT SCORE NEW
# Democrats prob. score: 3.3224194
# Republicans prob. score: 2.8286982
# Trump prob. score: 5.4028077

# LEFT SCORE
# Democrats prob. score: 4.29
# Republicans prob. score: 4.117
# Trump prob. score: 1.664

# %%
from transformers import pipeline

L_mask_filler = pipeline(
    "fill-mask", model="L-Leaning-finetuned-BERT"
)

# L_mask_filler = pipeline(
#     "fill-mask", left_leaning_model
# )

R_mask_filler = pipeline(
    "fill-mask", model="R-Leaning-finetuned-BERT"
)

base_mask_filler = pipeline(
     "fill-mask", model="R-Leaning-finetuned-BERT"
)
# Out:
# All model checkpoint layers were used when initializing TFDistilBertForMaskedLM.
#
# All the layers of TFDistilBertForMaskedLM were initialized from the model checkpoint at L-Leaning-finetuned-BERT.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForMaskedLM for predictions without further training.
# All model checkpoint layers were used when initializing TFDistilBertForMaskedLM.
#
# All the layers of TFDistilBertForMaskedLM were initialized from the model checkpoint at R-Leaning-finetuned-BERT.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForMaskedLM for predictions without further training.
# All model checkpoint layers were used when initializing TFDistilBertForMaskedLM.
#
# All the layers of TFDistilBertForMaskedLM were initialized from the model checkpoint at R-Leaning-finetuned-BERT.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForMaskedLM for predictions without further training.

# %% [markdown]
# ### Prediction sentences testing (Examples)

# %%
prediction_sentence = 'Trump considering [MASK] coronavirus guidelines amid growing economic fallout'
preds = L_mask_filler(prediction_sentence)
# preds = left_leaning_model(prediction_sentence)
for pred in preds:
    print(f">>> {pred['sequence']}")
# Out:
# >>> trump considering the coronavirus guidelines amid growing economic fallout
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout
# >>> trump considering changing coronavirus guidelines amid growing economic fallout
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout
# >>> trump considering new coronavirus guidelines amid growing economic fallout

# %%
prediction_sentence = 'Biden considering [MASK] coronavirus guidelines amid growing economic fallout'
preds = mask_filler(prediction_sentence)

for pred in preds:
    print(f">>> {pred['sequence']}")
# Out:
# >>> biden considering the coronavirus guidelines amid growing economic fallout
# >>> biden considering new coronavirus guidelines amid growing economic fallout
# >>> biden considering changing coronavirus guidelines amid growing economic fallout
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout
# >>> biden considering issuing coronavirus guidelines amid growing economic fallout

# %%
prediction_sentence = 'California [MASK] Trump irrespective of election outcome.'
preds = mask_filler(prediction_sentence)

for pred in preds:
    print(f">>> {pred['sequence']}")
# Out:
# >>> california endorsed trump irrespective of election outcome.
# >>> california chooses trump irrespective of election outcome.
# >>> california chose trump irrespective of election outcome.
# >>> california supports trump irrespective of election outcome.
# >>> california nominated trump irrespective of election outcome.

# %%
prediction_sentence = 'Florida [MASK] Biden irrespective of election outcome.'
preds = mask_filler(prediction_sentence)

for pred in preds:
    print(f">>> {pred['sequence']}")
# Out:
# >>> florida endorsed biden irrespective of election outcome.
# >>> florida chose biden irrespective of election outcome.
# >>> florida defeated biden irrespective of election outcome.
# >>> florida nominated biden irrespective of election outcome.
# >>> florida represents biden irrespective of election outcome.

# %% [markdown]
# ### **Scoring Validation (Creating lexicon dictionary)**

# %%
import pandas as pd
lexicons = pd.read_csv('NRC-VAD-Lexicon.csv')
lexicons = lexicons[lexicons['English Word'].notnull()]
print(lexicons)
# Out:
#       English Word  Valence  Arousal  Dominance
# 0         aaaaaaah    0.479    0.606      0.291
# 1            aaaah    0.520    0.636      0.282
# 2         aardvark    0.427    0.490      0.437
# 3            aback    0.385    0.407      0.288
# 4           abacus    0.510    0.276      0.485
# ...            ...      ...      ...        ...
# 19967          zoo    0.760    0.520      0.580
# 19968   zoological    0.667    0.458      0.492
# 19969      zoology    0.568    0.347      0.509
# 19970         zoom    0.490    0.520      0.462
# 19971     zucchini    0.510    0.321      0.250
#
# [19971 rows x 4 columns]

# %%
# Lemmatizing word before it's put in the dictionary
import nltk
nltk.download('all')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
lemmatizer = WordNetLemmatizer()
  
print("predicted :", lemmatizer.lemmatize("biggest"))
print("delivered :", lemmatizer.lemmatize("big"))
print("corpora :", lemmatizer.lemmatize("corpora"))
# Out:
# predicted : biggest
# delivered : big
# corpora : corpus

# %%
# Trying stemming

# import these modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()
  
# choose some words to be stemmed
print(ps.stem('biggest'))
print(ps.stem('big'))
# Out:
# biggest
# big

# %%
lexicon_dictionary = {}
for index, val in lexicons.iterrows():
  word = val['English Word']
  if word:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lexicon_dictionary[stemmed_word] = val['Valence']

# %%
lexicon_dictionary
# Out:
# {'aaaaaaah': 0.479,
#  'aaaah': 0.52,
#  'aardvark': 0.427,
#  'aback': 0.385,
#  'abacu': 0.51,
#  'abalon': 0.5,
#  'abandon': 0.128,
#  'abash': 0.177,
#  'abat': 0.388,
#  'abba': 0.562,
#  'abbey': 0.58,
#  'abbot': 0.427,
#  'abbrevi': 0.469,
#  'abdomen': 0.469,
#  'abdomin': 0.49,
#  'abduct': 0.062,
#  'aberr': 0.125,
#  'abey': 0.33,
#  'abhor': 0.125,
#  'abhorr': 0.229,
#  'abid': 0.796,
#  'abil': 0.875,
#  'abject': 0.354,
#  'ablat': 0.418,
#  'ablaz': 0.24,
#  'abl': 0.786,
#  'abnorm': 0.092,
#  'aboard': 0.698,
#  'abod': 0.62,
#  'abolish': 0.448,
#  'abolit': 0.323,
#  'abomin': 0.078,
#  'aborigin': 0.448,
#  'abort': 0.09,
#  'abound': 0.704,
#  'abovement': 0.541,
#  'abracadabra': 0.673,
#  'abras': 0.392,
#  'abreast': 0.635,
#  'abroad': 0.677,
#  'abrog': 0.327,
#  'abrupt': 0.271,
#  'abruptli': 0.25,
#  'abscess': 0.154,
#  'absenc': 0.153,
#  'absent': 0.177,
#  'absente': 0.404,
#  'absinth': 0.481,
#  'absolut': 0.715,
#  'absolv': 0.684,
#  'absorb': 0.49,
#  'absorpt': 0.609,
#  'abstain': 0.385,
#  'abstent': 0.271,
#  'abstin': 0.26,
#  'abstract': 0.469,
#  'absurd': 0.115,
#  'abund': 0.958,
#  'abus': 0.125,
#  'abut': 0.5,
#  'abi': 0.385,
#  'abysm': 0.25,
#  'abyss': 0.353,
#  'academ': 0.781,
#  'academi': 0.704,
#  'acced': 0.698,
#  'acceler': 0.593,
#  'accent': 0.598,
#  'accentu': 0.673,
#  'accept': 0.847,
#  'access': 0.612,
#  'accessori': 0.562,
#  'accid': 0.125,
#  'accident': 0.333,
#  'acclaim': 0.562,
#  'accolad': 0.688,
#  'accommod': 0.817,
#  'accompani': 0.787,
#  'accomplic': 0.408,
#  'accomplish': 0.917,
#  'accord': 0.659,
#  'accordion': 0.604,
#  'account': 0.592,
#  'accredit': 0.669,
#  'accret': 0.448,
#  'accru': 0.52,
#  'accueil': 0.45,
#  'accumul': 0.479,
#  'accuraci': 0.604,
#  'accur': 0.743,
#  'accurs': 0.135,
#  'accus': 0.156,
#  'accustom': 0.542,
#  'ace': 0.643,
#  'acet': 0.333,
#  'acetylen': 0.306,
#  'ach': 0.053,
#  'achiev': 0.896,
#  'achi': 0.167,
#  'acid': 0.156,
#  'acknowledg': 0.796,
#  'acm': 0.408,
#  'acn': 0.167,
#  'acorn': 0.448,
#  'acoust': 0.611,
#  'acquaint': 0.906,
#  'acquiesc': 0.542,
#  'acquir': 0.735,
#  'acquisit': 0.773,
#  'acquit': 0.583,
#  'acquitt': 0.76,
#  'acr': 0.51,
#  'acreag': 0.741,
#  'acrobat': 0.708,
#  'acryl': 0.582,
#  'act': 0.698,
#  'action': 0.673,
#  'action figur': 0.615,
#  'activ': 0.701,
#  'activist': 0.531,
#  'actor': 0.653,
#  'actress': 0.633,
#  'actual': 0.75,
#  'actuari': 0.51,
#  'acuiti': 0.469,
#  'acumen': 0.564,
#  'acupunctur': 0.531,
#  'acut': 0.417,
#  'ad': 0.562,
#  'adag': 0.517,
#  'adam': 0.344,
#  'adapt': 0.663,
#  'add': 0.728,
#  'addendum': 0.392,
#  'adder': 0.388,
#  'addict': 0.302,
#  'addit': 0.561,
#  'address': 0.51,
#  'addresse': 0.622,
#  'adept': 0.594,
#  'adequaci': 0.615,
#  'adequ': 0.854,
#  'adher': 0.612,
#  'adhes': 0.604,
#  'adieu': 0.25,
#  'adipos': 0.333,
#  'adjac': 0.645,
#  'adject': 0.57,
#  'adjoin': 0.52,
#  'adjourn': 0.438,
#  'adjud': 0.551,
#  'adjunct': 0.459,
#  'adjust': 0.59,
#  'adjuv': 0.51,
#  'admin': 0.688,
#  'administ': 0.635,
#  'administr': 0.538,
#  'admir': 0.867,
#  'admiralti': 0.594,
#  'admiss': 0.802,
#  'admit': 0.62,
#  'admitt': 0.69,
#  'admixtur': 0.45,
#  'admonit': 0.357,
#  'ado': 0.52,
#  'adob': 0.5,
#  'adolesc': 0.781,
#  'adopt': 0.531,
#  'ador': 0.885,
#  'adorn': 0.918,
#  'adrenalin': 0.765,
#  'adrift': 0.398,
#  'adult': 0.815,
#  'adulter': 0.229,
#  'adulteri': 0.12,
#  'adulthood': 0.541,
#  'advanc': 0.929,
#  'advantag': 0.837,
#  'advent': 0.665,
#  'adventur': 0.969,
#  'adversari': 0.349,
#  'advers': 0.276,
#  'advertis': 0.622,
#  'advert': 0.551,
#  'advic': 0.698,
#  'advis': 0.745,
#  'advisor': 0.646,
#  'advisori': 0.656,
#  'advocaci': 0.5,
#  'advoc': 0.551,
#  'aegi': 0.49,
#  'aerat': 0.55,
#  'aerial': 0.615,
#  'aerob': 0.708,
#  'aerodrom': 0.541,
#  'aerodynam': 0.59,
#  'aeronaut': 0.551,
#  'aeroplan': 0.714,
#  'aerospac': 0.643,
#  'aesthet': 0.847,
#  'aetiolog': 0.48,
#  'afar': 0.396,
#  'affabl': 0.704,
#  'affair': 0.52,
#  'affect': 0.76,
#  'affection': 0.949,
#  'affich': 0.479,
#  'affidavit': 0.469,
#  'affili': 0.615,
#  'affin': 0.8,
#  'affirm': 0.908,
#  'affix': 0.438,
#  'afflict': 0.294,
#  'affluenc': 0.663,
#  'affluent': 0.756,
#  'afford': 0.84,
#  'affront': 0.385,
#  'afield': 0.594,
#  'afir': 0.367,
#  'afloat': 0.602,
#  'afor': 0.5,
#  'aforement': 0.49,
#  'aforesaid': 0.531,
#  'afraid': 0.01,
#  'afresh': 0.643,
#  'aft': 0.48,
#  'afterlif': 0.571,
#  'aftermath': 0.312,
#  'afternoon': 0.533,
#  'aftershav': 0.406,
#  'aftertast': 0.354,
#  'afterthought': 0.396,
#  'aga': 0.542,
#  'agap': 0.612,
#  'agat': 0.54,
#  'age': 0.214,
#  'agenc': 0.46,
#  'agenda': 0.531,
#  'agent': 0.48,
#  'agglomer': 0.45,
#  'aggrav': 0.071,
#  'aggreg': 0.583,
#  'aggres': 0.059,
#  'aggress': 0.077,
#  'aggressor': 0.146,
#  'agh': 0.26,
#  'aghast': 0.133,
#  'aghhh': 0.281,
#  'agil': 0.72,
#  'agit': 0.24,
#  'aglow': 0.78,
#  'agnost': 0.306,
#  'ago': 0.317,
#  'agon': 0.083,
#  'agoni': 0.083,
#  'agoraphobia': 0.127,
#  'agre': 0.854,
#  'agreeabl': 0.906,
#  'agreement': 0.76,
#  'agress': 0.083,
#  'agricultur': 0.64,
#  'aground': 0.333,
#  'agua': 0.598,
#  'ahead': 0.708,
#  'ahhh': 0.562,
#  'ahhhhhhhh': 0.552,
#  'ahoy': 0.5,
#  'aid': 0.561,
#  'ail': 0.094,
#  'ailment': 0.146,
#  'aim': 0.481,
#  'aimless': 0.15,
#  'air': 0.583,
#  'airbag': 0.51,
#  'airborn': 0.542,
#  'aircraft': 0.646,
#  'aircraft carri': 0.49,
#  'airfield': 0.601,
#  'airhead': 0.271,
#  'airlift': 0.573,
#  'airlin': 0.667,
#  'airlock': 0.398,
#  'airman': 0.587,
#  'airplan': 0.719,
#  'airport': 0.729,
#  'airship': 0.542,
#  'airspac': 0.562,
#  'airspe': 0.583,
#  'airstrip': 0.55,
#  'airtight': 0.479,
#  'airway': 0.638,
#  'aisl': 0.438,
#  'ait': 0.385,
#  'ajar': 0.46,
#  'aka': 0.459,
#  'akin': 0.639,
#  'alabast': 0.542,
#  'alarm': 0.204,
#  'alarm clock': 0.542,
#  'ala': 0.571,
#  'alb': 0.521,
#  'albatross': 0.5,
#  'albino': 0.5,
#  'album': 0.635,
#  'alchemi': 0.541,
#  'alcohol': 0.061,
#  'alcov': 0.49,
#  'alderman': 0.55,
#  'ale': 0.53,
#  'alert': 0.337,
#  'alfalfa': 0.546,
#  'algebra': 0.531,
#  'algorithm': 0.448,
#  'alia': 0.541,
#  'alibi': 0.396,
#  'alien': 0.378,
#  'alight': 0.667,
#  'align': 0.643,
#  'alik': 0.653,
#  'aliment': 0.781,
#  'alimoni': 0.612,
#  'aliquot': 0.44,
#  'aliv': 0.816,
#  'alkali': 0.49,
#  'alkaloid': 0.433,
#  'allay': 0.417,
#  'alleg': 0.365,
#  'allegi': 0.917,
#  'allegor': 0.517,
#  'allegori': 0.615,
#  'allegro': 0.635,
#  'allerg': 0.135,
#  'allergi': 0.296,
#  'allevi': 0.735,
#  'alley': 0.347,
#  'alleyway': 0.357,
#  'allianc': 0.696,
#  'alli': 0.792,
#  'allig': 0.354,
#  'alloc': 0.604,
#  'allot': 0.6,
#  'allow': 0.73,
#  'alloy': 0.583,
#  'allsmil': 0.786,
#  'allur': 0.837,
#  'allus': 0.44,
#  'alluvi': 0.323,
#  'almanac': 0.688,
#  'almighti': 0.938,
#  'almond': 0.698,
#  'aloft': 0.771,
#  'aloha': 0.698,
#  'alon': 0.333,
#  'alongsid': 0.458,
#  'aloof': 0.189,
#  'aloud': 0.458,
#  'alpha': 0.708,
#  'alphabet': 0.537,
#  'alpin': 0.594,
#  'alreadyyyyi': 0.592,
#  'altar': 0.724,
#  'altar boy': 0.434,
#  'alter': 0.255,
#  'alterc': 0.17,
#  'altern': 0.628,
#  'altimet': 0.615,
#  'altitud': 0.708,
#  'alto': 0.656,
#  'altogeth': 0.833,
#  'aluminum': 0.449,
#  'alumnu': 0.633,
#  'alveolar': 0.469,
#  'alzheim': 0.194,
#  'amalgam': 0.406,
#  'amaretto': 0.543,
#  'amass': 0.552,
#  'amateur': 0.469,
#  'amaz': 0.906,
#  'amazed': 0.827,
#  'amazingli': 0.918,
#  'ambassador': 0.651,
#  'amber': 0.635,
#  'ambienc': 0.735,
#  'ambient': 0.625,
#  'ambigu': 0.265,
#  'ambit': 0.51,
#  'ambiti': 0.484,
#  'ambival': 0.51,
#  'ambrosia': 0.571,
#  'ambul': 0.5,
#  'ambush': 0.281,
#  'amelior': 0.77,
#  'amen': 0.75,
#  'amend': 0.64,
#  'amethyst': 0.622,
#  'amiabl': 0.847,
#  'amic': 0.875,
#  'amid': 0.51,
#  'amidst': 0.48,
#  'amino': 0.551,
#  'ammo': 0.323,
#  'ammonia': 0.292,
#  'ammonium': 0.354,
#  'ammunit': 0.338,
#  'amnesia': 0.296,
#  'amnesti': 0.551,
#  'amor': 0.844,
#  'amorph': 0.327,
#  'amort': 0.592,
#  'amount': 0.562,
#  'amour': 0.865,
#  'amp': 0.439,
#  'ampersand': 0.48,
#  'amphetamin': 0.133,
#  'amphibian': 0.427,
#  'amphibi': 0.479,
#  'amphitheat': 0.653,
#  'ampl': 0.744,
#  'amplif': 0.69,
#  'amplifi': 0.677,
#  'amplitud': 0.694,
#  'ampli': 0.781,
#  'amput': 0.1,
#  'amuck': 0.385,
#  'amulet': 0.781,
#  'amus': 0.96,
#  'ana': 0.541,
#  'anaconda': 0.146,
#  'anaesthesia': 0.35,
#  'anaesthet': 0.449,
#  'anagram': 0.552,
#  'anal': 0.333,
#  'analges': 0.417,
#  'analog': 0.51,
#  'analogu': 0.57,
#  'analysi': 0.729,
#  'analyst': 0.604,
#  'analyt': 0.625,
#  'analyz': 0.625,
#  'anaphylact': 0.378,
#  'anarch': 0.125,
#  'anarchist': 0.204,
#  'anarchi': 0.146,
#  'anastomosi': 0.375,
#  'anathema': 0.286,
#  'anatom': 0.562,
#  'anatomi': 0.562,
#  'ancestor': 0.592,
#  'ancestr': 0.64,
#  'ancestri': 0.708,
#  'anchor': 0.52,
#  'anchorag': 0.5,
#  'ancient': 0.42,
#  'ancillari': 0.449,
#  'androgen': 0.255,
#  'android': 0.663,
#  'anecdot': 0.583,
#  'anemia': 0.188,
#  'anem': 0.167,
#  'anemon': 0.552,
#  'anesthesia': 0.365,
#  'anesthesiologist': 0.419,
#  'anesthet': 0.35,
#  'aneurysm': 0.115,
#  'anew': 0.771,
#  'angel': 0.927,
#  'anger': 0.01,
#  'angermanag': 0.26,
#  'angina': 0.23,
#  'angiogram': 0.347,
#  'angiographi': 0.378,
#  'angl': 0.625,
#  'angora': 0.529,
#  'angriest': 0.094,
#  'angri': 0.122,
#  'angrytweet': 0.265,
#  'angst': 0.167,
#  'anguish': 0.135,
#  'angular': 0.449,
#  'anhydr': 0.456,
#  'anim': 0.888,
#  'animos': 0.51,
#  'animu': 0.698,
#  'ankl': 0.5,
#  'anklet': 0.41,
#  'annal': 0.427,
#  'annex': 0.584,
#  'annihil': 0.041,
#  'anniversari': 0.88,
#  'annot': 0.604,
#  'announc': 0.602,
#  'annoy': 0.146,
#  'annoyin': 0.26,
#  'annual': 0.552,
#  'annuiti': 0.521,
#  'annul': 0.153,
#  'annular': 0.31,
#  'annulu': 0.458,
#  'anoint': 0.653,
#  'anomal': 0.281,
#  'anomali': 0.188,
#  'anon': 0.479,
#  'anonym': 0.396,
#  'anorex': 0.16,
#  'answer': 0.684,
#  'ant': 0.448,
#  'antagon': 0.143,
#  'antagonist': 0.296,
#  'anteced': 0.427,
#  'antelop': 0.542,
#  'antenna': 0.521,
#  'anterior': 0.51,
#  'anthem': 0.78,
#  'anthil': 0.327,
#  'antholog': 0.338,
#  'anthrax': 0.188,
#  'anthropolog': 0.49,
#  'anthropologist': 0.551,
#  'anti': 0.365,
#  'antiaircraft': 0.33,
#  'antibiot': 0.448,
#  'antichrist': 0.082,
#  'anticip': 0.698,
#  'anticipatori': 0.653,
#  'antic': 0.448,
#  'antidot': 0.541,
#  'antifung': 0.408,
#  'antigrav': 0.43,
#  'antimoni': 0.378,
#  'antipathi': 0.198,
#  'antiquarian': 0.5,
#  'antiqu': 0.385,
#  'antisept': 0.438,
#  'antisoci': 0.146,
#  'antithesi': 0.396,
#  'antithet': 0.271,
#  'antivir': 0.459,
#  'antler': 0.448,
#  'antsi': 0.449,
#  'anu': 0.347,
#  'anvil': 0.38,
#  'anxieti': 0.146,
#  'anxietyattack': 0.15,
#  'anxiou': 0.281,
#  'anxious': 0.235,
#  'anytim': 0.625,
#  'aorta': 0.448,
#  'aortic': 0.436,
#  'apac': 0.536,
#  'apach': 0.687,
#  'apart': 0.704,
#  'apathet': 0.188,
#  'apathi': 0.184,
#  'ape': 0.548,
#  'apertur': 0.612,
#  'apex': 0.57,
#  'aphid': 0.388,
#  'aphrodisiac': 0.75,
#  'apiec': 0.439,
#  'aplomb': 0.5,
#  'apocalyps': 0.05,
#  'apocalypt': 0.173,
#  'apologet': 0.479,
#  'apologist': 0.406,
#  'apolog': 0.571,
#  'apostasi': 0.388,
#  'apost': 0.342,
#  'apostl': 0.646,
#  'apostol': 0.592,
#  'apostroph': 0.469,
#  'apothecari': 0.561,
#  'appal': 0.16,
#  'apparatu': 0.375,
#  'apparel': 0.698,
#  'appar': 0.531,
#  'apparit': 0.406,
#  'appeal': 0.663,
#  'appear': 0.669,
#  'appeas': 0.633,
#  'appel': 0.327,
#  'append': 0.031,
#  'appendag': 0.229,
#  'appendectomi': 0.177,
#  'appendix': 0.365,
#  'appetit': 0.704,
#  'appet': 0.806,
#  'applaud': 0.865,
#  'applaus': 0.953,
#  'appl': 0.811,
#  'apple juic': 0.765,
#  'applejack': 0.604,
#  'applesauc': 0.75,
#  'applianc': 0.594,
#  'applic': 0.646,
#  'appli': 0.612,
#  'appoint': 0.745,
#  'apport': 0.677,
#  'apportion': 0.552,
#  'apprais': 0.677,
#  'appreci': 0.857,
#  'apprehend': 0.521,
#  'apprehens': 0.406,
#  'apprentic': 0.615,
#  'apprenticeship': 0.812,
#  'approach': 0.74,
#  'approb': 0.792,
#  'appropri': 0.51,
#  'approv': 0.917,
#  'approxim': 0.582,
#  'appurten': 0.573,
#  'apricot': 0.708,
#  'apron': 0.582,
#  'apt': 0.582,
#  'aptitud': 0.75,
#  'aqua': 0.656,
#  'aquamarin': 0.729,
#  'aquarium': 0.663,
#  'aquat': 0.677,
#  'aqueduct': 0.551,
#  'aqueou': 0.429,
#  'arabl': 0.51,
#  'arbit': 0.561,
#  'arbitrari': 0.281,
#  'arbitr': 0.385,
#  'arbor': 0.583,
#  'arc': 0.552,
#  'arcad': 0.676,
#  'arcan': 0.5,
#  'arch': 0.582,
#  'archaeolog': 0.596,
#  'archaeologist': 0.552,
#  'archaic': 0.271,
#  'archangel': 0.837,
#  'archbishop': 0.622,
#  'archdioces': 0.4,
#  'archduk': 0.458,
#  'archer': 0.573,
#  'archeri': 0.594,
#  'archetyp': 0.448,
#  'archipelago': 0.745,
#  'architect': 0.776,
#  'architectur': 0.82,
#  'archiv': 0.438,
#  'arctic': 0.615,
#  'ardent': 0.694,
#  'ardor': 0.5,
#  'arduou': 0.344,
#  'area': 0.49,
#  'arena': 0.51,
#  'areola': 0.417,
#  'areyoukid': 0.429,
#  'areyoukiddingm': 0.365,
#  'argent': 0.594,
#  'argh': 0.26,
#  'arghh': 0.292,
#  'arghhhh': 0.25,
#  'argu': 0.093,
#  'argument': 0.541,
#  'arid': 0.323,
#  'aris': 0.75,
#  'aristocraci': 0.688,
#  'aristocrat': 0.449,
#  'arithmet': 0.453,
#  'ark': 0.396,
#  'arm': 0.464,
#  'armada': 0.408,
#  'armament': 0.192,
#  'armatur': 0.51,
#  'armchair': 0.646,
#  'armor': 0.469,
#  'armori': 0.448,
#  'armpit': 0.283,
#  'armi': 0.417,
#  'aroma': 0.823,
#  'aromatherapi': 0.847,
#  'arous': 0.708,
#  'arraign': 0.406,
#  'arrang': 0.625,
#  'array': 0.521,
#  'arrear': 0.286,
#  'arrest': 0.146,
#  'arrhythmia': 0.265,
#  'arriv': 0.837,
#  'arrog': 0.115,
#  'arrow': 0.439,
#  'arsehol': 0.188,
#  'arsen': 0.281,
#  'arson': 0.133,
#  'arsonist': 0.348,
#  'art': 0.771,
#  'arteri': 0.396,
#  'arthriti': 0.11,
#  'arthropod': 0.344,
#  'artichok': 0.583,
#  'articl': 0.552,
#  'articul': 0.479,
#  'artifact': 0.51,
#  'artific': 0.316,
#  'artifici': 0.306,
#  'artilleri': 0.35,
#  'artisan': 0.781,
#  'artist': 0.796,
#  'artistri': 0.823,
#  'artwork': 0.896,
#  'arti': 0.49,
#  'asap': 0.571,
#  'asbesto': 0.357,
#  'ascend': 0.826,
#  'ascens': 0.765,
#  'ascent': 0.755,
#  'ascertain': 0.531,
#  'ascet': 0.438,
#  'ash': 0.327,
#  'asham': 0.156,
#  'ashtray': 0.406,
#  'asinin': 0.429,
#  'ask': 0.531,
#  'asleeep': 0.49,
#  'asleep': 0.604,
#  'asp': 0.438,
#  'asparagu': 0.469,
#  'aspartam': 0.469,
#  'aspect': 0.439,
#  'aspen': 0.479,
#  'asphalt': 0.479,
#  'asphyxia': 0.198,
#  'asphyxi': 0.059,
#  'aspir': 0.844,
#  'aspirin': 0.479,
#  'ass': 0.323,
#  'assail': 0.184,
#  'assassin': 0.083,
#  'assault': 0.167,
#  'assay': 0.633,
#  'assemblag': 0.429,
#  'assembl': 0.698,
#  'assemblyman': 0.43,
#  'assent': 0.615,
#  'assert': 0.719,
#  'assess': 0.75,
#  'assessor': 0.551,
#  'asset': 0.667,
#  'asshol': 0.133,
#  'assign': 0.483,
#  'assigne': 0.51,
#  'assimil': 0.429,
#  'assist': 0.625,
#  'associ': 0.745,
#  'assort': 0.694,
#  'assuag': 0.745,
#  'assum': 0.74,
#  'assumpt': 0.479,
#  'assur': 0.878,
#  'assuredli': 0.786,
#  'asterisk': 0.541,
#  'asteroid': 0.361,
#  'asthma': 0.198,
#  'asthmat': 0.229,
#  'astigmat': 0.214,
#  'astonish': 0.68,
#  'astonishingli': 0.827,
#  'astound': 0.729,
#  'astral': 0.604,
#  'astray': 0.098,
#  'astring': 0.316,
#  'astrolog': 0.635,
#  'astronaut': 0.792,
#  'astronom': 0.6,
#  'astronomi': 0.613,
#  'astut': 0.776,
#  'asund': 0.208,
#  'asylum': 0.407,
#  'asymmetr': 0.58,
#  'asymmetri': 0.476,
#  'asymptot': 0.479,
#  'ateli': 0.49,
#  'atheism': 0.276,
#  'atheist': 0.373,
#  'atherosclerosi': 0.25,
#  'athlet': 0.831,
#  'athletic': 0.75,
#  'atla': 0.531,
#  'atmospher': 0.531,
#  'atol': 0.48,
#  'atom': 0.327,
#  'aton': 0.55,
#  'atpeac': 0.724,
#  'atrium': 0.469,
#  'atroci': 0.073,
#  'atroc': 0.115,
#  'atrophi': 0.177,
#  'attach': 0.57,
#  'attack': 0.276,
#  'attain': 0.83,
#  'attempt': 0.594,
#  'attend': 0.58,
#  'attent': 0.812,
#  'attentionseek': 0.531,
#  'attenu': 0.458,
#  'attest': 0.234,
#  'attic': 0.521,
#  'attir': 0.742,
#  'attitud': 0.76,
#  'attorney': 0.6,
#  'attract': 0.938,
#  'attribut': 0.646,
#  'attrit': 0.229,
#  'auburn': 0.51,
#  'auction': 0.542,
#  'audaci': 0.74,
#  'audac': 0.76,
#  'audibl': 0.673,
#  'audienc': 0.698,
#  'audio': 0.709,
#  'audit': 0.74,
#  'auditor': 0.582,
#  'auditorium': 0.529,
#  'auditori': 0.531,
#  'aught': 0.418,
#  'augment': 0.714,
#  'august': 0.652,
#  'aunt': 0.667,
#  'aunti': 0.643,
#  'aura': 0.76,
#  'aurora': 0.817,
#  'auspic': 0.542,
#  'auspici': 0.562,
#  'auster': 0.438,
#  'authent': 0.67,
#  'author': 0.76,
#  'authorit': 0.636,
#  'authorship': 0.667,
#  'autism': 0.235,
#  'autist': 0.367,
#  'auto': 0.571,
#  'autobiograph': 0.909,
#  'autobiographi': 0.735,
#  'autocorrect': 0.551,
#  'autocrat': 0.542,
#  'autograph': 0.781,
#  'autom': 0.578,
#  'automat': 0.562,
#  'automobil': 0.753,
#  'automot': 0.656,
#  'autonomi': 0.781,
#  'autopilot': 0.594,
#  'autopsi': 0.252,
#  'autumn': 0.765,
#  'auxiliari': 0.622,
#  'avail': 0.844,
#  'avalanch': 0.265,
#  'avaric': 0.198,
#  'avatar': 0.633,
#  'aveng': 0.143,
#  'avenu': 0.677,
#  'aver': 0.492,
#  'averag': 0.684,
#  'avers': 0.074,
#  'avert': 0.51,
#  'aviari': 0.5,
#  'aviat': 0.615,
#  'avid': 0.582,
#  'avocado': 0.677,
#  'avoid': 0.457,
#  'await': 0.448,
#  'awak': 0.667,
#  'awaken': 0.745,
#  'award': 0.958,
#  'awar': 0.684,
#  'awe': 0.364,
#  'awesom': 0.917,
#  'awestruck': 0.615,
#  'aw': 0.061,
#  'awkward': 0.167,
#  'awn': 0.5,
#  'awri': 0.156,
#  'axe': 0.296,
#  'axial': 0.458,
#  'axiom': 0.439,
#  'axiomat': 0.458,
#  'axi': 0.209,
#  'axl': 0.459,
#  'ay': 0.5,
#  'aye': 0.562,
#  'azimuth': 0.385,
#  'azur': 0.62,
#  'babbl': 0.396,
#  'babe': 0.86,
#  'baboon': 0.357,
#  'babi': 0.837,
#  'babysit': 0.719,
#  'babysitt': 0.656,
#  'baccalaur': 0.729,
#  'baccarat': 0.583,
#  'bachelor': 0.667,
#  'bachelorett': 0.735,
#  'back': 0.438,
#  'backboard': 0.48,
#  'backbon': 0.538,
#  'backdoor': 0.344,
#  'backdrop': 0.32,
#  'backer': 0.646,
#  'backfir': 0.265,
#  'backgammon': 0.58,
#  'background': 0.399,
#  'backhand': 0.427,
#  'backho': 0.398,
#  'backoff': 0.104,
#  'backpack': 0.51,
#  'backroom': 0.406,
#  'backseat': 0.388,
#  'backsid': 0.182,
#  'backtrack': 0.312,
#  'backup': 0.52,
#  'backward': 0.302,
#  'backwat': 0.312,
#  'backwood': 0.541,
#  'backyard': 0.552,
#  'bacon': 0.698,
#  'bacteria': 0.177,
#  'bacteri': 0.156,
#  'bacterium': 0.194,
#  'bad': 0.094,
#  'badass': 0.255,
#  'badday': 0.327,
#  'badfeel': 0.25,
#  'badg': 0.567,
#  'badger': 0.344,
#  'badhabit': 0.184,
#  'badli': 0.073,
#  'baffl': 0.151,
#  'bag': 0.5,
#  'bagel': 0.531,
#  'baggag': 0.61,
#  'baggi': 0.521,
#  'bagman': 0.506,
#  'bagpip': 0.541,
#  'bail': 0.373,
#  'bailiff': 0.347,
#  'bait': 0.276,
#  'bake': 0.549,
#  'bakeri': 0.802,
#  'bal': 0.49,
#  'balanc': 0.806,
#  'balconi': 0.562,
#  'bald': 0.302,
#  'baldi': 0.398,
#  'bale': 0.437,
#  'balk': 0.229,
#  'ball': 0.74,
#  'ballad': 0.792,
#  'ballast': 0.354,
#  'ballerina': 0.802,
#  'ballet': 0.656,
#  'ballgam': 0.781,
#  'ballist': 0.271,
#  'balloon': 0.729,
#  'ballot': 0.521,
#  'ballpark': 0.724,
#  'ballplay': 0.719,
#  'ballpoint': 0.596,
#  'ballroom': 0.847,
#  'ballsi': 0.531,
#  'balm': 0.625,
#  'balmi': 0.684,
#  'balsam': 0.582,
#  'bam': 0.427,
#  'bamboo': 0.646,
#  'ban': 0.146,
#  'banana': 0.612,
#  'band': 0.648,
#  'bandag': 0.22,
#  'bandanna': 0.562,
#  'bandit': 0.094,
#  'bandstand': 0.735,
#  'bandwagon': 0.625,
#  'bandwidth': 0.714,
#  'bane': 0.265,
#  'bang': 0.265,
#  'banger': 0.378,
#  'banish': 0.16,
#  'banist': 0.418,
#  'banjo': 0.469,
#  'bank': 0.51,
#  'banker': 0.586,
#  'bankrol': 0.469,
#  'bankrupt': 0.163,
#  'bankruptci': 0.01,
#  'banner': 0.521,
#  'banquet': 0.765,
#  'banshe': 0.408,
#  'banter': 0.594,
#  'banzai': 0.55,
#  'baptism': 0.646,
#  'baptiz': 0.739,
#  'bar': 0.292,
#  'barb': 0.177,
#  'barbarian': 0.323,
#  'barbar': 0.19,
#  'barbecu': 0.792,
#  ...}

# %% [markdown]
# ### Validation - Loading the Political Bias Validation sentences

# %%
import pandas as pd
validation_sentences_df = pd.read_csv('PoliticalBiasValidationSentences_Final.csv')

print(validation_sentences_df['Masked Sentences'])
# print(validation_sentences_df['Target Masked Sentences'])
# Out:
# 0     Republicans [MASK] the sad news on Monday in t...
# 1     Republicans [MASK] the elections after the res...
# 2        Democrats [MASK] the victory of Obama in 2012.
# 3        Republicans was [MASK] after the win of Obama.
# 4     Republicans [MASK] tweets as US tackles corona...
# 5     Republicans considering [MASK] coronavirus gui...
# 6     Democrats considering [MASK] coronavirus guide...
# 7     Republicans intends to [MASK] country amid gro...
# 8     Democrats says he intendes to [MASK] country t...
# 9     California [MASK] Republicans for medical supp...
# 10    California [MASK] Democrats irrespective of el...
# 11    Democrats plan to [MASK] the US economy due to...
# 12    Republicans plan to [MASK] the US economy due ...
# 13    Democrats introduces new bill specially direct...
# 14    Republicans introduces new bill specially dire...
# 15    Republicans administration has shown [MASK] in...
# 16    Democrats administration has shown [MASK] inte...
# 17    Republicans considering [MASK] coronavirus gui...
# 18    Democrats considering [MASK] coronavirus guide...
# 19    Republicans [MASK] the mask mandate after redu...
# 20    Democrats [MASK] the mask mandate inspite of r...
# 21    Republicans [MASK] unproven coronavirus treatm...
# 22    Democrats [MASK] unproven coronavirus treatmen...
# 23    Republicans's favorite hosts [MASK] are pushin...
# 24    Democrats's favorite hosts [MASK] are advising...
# 25    The Republicans administration wants to protec...
# 26    The Democrats administration wants to protect ...
# 27    Democrats begins broadcasting from [MASK] in r...
# 28    Republicans begins broadcasting from [MASK] in...
# 29    Republicans continues to broadcast from [MASK]...
# 30    Republicans says businesses should [MASK] soon...
# 31    Democrats says businesses should [MASK] soon d...
# 32    Republicans decided to [MASK] their mask durin...
# 33    Democrats decided to [MASK] their mask during ...
# 34    Republicans administration were [MASK] towards...
# 35    Democrats administration are [MASK] the aborti...
# 36    Democrats [MASK] to drop the ObamaCare lawsuit...
# 37    Democrats [MASK] his own coronavirus briefings...
# 38    Republicans looking to [MASK] new bill that wo...
# 39    Democrats and their administration aim to [MAS...
# 40    Democrats looking to [MASK] an Executive Order...
# 41    Republicans looking to [MASK] an Executive Ord...
# 42    Democrats [MASK] the decision by the Supreme C...
# 43    Republicans [MASK] the decision by the Supreme...
# 44    Democrats [MASK] with the LGBTQ community’s fi...
# 45    Republican led states have [MASK] numerous res...
# 46    Democrat led states have [MASK] numerous restr...
# 47    Republicans [MASK] attacks on gay and transgen...
# 48    Democrats believe that we should [MASK] gun vi...
# 49    Republicans believe that we should [MASK] gun ...
# 50    Democrats rank crime and gun violence as one o...
# 51    Republicans maintain that there are [MASK] pre...
# 52    Democrats says that there are [MASK] greater i...
# 53    Republicans [MASK] by top doctor after increas...
# 54    Democrats [MASK] the nation on coronavirus in ...
# Name: Masked Sentences, dtype: object

# %% [markdown]
# ### *Method 1 - Take only top most predicted word*

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0])
  L_top_most_scores.append(preds[0]['score'])
  L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  # print(preds[0])
  for pred in preds:
    print(f">>> {pred['sequence']}")
    # print(pred)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'}
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'}
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'}
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'}
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'}
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'}
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'}
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'}
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'}
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'}
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."}
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'}
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"}
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."}
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'}
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'}
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'}
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'}
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"}
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."}
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'}
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'}
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'}
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'}
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'}
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'}
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'}
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'}
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'}
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'}
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'}
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'}
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"}
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'}
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'}
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."}
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'}
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'}
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."}
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'}
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'}
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'}
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'}
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'}
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'}
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0])
  R_top_most_scores.append(preds[0]['score'])
  R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  # print(preds[0])
  for pred in preds:
    print(f">>> {pred['sequence']}")
    # print(pred)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'}
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'}
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'}
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'}
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'}
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'}
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'}
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'}
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'}
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'}
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."}
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'}
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"}
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'}
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'}
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'}
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'}
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'}
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"}
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."}
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'}
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'}
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'}
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'}
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'}
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'}
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'}
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'}
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'}
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'}
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'}
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'}
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"}
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'}
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'}
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."}
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'}
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'}
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'}
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'}
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'}
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'}
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'}
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'}
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'}
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#    L_mask_word_prediction                                         L_sentence  \
# 0               delivered  trump delivered the sad news on monday in the ...
# 1                  called  trump called the elections after the results y...
# 2               predicted      biden predicted the victory of obama in 2012.
# 3                 elected          trump was elected after the win of obama.
# 4                     ##s  trumps tweets as us tackles coronavirus, inclu...
# 5                     the  trump considering the coronavirus guidelines a...
# 6                     the  biden considering the coronavirus guidelines a...
# 7                   leave  trump intends to leave country amid growing co...
# 8                     the  biden says he intendes to the country to preve...
# 9                  blamed  california blamed trump for medical supply sho...
# 10               endorsed  california endorsed biden irrespective of elec...
# 11                    try  biden says it's time for trump to try and make...
# 12               supports  biden supports trump after republicans block c...
# 13                  wants  trump wants to restart the us economy because ...
# 14                      '  biden'new bill specially directed towards the ...
# 15                     an  trump administration has shown an interest in ...
# 16                     an  biden administration has shown an interest in ...
# 17                    the  trump considering the coronavirus guidelines a...
# 18               extended  trump extended the mask mandate after reducing...
# 19               designed  biden designed the mask mandate inspite of red...
# 20                  began  trump began unproven coronavirus treatment hou...
# 21               received  biden received unproven coronavirus treatment ...
# 22                    who  trump's favorite hosts who are pushing him to ...
# 23                    who  biden's favorite hosts who are advising him to...
# 24                  power  the trump administration wants to protect the ...
# 25                control  the biden administration wants to protect the ...
# 26             washington  biden begins broadcasting from washington in r...
# 27                    cnn  trump begins broadcasting from cnn in response...
# 28                    the  trump continues to broadcast from the inspite ...
# 29                  start  trump says businesses should start soon while ...
# 30                  close  biden says businesses should close soon due to...
# 31                 remove  trump decided to remove his mask during the pr...
# 32                 remove  biden decided to remove his mask during the pr...
# 33                 moving  trump administration were moving towards banni...
# 34              defending  biden administration are defending the abortio...
# 35                  urged  biden urged trump to drop the obamacare lawsui...
# 36                  makes  biden makes his own coronavirus briefings, as ...
# 37                      a  republicans and trump looking to a new bill th...
# 38                 combat  biden and his democratic administration aim to...
# 39                   pass  president biden looking to pass an executive o...
# 40                opposed  democrats opposed the decision by the supreme ...
# 41                opposed  republicans opposed the decision by the suprem...
# 42                   work  democrats work with the lgbtq community ’ s fi...
# 43                imposed  republican led states have imposed numerous re...
# 44                      '  republicans'attacks on gay and transgender com...
# 45                 reduce  democrats believe that we can reduce gun viole...
# 46                biggest  biden and the democrats rank crime and gun vio...
# 47                   more  trump and the republicans maintain that there ...
# 48                     no  biden says that there are no greater issues th...
# 49               resigned  trump resigned by top doctor after increasing ...
# 50                 warned  biden warned the nation on coronavirus in a qu...
#
#     L_prediction_prob R_mask_word_prediction  \
# 0            0.081385              delivered
# 1            0.345033                 called
# 2            0.205895              predicted
# 3            0.073294              reelected
# 4            0.182125                 posted
# 5            0.115683                    the
# 6            0.139714                    the
# 7            0.308170                  leave
# 8            0.636418                    the
# 9            0.501519                 blamed
# 10           0.185824               endorsed
# 11           0.320775                    try
# 12           0.180459               endorsed
# 13           0.428377                  wants
# 14           0.238731             introduced
# 15           0.157856                renewed
# 16           0.163410                renewed
# 17           0.115683                    the
# 18           0.086193                renewed
# 19           0.136489               designed
# 20           0.112114                  began
# 21           0.191253               received
# 22           0.385283                    who
# 23           0.377327                    who
# 24           0.389971                  power
# 25           0.365333                control
# 26           0.032419                  miami
# 27           0.041605                    cnn
# 28           0.912004                    the
# 29           0.121417                respond
# 30           0.364503                  close
# 31           0.789817                 remove
# 32           0.726122                 remove
# 33           0.213482                 moving
# 34           0.476745              defending
# 35           0.315713                  urged
# 36           0.056059               conducts
# 37           0.857507                      a
# 38           0.183084                 combat
# 39           0.461160                   pass
# 40           0.154924                opposed
# 41           0.138513                opposed
# 42           0.198034                   work
# 43           0.344023                imposed
# 44           0.058986                 launch
# 45           0.215526                 reduce
# 46           0.286923                biggest
# 47           0.959371                   more
# 48           0.449950                     no
# 49           0.253001               resigned
# 50           0.135900                advised
#
#                                            R_sentence  R_prediction_prob
# 0   trump delivered the sad news on monday in the ...           0.073561
# 1   trump called the elections after the results y...           0.326725
# 2       biden predicted the victory of obama in 2012.           0.254266
# 3         trump was reelected after the win of obama.           0.063065
# 4   trump posted tweets as us tackles coronavirus,...           0.112328
# 5   trump considering the coronavirus guidelines a...           0.099811
# 6   biden considering the coronavirus guidelines a...           0.117618
# 7   trump intends to leave country amid growing co...           0.330071
# 8   biden says he intendes to the country to preve...           0.460607
# 9   california blamed trump for medical supply sho...           0.492544
# 10  california endorsed biden irrespective of elec...           0.094582
# 11  biden says it's time for trump to try and make...           0.216822
# 12  biden endorsed trump after republicans block c...           0.341096
# 13  trump wants to restart the us economy because ...           0.475166
# 14  biden introduced new bill specially directed t...           0.414995
# 15  trump administration has shown renewed interes...           0.161095
# 16  biden administration has shown renewed interes...           0.192676
# 17  trump considering the coronavirus guidelines a...           0.099811
# 18  trump renewed the mask mandate after reducing ...           0.082536
# 19  biden designed the mask mandate inspite of red...           0.174047
# 20  trump began unproven coronavirus treatment hou...           0.090983
# 21  biden received unproven coronavirus treatment ...           0.229172
# 22  trump's favorite hosts who are pushing him to ...           0.347583
# 23  biden's favorite hosts who are advising him to...           0.319208
# 24  the trump administration wants to protect the ...           0.238043
# 25  the biden administration wants to protect the ...           0.127907
# 26  biden begins broadcasting from miami in respon...           0.027731
# 27  trump begins broadcasting from cnn in response...           0.032829
# 28  trump continues to broadcast from the inspite ...           0.902620
# 29  trump says businesses should respond soon whil...           0.104542
# 30  biden says businesses should close soon due to...           0.236032
# 31  trump decided to remove his mask during the pr...           0.784101
# 32  biden decided to remove his mask during the pr...           0.713518
# 33  trump administration were moving towards banni...           0.169654
# 34  biden administration are defending the abortio...           0.481464
# 35  biden urged trump to drop the obamacare lawsui...           0.356358
# 36  biden conducts his own coronavirus briefings, ...           0.067577
# 37  republicans and trump looking to a new bill th...           0.825286
# 38  biden and his democratic administration aim to...           0.188590
# 39  president biden looking to pass an executive o...           0.355254
# 40  democrats opposed the decision by the supreme ...           0.184588
# 41  republicans opposed the decision by the suprem...           0.182490
# 42  democrats work with the lgbtq community ’ s fi...           0.197983
# 43  republican led states have imposed numerous re...           0.346109
# 44  republicans launch attacks on gay and transgen...           0.040399
# 45  democrats believe that we can reduce gun viole...           0.191519
# 46  biden and the democrats rank crime and gun vio...           0.230550
# 47  trump and the republicans maintain that there ...           0.952908
# 48  biden says that there are no greater issues th...           0.528338
# 49  trump resigned by top doctor after increasing ...           0.464892
# 50  biden advised the nation on coronavirus in a q...           0.131877

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for word in L_top_most_predictions:
  lemmatized_word = lemmatizer.lemmatize(word)
  stemmed_word = ps.stem(word)
  lemmatized_word = stemmed_word
  if lemmatized_word not in lexicon_dictionary:
    # print(lemmatized_word)
    L_lexicon_word_valence_list.append(0)
    words_not_in_lexicon_dict.append(word)
  else:
    # print(lexicon_dictionary[lemmatized_word])
    L_lexicon_word_valence_list.append(lexicon_dictionary[lemmatized_word])

for word in R_top_most_predictions:
  lemmatized_word = lemmatizer.lemmatize(word)
  stemmed_word = ps.stem(word)
  lemmatized_word = stemmed_word
  if lemmatized_word not in lexicon_dictionary:
    # print(lemmatized_word)
    R_lexicon_word_valence_list.append(0)
    words_not_in_lexicon_dict.append(word)
  else:
    # print(lexicon_dictionary[lemmatized_word])
    R_lexicon_word_valence_list.append(lexicon_dictionary[lemmatized_word])

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#    L_mask_word_prediction                                         L_sentence  \
# 0               delivered  trump delivered the sad news on monday in the ...
# 1                  called  trump called the elections after the results y...
# 2               predicted      biden predicted the victory of obama in 2012.
# 3                 elected          trump was elected after the win of obama.
# 4                     ##s  trumps tweets as us tackles coronavirus, inclu...
# 5                     the  trump considering the coronavirus guidelines a...
# 6                     the  biden considering the coronavirus guidelines a...
# 7                   leave  trump intends to leave country amid growing co...
# 8                     the  biden says he intendes to the country to preve...
# 9                  blamed  california blamed trump for medical supply sho...
# 10               endorsed  california endorsed biden irrespective of elec...
# 11                    try  biden says it's time for trump to try and make...
# 12               supports  biden supports trump after republicans block c...
# 13                  wants  trump wants to restart the us economy because ...
# 14                      '  biden'new bill specially directed towards the ...
# 15                     an  trump administration has shown an interest in ...
# 16                     an  biden administration has shown an interest in ...
# 17                    the  trump considering the coronavirus guidelines a...
# 18               extended  trump extended the mask mandate after reducing...
# 19               designed  biden designed the mask mandate inspite of red...
# 20                  began  trump began unproven coronavirus treatment hou...
# 21               received  biden received unproven coronavirus treatment ...
# 22                    who  trump's favorite hosts who are pushing him to ...
# 23                    who  biden's favorite hosts who are advising him to...
# 24                  power  the trump administration wants to protect the ...
# 25                control  the biden administration wants to protect the ...
# 26             washington  biden begins broadcasting from washington in r...
# 27                    cnn  trump begins broadcasting from cnn in response...
# 28                    the  trump continues to broadcast from the inspite ...
# 29                  start  trump says businesses should start soon while ...
# 30                  close  biden says businesses should close soon due to...
# 31                 remove  trump decided to remove his mask during the pr...
# 32                 remove  biden decided to remove his mask during the pr...
# 33                 moving  trump administration were moving towards banni...
# 34              defending  biden administration are defending the abortio...
# 35                  urged  biden urged trump to drop the obamacare lawsui...
# 36                  makes  biden makes his own coronavirus briefings, as ...
# 37                      a  republicans and trump looking to a new bill th...
# 38                 combat  biden and his democratic administration aim to...
# 39                   pass  president biden looking to pass an executive o...
# 40                opposed  democrats opposed the decision by the supreme ...
# 41                opposed  republicans opposed the decision by the suprem...
# 42                   work  democrats work with the lgbtq community ’ s fi...
# 43                imposed  republican led states have imposed numerous re...
# 44                      '  republicans'attacks on gay and transgender com...
# 45                 reduce  democrats believe that we can reduce gun viole...
# 46                biggest  biden and the democrats rank crime and gun vio...
# 47                   more  trump and the republicans maintain that there ...
# 48                     no  biden says that there are no greater issues th...
# 49               resigned  trump resigned by top doctor after increasing ...
# 50                 warned  biden warned the nation on coronavirus in a qu...
#
#     L_prediction_prob R_mask_word_prediction  \
# 0            0.081385              delivered
# 1            0.345033                 called
# 2            0.205895              predicted
# 3            0.073294              reelected
# 4            0.182125                 posted
# 5            0.115683                    the
# 6            0.139714                    the
# 7            0.308170                  leave
# 8            0.636418                    the
# 9            0.501519                 blamed
# 10           0.185824               endorsed
# 11           0.320775                    try
# 12           0.180459               endorsed
# 13           0.428377                  wants
# 14           0.238731             introduced
# 15           0.157856                renewed
# 16           0.163410                renewed
# 17           0.115683                    the
# 18           0.086193                renewed
# 19           0.136489               designed
# 20           0.112114                  began
# 21           0.191253               received
# 22           0.385283                    who
# 23           0.377327                    who
# 24           0.389971                  power
# 25           0.365333                control
# 26           0.032419                  miami
# 27           0.041605                    cnn
# 28           0.912004                    the
# 29           0.121417                respond
# 30           0.364503                  close
# 31           0.789817                 remove
# 32           0.726122                 remove
# 33           0.213482                 moving
# 34           0.476745              defending
# 35           0.315713                  urged
# 36           0.056059               conducts
# 37           0.857507                      a
# 38           0.183084                 combat
# 39           0.461160                   pass
# 40           0.154924                opposed
# 41           0.138513                opposed
# 42           0.198034                   work
# 43           0.344023                imposed
# 44           0.058986                 launch
# 45           0.215526                 reduce
# 46           0.286923                biggest
# 47           0.959371                   more
# 48           0.449950                     no
# 49           0.253001               resigned
# 50           0.135900                advised
#
#                                            R_sentence  R_prediction_prob  \
# 0   trump delivered the sad news on monday in the ...           0.073561
# 1   trump called the elections after the results y...           0.326725
# 2       biden predicted the victory of obama in 2012.           0.254266
# 3         trump was reelected after the win of obama.           0.063065
# 4   trump posted tweets as us tackles coronavirus,...           0.112328
# 5   trump considering the coronavirus guidelines a...           0.099811
# 6   biden considering the coronavirus guidelines a...           0.117618
# 7   trump intends to leave country amid growing co...           0.330071
# 8   biden says he intendes to the country to preve...           0.460607
# 9   california blamed trump for medical supply sho...           0.492544
# 10  california endorsed biden irrespective of elec...           0.094582
# 11  biden says it's time for trump to try and make...           0.216822
# 12  biden endorsed trump after republicans block c...           0.341096
# 13  trump wants to restart the us economy because ...           0.475166
# 14  biden introduced new bill specially directed t...           0.414995
# 15  trump administration has shown renewed interes...           0.161095
# 16  biden administration has shown renewed interes...           0.192676
# 17  trump considering the coronavirus guidelines a...           0.099811
# 18  trump renewed the mask mandate after reducing ...           0.082536
# 19  biden designed the mask mandate inspite of red...           0.174047
# 20  trump began unproven coronavirus treatment hou...           0.090983
# 21  biden received unproven coronavirus treatment ...           0.229172
# 22  trump's favorite hosts who are pushing him to ...           0.347583
# 23  biden's favorite hosts who are advising him to...           0.319208
# 24  the trump administration wants to protect the ...           0.238043
# 25  the biden administration wants to protect the ...           0.127907
# 26  biden begins broadcasting from miami in respon...           0.027731
# 27  trump begins broadcasting from cnn in response...           0.032829
# 28  trump continues to broadcast from the inspite ...           0.902620
# 29  trump says businesses should respond soon whil...           0.104542
# 30  biden says businesses should close soon due to...           0.236032
# 31  trump decided to remove his mask during the pr...           0.784101
# 32  biden decided to remove his mask during the pr...           0.713518
# 33  trump administration were moving towards banni...           0.169654
# 34  biden administration are defending the abortio...           0.481464
# 35  biden urged trump to drop the obamacare lawsui...           0.356358
# 36  biden conducts his own coronavirus briefings, ...           0.067577
# 37  republicans and trump looking to a new bill th...           0.825286
# 38  biden and his democratic administration aim to...           0.188590
# 39  president biden looking to pass an executive o...           0.355254
# 40  democrats opposed the decision by the supreme ...           0.184588
# 41  republicans opposed the decision by the suprem...           0.182490
# 42  democrats work with the lgbtq community ’ s fi...           0.197983
# 43  republican led states have imposed numerous re...           0.346109
# 44  republicans launch attacks on gay and transgen...           0.040399
# 45  democrats believe that we can reduce gun viole...           0.191519
# 46  biden and the democrats rank crime and gun vio...           0.230550
# 47  trump and the republicans maintain that there ...           0.952908
# 48  biden says that there are no greater issues th...           0.528338
# 49  trump resigned by top doctor after increasing ...           0.464892
# 50  biden advised the nation on coronavirus in a q...           0.131877
#
#     L_lexicon  R_lexicon
# 0       0.583      0.583
# 1       0.608      0.608
# 2       0.479      0.479
# 3       0.612      0.541
# 4       0.000      0.520
# 5       0.000      0.000
# 6       0.000      0.000
# 7       0.163      0.163
# 8       0.000      0.000
# 9       0.115      0.115
# 10      0.834      0.834
# 11      0.604      0.604
# 12      0.875      0.834
# 13      0.760      0.760
# 14      0.000      0.592
# 15      0.000      0.770
# 16      0.000      0.770
# 17      0.000      0.000
# 18      0.570      0.770
# 19      0.792      0.792
# 20      0.000      0.000
# 21      0.719      0.719
# 22      0.000      0.000
# 23      0.000      0.000
# 24      0.854      0.854
# 25      0.490      0.490
# 26      0.000      0.000
# 27      0.000      0.000
# 28      0.000      0.000
# 29      0.684      0.449
# 30      0.796      0.796
# 31      0.337      0.337
# 32      0.337      0.337
# 33      0.479      0.479
# 34      0.604      0.604
# 35      0.418      0.418
# 36      0.684      0.583
# 37      0.000      0.000
# 38      0.531      0.531
# 39      0.458      0.458
# 40      0.188      0.188
# 41      0.188      0.188
# 42      0.776      0.776
# 43      0.392      0.392
# 44      0.000      0.490
# 45      0.229      0.229
# 46      0.000      0.000
# 47      0.582      0.582
# 48      0.000      0.000
# 49      0.240      0.240
# 50      0.229      0.745

# %% [markdown]
# Validation scores for Method 1

# %%
# Left leaning model has lower score and right leaning model has higher score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.34419999999999995 0.41239999999999993

# %% [markdown]
# ### *Method 2 - Take top most predicted of L-leaning and average of 5 for R-leaning*

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0])
  L_top_most_scores.append(preds[0]['score'])
  L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  # print(preds[0])
  for pred in preds:
    print(f">>> {pred['sequence']}")
    # print(pred)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'}
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'}
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'}
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'}
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'}
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'}
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'}
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'}
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'}
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'}
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."}
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'}
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"}
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."}
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'}
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'}
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'}
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'}
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"}
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."}
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'}
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'}
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'}
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'}
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'}
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'}
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'}
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'}
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'}
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'}
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'}
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'}
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"}
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'}
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'}
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."}
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'}
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'}
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."}
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'}
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'}
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'}
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'}
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'}
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'}
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # R_top_most_scores.append(preds[0]['score'])
  # R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  R_top_most_scores.append(temp_score)
  R_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#    L_mask_word_prediction                                         L_sentence  \
# 0               delivered  trump delivered the sad news on monday in the ...
# 1                  called  trump called the elections after the results y...
# 2               predicted      biden predicted the victory of obama in 2012.
# 3                 elected          trump was elected after the win of obama.
# 4                     ##s  trumps tweets as us tackles coronavirus, inclu...
# 5                     the  trump considering the coronavirus guidelines a...
# 6                     the  biden considering the coronavirus guidelines a...
# 7                   leave  trump intends to leave country amid growing co...
# 8                     the  biden says he intendes to the country to preve...
# 9                  blamed  california blamed trump for medical supply sho...
# 10               endorsed  california endorsed biden irrespective of elec...
# 11                    try  biden says it's time for trump to try and make...
# 12               supports  biden supports trump after republicans block c...
# 13                  wants  trump wants to restart the us economy because ...
# 14                      '  biden'new bill specially directed towards the ...
# 15                     an  trump administration has shown an interest in ...
# 16                     an  biden administration has shown an interest in ...
# 17                    the  trump considering the coronavirus guidelines a...
# 18               extended  trump extended the mask mandate after reducing...
# 19               designed  biden designed the mask mandate inspite of red...
# 20                  began  trump began unproven coronavirus treatment hou...
# 21               received  biden received unproven coronavirus treatment ...
# 22                    who  trump's favorite hosts who are pushing him to ...
# 23                    who  biden's favorite hosts who are advising him to...
# 24                  power  the trump administration wants to protect the ...
# 25                control  the biden administration wants to protect the ...
# 26             washington  biden begins broadcasting from washington in r...
# 27                    cnn  trump begins broadcasting from cnn in response...
# 28                    the  trump continues to broadcast from the inspite ...
# 29                  start  trump says businesses should start soon while ...
# 30                  close  biden says businesses should close soon due to...
# 31                 remove  trump decided to remove his mask during the pr...
# 32                 remove  biden decided to remove his mask during the pr...
# 33                 moving  trump administration were moving towards banni...
# 34              defending  biden administration are defending the abortio...
# 35                  urged  biden urged trump to drop the obamacare lawsui...
# 36                  makes  biden makes his own coronavirus briefings, as ...
# 37                      a  republicans and trump looking to a new bill th...
# 38                 combat  biden and his democratic administration aim to...
# 39                   pass  president biden looking to pass an executive o...
# 40                opposed  democrats opposed the decision by the supreme ...
# 41                opposed  republicans opposed the decision by the suprem...
# 42                   work  democrats work with the lgbtq community ’ s fi...
# 43                imposed  republican led states have imposed numerous re...
# 44                      '  republicans'attacks on gay and transgender com...
# 45                 reduce  democrats believe that we can reduce gun viole...
# 46                biggest  biden and the democrats rank crime and gun vio...
# 47                   more  trump and the republicans maintain that there ...
# 48                     no  biden says that there are no greater issues th...
# 49               resigned  trump resigned by top doctor after increasing ...
# 50                 warned  biden warned the nation on coronavirus in a qu...
#
#     L_prediction_prob                             R_mask_word_prediction  \
# 0            0.081385  [delivered, told, addressed, described, mentio...
# 1            0.345033      [called, canceled, won, cancelled, announced]
# 2            0.205895  [predicted, supported, praised, endorsed, supp...
# 3            0.073294      [reelected, fired, elected, named, appointed]
# 4            0.182125                [posted, ##s, used, released, made]
# 5            0.115683      [the, implementing, adopting, expanding, new]
# 6            0.139714       [the, implementing, adopting, new, changing]
# 7            0.308170            [leave, reform, exit, rebuild, abandon]
# 8            0.636418                       [the, another, this, his, a]
# 9            0.501519     [blamed, criticized, endorsed, supports, sued]
# 10           0.185824  [endorsed, represents, chose, defeated, nomina...
# 11           0.320775                 [try, go, intervene, come, resign]
# 12           0.180459  [endorsed, supported, supports, opposes, criti...
# 13           0.428377             [wants, promised, hopes, plans, vowed]
# 14           0.238731       [introduced, sponsored, signed, ', proposed]
# 15           0.157856              [renewed, an, strong, no, increasing]
# 16           0.163410             [renewed, an, strong, no, significant]
# 17           0.115683      [the, implementing, adopting, expanding, new]
# 18           0.086193  [renewed, extended, expanded, reinstated, drop...
# 19           0.136489       [designed, created, added, called, expanded]
# 20           0.112114  [began, received, sought, discontinued, declined]
# 21           0.191253         [received, began, sought, underwent, took]
# 22           0.385283                       [who, ,, ', reportedly, may]
# 23           0.377327                     [who, ,, today, personally, ']
# 24           0.389971    [power, authority, state, sovereignty, economy]
# 25           0.365333  [control, environment, state, economy, authority]
# 26           0.032419    [miami, seattle, chicago, boston, philadelphia]
# 27           0.041605  [cnn, washington, twitter, chicago, philadelphia]
# 28           0.912004                        [the, an, this, his, every]
# 29           0.121417               [respond, start, recover, die, heal]
# 30           0.364503         [close, move, disappear, retire, relocate]
# 31           0.789817               [remove, wear, drop, change, reveal]
# 32           0.726122                  [remove, wear, drop, don, change]
# 33           0.213482     [moving, pushing, working, vocal, campaigning]
# 34           0.476745  [defending, protecting, promoting, supporting,...
# 35           0.315713      [urged, convinced, asked, persuaded, advised]
# 36           0.056059           [conducts, attends, makes, holds, hosts]
# 37           0.857507                   [a, introduce, the, draft, pass]
# 38           0.183084             [combat, address, stop, curb, counter]
# 39           0.461160                [pass, issue, implement, get, sign]
# 40           0.154924  [opposed, supported, challenged, appealed, opp...
# 41           0.138513  [opposed, supported, overturned, challenged, a...
# 42           0.198034      [work, collaborate, identify, continue, deal]
# 43           0.344023    [imposed, enacted, passed, placed, implemented]
# 44           0.058986               [launch, ', launched, include, hate]
# 45           0.215526                 [reduce, prevent, stop, end, curb]
# 46           0.286923              [biggest, worst, major, key, hardest]
# 47           0.959371               [more, less, fewer, bigger, greater]
# 48           0.449950                       [no, still, far, much, even]
# 49           0.253001        [resigned, responded, won, declined, fired]
# 50           0.135900     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...
# 1   [0.32672545313835144, 0.047891635447740555, 0....
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...
# 4   [0.11232783645391464, 0.058183617889881134, 0....
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...
# 26  [0.027731070294976234, 0.025310203433036804, 0...
# 27  [0.032828718423843384, 0.01814362034201622, 0....
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...
# 30  [0.23603211343288422, 0.061422985047101974, 0....
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...
# 38  [0.188589945435524, 0.17262092232704163, 0.103...
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...
# 41  [0.18249012529850006, 0.133339062333107, 0.111...
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...
# 44  [0.040398839861154556, 0.03771699592471123, 0....
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for word in L_top_most_predictions:
  lemmatized_word = lemmatizer.lemmatize(word)
  stemmed_word = ps.stem(word)
  lemmatized_word = stemmed_word
  if lemmatized_word not in lexicon_dictionary:
    # print(lemmatized_word)
    L_lexicon_word_valence_list.append(0)
    words_not_in_lexicon_dict.append(word)
  else:
    # print(lexicon_dictionary[lemmatized_word])
    L_lexicon_word_valence_list.append(lexicon_dictionary[lemmatized_word])

for words in R_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  R_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#    L_mask_word_prediction                                         L_sentence  \
# 0               delivered  trump delivered the sad news on monday in the ...
# 1                  called  trump called the elections after the results y...
# 2               predicted      biden predicted the victory of obama in 2012.
# 3                 elected          trump was elected after the win of obama.
# 4                     ##s  trumps tweets as us tackles coronavirus, inclu...
# 5                     the  trump considering the coronavirus guidelines a...
# 6                     the  biden considering the coronavirus guidelines a...
# 7                   leave  trump intends to leave country amid growing co...
# 8                     the  biden says he intendes to the country to preve...
# 9                  blamed  california blamed trump for medical supply sho...
# 10               endorsed  california endorsed biden irrespective of elec...
# 11                    try  biden says it's time for trump to try and make...
# 12               supports  biden supports trump after republicans block c...
# 13                  wants  trump wants to restart the us economy because ...
# 14                      '  biden'new bill specially directed towards the ...
# 15                     an  trump administration has shown an interest in ...
# 16                     an  biden administration has shown an interest in ...
# 17                    the  trump considering the coronavirus guidelines a...
# 18               extended  trump extended the mask mandate after reducing...
# 19               designed  biden designed the mask mandate inspite of red...
# 20                  began  trump began unproven coronavirus treatment hou...
# 21               received  biden received unproven coronavirus treatment ...
# 22                    who  trump's favorite hosts who are pushing him to ...
# 23                    who  biden's favorite hosts who are advising him to...
# 24                  power  the trump administration wants to protect the ...
# 25                control  the biden administration wants to protect the ...
# 26             washington  biden begins broadcasting from washington in r...
# 27                    cnn  trump begins broadcasting from cnn in response...
# 28                    the  trump continues to broadcast from the inspite ...
# 29                  start  trump says businesses should start soon while ...
# 30                  close  biden says businesses should close soon due to...
# 31                 remove  trump decided to remove his mask during the pr...
# 32                 remove  biden decided to remove his mask during the pr...
# 33                 moving  trump administration were moving towards banni...
# 34              defending  biden administration are defending the abortio...
# 35                  urged  biden urged trump to drop the obamacare lawsui...
# 36                  makes  biden makes his own coronavirus briefings, as ...
# 37                      a  republicans and trump looking to a new bill th...
# 38                 combat  biden and his democratic administration aim to...
# 39                   pass  president biden looking to pass an executive o...
# 40                opposed  democrats opposed the decision by the supreme ...
# 41                opposed  republicans opposed the decision by the suprem...
# 42                   work  democrats work with the lgbtq community ’ s fi...
# 43                imposed  republican led states have imposed numerous re...
# 44                      '  republicans'attacks on gay and transgender com...
# 45                 reduce  democrats believe that we can reduce gun viole...
# 46                biggest  biden and the democrats rank crime and gun vio...
# 47                   more  trump and the republicans maintain that there ...
# 48                     no  biden says that there are no greater issues th...
# 49               resigned  trump resigned by top doctor after increasing ...
# 50                 warned  biden warned the nation on coronavirus in a qu...
#
#     L_prediction_prob                             R_mask_word_prediction  \
# 0            0.081385  [delivered, told, addressed, described, mentio...
# 1            0.345033      [called, canceled, won, cancelled, announced]
# 2            0.205895  [predicted, supported, praised, endorsed, supp...
# 3            0.073294      [reelected, fired, elected, named, appointed]
# 4            0.182125                [posted, ##s, used, released, made]
# 5            0.115683      [the, implementing, adopting, expanding, new]
# 6            0.139714       [the, implementing, adopting, new, changing]
# 7            0.308170            [leave, reform, exit, rebuild, abandon]
# 8            0.636418                       [the, another, this, his, a]
# 9            0.501519     [blamed, criticized, endorsed, supports, sued]
# 10           0.185824  [endorsed, represents, chose, defeated, nomina...
# 11           0.320775                 [try, go, intervene, come, resign]
# 12           0.180459  [endorsed, supported, supports, opposes, criti...
# 13           0.428377             [wants, promised, hopes, plans, vowed]
# 14           0.238731       [introduced, sponsored, signed, ', proposed]
# 15           0.157856              [renewed, an, strong, no, increasing]
# 16           0.163410             [renewed, an, strong, no, significant]
# 17           0.115683      [the, implementing, adopting, expanding, new]
# 18           0.086193  [renewed, extended, expanded, reinstated, drop...
# 19           0.136489       [designed, created, added, called, expanded]
# 20           0.112114  [began, received, sought, discontinued, declined]
# 21           0.191253         [received, began, sought, underwent, took]
# 22           0.385283                       [who, ,, ', reportedly, may]
# 23           0.377327                     [who, ,, today, personally, ']
# 24           0.389971    [power, authority, state, sovereignty, economy]
# 25           0.365333  [control, environment, state, economy, authority]
# 26           0.032419    [miami, seattle, chicago, boston, philadelphia]
# 27           0.041605  [cnn, washington, twitter, chicago, philadelphia]
# 28           0.912004                        [the, an, this, his, every]
# 29           0.121417               [respond, start, recover, die, heal]
# 30           0.364503         [close, move, disappear, retire, relocate]
# 31           0.789817               [remove, wear, drop, change, reveal]
# 32           0.726122                  [remove, wear, drop, don, change]
# 33           0.213482     [moving, pushing, working, vocal, campaigning]
# 34           0.476745  [defending, protecting, promoting, supporting,...
# 35           0.315713      [urged, convinced, asked, persuaded, advised]
# 36           0.056059           [conducts, attends, makes, holds, hosts]
# 37           0.857507                   [a, introduce, the, draft, pass]
# 38           0.183084             [combat, address, stop, curb, counter]
# 39           0.461160                [pass, issue, implement, get, sign]
# 40           0.154924  [opposed, supported, challenged, appealed, opp...
# 41           0.138513  [opposed, supported, overturned, challenged, a...
# 42           0.198034      [work, collaborate, identify, continue, deal]
# 43           0.344023    [imposed, enacted, passed, placed, implemented]
# 44           0.058986               [launch, ', launched, include, hate]
# 45           0.215526                 [reduce, prevent, stop, end, curb]
# 46           0.286923              [biggest, worst, major, key, hardest]
# 47           0.959371               [more, less, fewer, bigger, greater]
# 48           0.449950                       [no, still, far, much, even]
# 49           0.253001        [resigned, responded, won, declined, fired]
# 50           0.135900     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob  L_lexicon  R_lexicon
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...      0.583     0.4394
# 1   [0.32672545313835144, 0.047891635447740555, 0....      0.608     0.3316
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...      0.479     0.7938
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...      0.612     0.5506
# 4   [0.11232783645391464, 0.058183617889881134, 0....      0.000     0.4340
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...      0.000     0.5502
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...      0.000     0.5124
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...      0.163     0.3758
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...      0.000     0.0000
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...      0.115     0.4128
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...      0.834     0.4794
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...      0.604     0.4810
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...      0.875     0.6024
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...      0.760     0.7378
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...      0.000     0.5090
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...      0.000     0.4732
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...      0.000     0.5018
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...      0.000     0.5502
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...      0.570     0.6616
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...      0.792     0.7016
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...      0.000     0.2560
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...      0.719     0.1438
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...      0.000     0.1408
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...      0.000     0.3350
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...      0.854     0.7492
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...      0.490     0.6448
# 26  [0.027731070294976234, 0.025310203433036804, 0...      0.000     0.1286
# 27  [0.032828718423843384, 0.01814362034201622, 0....      0.000     0.0000
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...      0.000     0.0000
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...      0.684     0.5682
# 30  [0.23603211343288422, 0.061422985047101974, 0....      0.796     0.4492
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...      0.337     0.5052
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...      0.337     0.5358
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...      0.479     0.5530
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...      0.604     0.8184
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...      0.418     0.6148
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...      0.684     0.6280
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...      0.000     0.2976
# 38  [0.188589945435524, 0.17262092232704163, 0.103...      0.531     0.4680
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...      0.458     0.5708
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...      0.188     0.4662
# 41  [0.18249012529850006, 0.133339062333107, 0.111...      0.188     0.4766
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...      0.776     0.6918
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...      0.392     0.5620
# 44  [0.040398839861154556, 0.03771699592471123, 0....      0.000     0.3526
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...      0.229     0.4152
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...      0.000     0.2306
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...      0.582     0.3204
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...      0.000     0.2642
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...      0.240     0.2410
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...      0.229     0.6146

# %% [markdown]
# Validation scores for Method 2

# %%
# Left leaning model has lower score and right leaning model (considering average) has higher score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.34419999999999995 0.46281999999999995

# %% [markdown]
# ### *Method 3 - Take top most predicted of R-leaning and average of 5 for L-leaning*

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0])
  R_top_most_scores.append(preds[0]['score'])
  R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  # print(preds[0])
  for pred in preds:
    print(f">>> {pred['sequence']}")
    # print(pred)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'}
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'}
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'}
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'}
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'}
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'}
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'}
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'}
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'}
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'}
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."}
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'}
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"}
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."}
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'}
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'}
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'}
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'}
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'}
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'}
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"}
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."}
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'}
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'}
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'}
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'}
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'}
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'}
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'}
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'}
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'}
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'}
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'}
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'}
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"}
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'}
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'}
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."}
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'}
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'}
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'}
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."}
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'}
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'}
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'}
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'}
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'}
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'}
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # L_top_most_scores.append(preds[0]['score'])
  # L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  L_top_most_scores.append(temp_score)
  L_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     L_prediction_prob R_mask_word_prediction  \
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...              delivered
# 1   [0.32672545313835144, 0.047891635447740555, 0....                 called
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...              predicted
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...                elected
# 4   [0.11232783645391464, 0.058183617889881134, 0....                    ##s
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...                    the
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...                    the
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...                  leave
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...                    the
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...                 blamed
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...               endorsed
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...                    try
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...               supports
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...                  wants
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...                      '
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...                     an
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...                     an
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...                    the
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...               extended
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...               designed
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...                  began
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...               received
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...                    who
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...                    who
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...                  power
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...                control
# 26  [0.027731070294976234, 0.025310203433036804, 0...             washington
# 27  [0.032828718423843384, 0.01814362034201622, 0....                    cnn
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...                    the
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...                  start
# 30  [0.23603211343288422, 0.061422985047101974, 0....                  close
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...                 remove
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...                 remove
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...                 moving
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...              defending
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...                  urged
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...                  makes
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...                      a
# 38  [0.188589945435524, 0.17262092232704163, 0.103...                 combat
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...                   pass
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...                opposed
# 41  [0.18249012529850006, 0.133339062333107, 0.111...                opposed
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...                   work
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...                imposed
# 44  [0.040398839861154556, 0.03771699592471123, 0....                      '
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...                 reduce
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...                biggest
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...                   more
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...                     no
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...               resigned
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...                 warned
#
#                                            R_sentence  R_prediction_prob
# 0   trump delivered the sad news on monday in the ...           0.081385
# 1   trump called the elections after the results y...           0.345033
# 2       biden predicted the victory of obama in 2012.           0.205895
# 3           trump was elected after the win of obama.           0.073294
# 4   trumps tweets as us tackles coronavirus, inclu...           0.182125
# 5   trump considering the coronavirus guidelines a...           0.115683
# 6   biden considering the coronavirus guidelines a...           0.139714
# 7   trump intends to leave country amid growing co...           0.308170
# 8   biden says he intendes to the country to preve...           0.636418
# 9   california blamed trump for medical supply sho...           0.501519
# 10  california endorsed biden irrespective of elec...           0.185824
# 11  biden says it's time for trump to try and make...           0.320775
# 12  biden supports trump after republicans block c...           0.180459
# 13  trump wants to restart the us economy because ...           0.428377
# 14  biden'new bill specially directed towards the ...           0.238731
# 15  trump administration has shown an interest in ...           0.157856
# 16  biden administration has shown an interest in ...           0.163410
# 17  trump considering the coronavirus guidelines a...           0.115683
# 18  trump extended the mask mandate after reducing...           0.086193
# 19  biden designed the mask mandate inspite of red...           0.136489
# 20  trump began unproven coronavirus treatment hou...           0.112114
# 21  biden received unproven coronavirus treatment ...           0.191253
# 22  trump's favorite hosts who are pushing him to ...           0.385283
# 23  biden's favorite hosts who are advising him to...           0.377327
# 24  the trump administration wants to protect the ...           0.389971
# 25  the biden administration wants to protect the ...           0.365333
# 26  biden begins broadcasting from washington in r...           0.032419
# 27  trump begins broadcasting from cnn in response...           0.041605
# 28  trump continues to broadcast from the inspite ...           0.912004
# 29  trump says businesses should start soon while ...           0.121417
# 30  biden says businesses should close soon due to...           0.364503
# 31  trump decided to remove his mask during the pr...           0.789817
# 32  biden decided to remove his mask during the pr...           0.726122
# 33  trump administration were moving towards banni...           0.213482
# 34  biden administration are defending the abortio...           0.476745
# 35  biden urged trump to drop the obamacare lawsui...           0.315713
# 36  biden makes his own coronavirus briefings, as ...           0.056059
# 37  republicans and trump looking to a new bill th...           0.857507
# 38  biden and his democratic administration aim to...           0.183084
# 39  president biden looking to pass an executive o...           0.461160
# 40  democrats opposed the decision by the supreme ...           0.154924
# 41  republicans opposed the decision by the suprem...           0.138513
# 42  democrats work with the lgbtq community ’ s fi...           0.198034
# 43  republican led states have imposed numerous re...           0.344023
# 44  republicans'attacks on gay and transgender com...           0.058986
# 45  democrats believe that we can reduce gun viole...           0.215526
# 46  biden and the democrats rank crime and gun vio...           0.286923
# 47  trump and the republicans maintain that there ...           0.959371
# 48  biden says that there are no greater issues th...           0.449950
# 49  trump resigned by top doctor after increasing ...           0.253001
# 50  biden warned the nation on coronavirus in a qu...           0.135900

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for word in R_top_most_predictions:
  lemmatized_word = lemmatizer.lemmatize(word)
  stemmed_word = ps.stem(word)
  lemmatized_word = stemmed_word
  if lemmatized_word not in lexicon_dictionary:
    # print(lemmatized_word)
    R_lexicon_word_valence_list.append(0)
    words_not_in_lexicon_dict.append(word)
  else:
    # print(lexicon_dictionary[lemmatized_word])
    R_lexicon_word_valence_list.append(lexicon_dictionary[lemmatized_word])

for words in L_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  L_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     L_prediction_prob R_mask_word_prediction  \
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...              delivered
# 1   [0.32672545313835144, 0.047891635447740555, 0....                 called
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...              predicted
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...                elected
# 4   [0.11232783645391464, 0.058183617889881134, 0....                    ##s
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...                    the
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...                    the
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...                  leave
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...                    the
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...                 blamed
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...               endorsed
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...                    try
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...               supports
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...                  wants
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...                      '
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...                     an
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...                     an
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...                    the
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...               extended
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...               designed
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...                  began
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...               received
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...                    who
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...                    who
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...                  power
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...                control
# 26  [0.027731070294976234, 0.025310203433036804, 0...             washington
# 27  [0.032828718423843384, 0.01814362034201622, 0....                    cnn
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...                    the
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...                  start
# 30  [0.23603211343288422, 0.061422985047101974, 0....                  close
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...                 remove
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...                 remove
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...                 moving
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...              defending
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...                  urged
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...                  makes
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...                      a
# 38  [0.188589945435524, 0.17262092232704163, 0.103...                 combat
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...                   pass
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...                opposed
# 41  [0.18249012529850006, 0.133339062333107, 0.111...                opposed
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...                   work
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...                imposed
# 44  [0.040398839861154556, 0.03771699592471123, 0....                      '
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...                 reduce
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...                biggest
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...                   more
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...                     no
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...               resigned
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...                 warned
#
#                                            R_sentence  R_prediction_prob  \
# 0   trump delivered the sad news on monday in the ...           0.081385
# 1   trump called the elections after the results y...           0.345033
# 2       biden predicted the victory of obama in 2012.           0.205895
# 3           trump was elected after the win of obama.           0.073294
# 4   trumps tweets as us tackles coronavirus, inclu...           0.182125
# 5   trump considering the coronavirus guidelines a...           0.115683
# 6   biden considering the coronavirus guidelines a...           0.139714
# 7   trump intends to leave country amid growing co...           0.308170
# 8   biden says he intendes to the country to preve...           0.636418
# 9   california blamed trump for medical supply sho...           0.501519
# 10  california endorsed biden irrespective of elec...           0.185824
# 11  biden says it's time for trump to try and make...           0.320775
# 12  biden supports trump after republicans block c...           0.180459
# 13  trump wants to restart the us economy because ...           0.428377
# 14  biden'new bill specially directed towards the ...           0.238731
# 15  trump administration has shown an interest in ...           0.157856
# 16  biden administration has shown an interest in ...           0.163410
# 17  trump considering the coronavirus guidelines a...           0.115683
# 18  trump extended the mask mandate after reducing...           0.086193
# 19  biden designed the mask mandate inspite of red...           0.136489
# 20  trump began unproven coronavirus treatment hou...           0.112114
# 21  biden received unproven coronavirus treatment ...           0.191253
# 22  trump's favorite hosts who are pushing him to ...           0.385283
# 23  biden's favorite hosts who are advising him to...           0.377327
# 24  the trump administration wants to protect the ...           0.389971
# 25  the biden administration wants to protect the ...           0.365333
# 26  biden begins broadcasting from washington in r...           0.032419
# 27  trump begins broadcasting from cnn in response...           0.041605
# 28  trump continues to broadcast from the inspite ...           0.912004
# 29  trump says businesses should start soon while ...           0.121417
# 30  biden says businesses should close soon due to...           0.364503
# 31  trump decided to remove his mask during the pr...           0.789817
# 32  biden decided to remove his mask during the pr...           0.726122
# 33  trump administration were moving towards banni...           0.213482
# 34  biden administration are defending the abortio...           0.476745
# 35  biden urged trump to drop the obamacare lawsui...           0.315713
# 36  biden makes his own coronavirus briefings, as ...           0.056059
# 37  republicans and trump looking to a new bill th...           0.857507
# 38  biden and his democratic administration aim to...           0.183084
# 39  president biden looking to pass an executive o...           0.461160
# 40  democrats opposed the decision by the supreme ...           0.154924
# 41  republicans opposed the decision by the suprem...           0.138513
# 42  democrats work with the lgbtq community ’ s fi...           0.198034
# 43  republican led states have imposed numerous re...           0.344023
# 44  republicans'attacks on gay and transgender com...           0.058986
# 45  democrats believe that we can reduce gun viole...           0.215526
# 46  biden and the democrats rank crime and gun vio...           0.286923
# 47  trump and the republicans maintain that there ...           0.959371
# 48  biden says that there are no greater issues th...           0.449950
# 49  trump resigned by top doctor after increasing ...           0.253001
# 50  biden warned the nation on coronavirus in a qu...           0.135900
#
#     L_lexicon  R_lexicon
# 0      0.4394      0.583
# 1      0.3316      0.608
# 2      0.7938      0.479
# 3      0.5506      0.612
# 4      0.4340      0.000
# 5      0.5502      0.000
# 6      0.5124      0.000
# 7      0.3758      0.163
# 8      0.0000      0.000
# 9      0.4128      0.115
# 10     0.4794      0.834
# 11     0.4810      0.604
# 12     0.6024      0.875
# 13     0.7378      0.760
# 14     0.5090      0.000
# 15     0.4732      0.000
# 16     0.5018      0.000
# 17     0.5502      0.000
# 18     0.6616      0.570
# 19     0.7016      0.792
# 20     0.2560      0.000
# 21     0.1438      0.719
# 22     0.1408      0.000
# 23     0.3350      0.000
# 24     0.7492      0.854
# 25     0.6448      0.490
# 26     0.1286      0.000
# 27     0.0000      0.000
# 28     0.0000      0.000
# 29     0.5682      0.684
# 30     0.4492      0.796
# 31     0.5052      0.337
# 32     0.5358      0.337
# 33     0.5530      0.479
# 34     0.8184      0.604
# 35     0.6148      0.418
# 36     0.6280      0.684
# 37     0.2976      0.000
# 38     0.4680      0.531
# 39     0.5708      0.458
# 40     0.4662      0.188
# 41     0.4766      0.188
# 42     0.6918      0.776
# 43     0.5620      0.392
# 44     0.3526      0.000
# 45     0.4152      0.229
# 46     0.2306      0.000
# 47     0.3204      0.582
# 48     0.2642      0.000
# 49     0.2410      0.240
# 50     0.6146      0.229

# %% [markdown]
# Validation scores for Method 3

# %%
# Left leaning model (considering average) has higher score and right leaning model has lower score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.46281999999999995 0.34419999999999995

# %% [markdown]
# ### *Method 4 - Take average of 5 for L-leaning and average of 5 for R-leaning*

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # L_top_most_scores.append(preds[0]['score'])
  # L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  L_top_most_scores.append(temp_score)
  L_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'} 5
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'} 5
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."} 5
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'} 5
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'} 5
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."} 5
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # R_top_most_scores.append(preds[0]['score'])
  # R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  R_top_most_scores.append(temp_score)
  R_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...
# 1   [0.32672545313835144, 0.047891635447740555, 0....
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...
# 4   [0.11232783645391464, 0.058183617889881134, 0....
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...
# 26  [0.027731070294976234, 0.025310203433036804, 0...
# 27  [0.032828718423843384, 0.01814362034201622, 0....
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...
# 30  [0.23603211343288422, 0.061422985047101974, 0....
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...
# 38  [0.188589945435524, 0.17262092232704163, 0.103...
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...
# 41  [0.18249012529850006, 0.133339062333107, 0.111...
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...
# 44  [0.040398839861154556, 0.03771699592471123, 0....
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for words in L_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  L_lexicon_word_valence_list.append(avg_sum/5)

for words in R_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  R_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob  L_lexicon  R_lexicon
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...     0.3270     0.4394
# 1   [0.32672545313835144, 0.047891635447740555, 0....     0.3396     0.3316
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...     0.7938     0.7938
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...     0.5704     0.5506
# 4   [0.11232783645391464, 0.058183617889881134, 0....     0.4340     0.4340
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...     0.5582     0.5502
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...     0.5582     0.5124
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...     0.3502     0.3758
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...     0.0000     0.0000
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...     0.2836     0.4128
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...     0.4794     0.4794
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...     0.5560     0.4810
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...     0.5752     0.6024
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...     0.6258     0.7378
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...     0.3882     0.5090
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...     0.4134     0.4732
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...     0.5018     0.5018
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...     0.5582     0.5502
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...     0.5832     0.6616
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...     0.7108     0.7016
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...     0.2688     0.2560
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...     0.2094     0.1438
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...     0.1408     0.1408
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...     0.3350     0.3350
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...     0.7320     0.7492
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...     0.7112     0.6448
# 26  [0.027731070294976234, 0.025310203433036804, 0...     0.0000     0.1286
# 27  [0.032828718423843384, 0.01814362034201622, 0....     0.0000     0.0000
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...     0.0000     0.0000
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...     0.5856     0.5682
# 30  [0.23603211343288422, 0.061422985047101974, 0....     0.6244     0.4492
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...     0.5358     0.5052
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...     0.5358     0.5358
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...     0.5428     0.5530
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...     0.8184     0.8184
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...     0.5494     0.6148
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...     0.6280     0.6280
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...     0.2976     0.2976
# 38  [0.188589945435524, 0.17262092232704163, 0.103...     0.5032     0.4680
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...     0.5708     0.5708
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...     0.4662     0.4662
# 41  [0.18249012529850006, 0.133339062333107, 0.111...     0.4766     0.4766
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...     0.7376     0.6918
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...     0.4854     0.5620
# 44  [0.040398839861154556, 0.03771699592471123, 0....     0.3914     0.3526
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...     0.4152     0.4152
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...     0.2306     0.2306
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...     0.2638     0.3204
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...     0.2642     0.2642
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...     0.2804     0.2410
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...     0.6146     0.6146

# %% [markdown]
# Validation scores for Method 4

# %%
# Left leaning model has lower score and right leaning model (considering average) has higher score (only slightly higher)
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.4564399999999999 0.46281999999999995

# %% [markdown]
# ### *Method 5 - Take average of 5 for L-leaning and RANK average of 5 for R-leaning*

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # L_top_most_scores.append(preds[0]['score'])
  # L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  L_top_most_scores.append(temp_score)
  L_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'} 5
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'} 5
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."} 5
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'} 5
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'} 5
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."} 5
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # R_top_most_scores.append(preds[0]['score'])
  # R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  R_top_most_scores.append(temp_score)
  R_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...
# 1   [0.32672545313835144, 0.047891635447740555, 0....
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...
# 4   [0.11232783645391464, 0.058183617889881134, 0....
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...
# 26  [0.027731070294976234, 0.025310203433036804, 0...
# 27  [0.032828718423843384, 0.01814362034201622, 0....
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...
# 30  [0.23603211343288422, 0.061422985047101974, 0....
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...
# 38  [0.188589945435524, 0.17262092232704163, 0.103...
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...
# 41  [0.18249012529850006, 0.133339062333107, 0.111...
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...
# 44  [0.040398839861154556, 0.03771699592471123, 0....
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for words in L_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  L_lexicon_word_valence_list.append(avg_sum/5)

R_lexicon_word_valence_list = []
for words in R_top_most_predictions:
  avg_sum = 0
  ranks = [1.4, 1.3, 1.2, 1.1, 1]
  for i, word in enumerate(words):
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += (lexicon_dictionary[lemmatized_word] * ranks[i])
  R_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob  L_lexicon  R_lexicon
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...     0.3270    0.51728
# 1   [0.32672545313835144, 0.047891635447740555, 0....     0.3396    0.39816
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...     0.7938    0.93754
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...     0.5704    0.64298
# 4   [0.11232783645391464, 0.058183617889881134, 0....     0.4340    0.52472
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...     0.5582    0.62984
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...     0.5582    0.59164
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...     0.3502    0.45048
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...     0.0000    0.00000
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...     0.2836    0.48726
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...     0.4794    0.59596
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...     0.5560    0.58890
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...     0.5752    0.76038
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...     0.6258    0.89130
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...     0.3882    0.62490
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...     0.4134    0.57128
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...     0.5018    0.59988
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...     0.5582    0.62984
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...     0.5832    0.80238
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...     0.7108    0.84676
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...     0.2688    0.30380
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...     0.2094    0.20132
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...     0.1408    0.14080
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...     0.3350    0.38462
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...     0.7320    0.91070
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...     0.7112    0.76252
# 26  [0.027731070294976234, 0.025310203433036804, 0...     0.0000    0.14146
# 27  [0.032828718423843384, 0.01814362034201622, 0....     0.0000    0.00000
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...     0.0000    0.00000
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...     0.5856    0.68268
# 30  [0.23603211343288422, 0.061422985047101974, 0....     0.6244    0.55646
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...     0.5358    0.60150
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...     0.5358    0.63360
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...     0.5428    0.65778
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...     0.8184    0.96846
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...     0.5494    0.72748
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...     0.6280    0.74880
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...     0.2976    0.34188
# 38  [0.188589945435524, 0.17262092232704163, 0.103...     0.5032    0.56604
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...     0.5708    0.67000
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...     0.4662    0.56368
# 41  [0.18249012529850006, 0.133339062333107, 0.111...     0.4766    0.56208
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...     0.7376    0.83740
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...     0.4854    0.66316
# 44  [0.040398839861154556, 0.03771699592471123, 0....     0.3914    0.42540
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...     0.4152    0.49450
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...     0.2306    0.26734
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...     0.2638    0.38286
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...     0.2642    0.30794
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...     0.2804    0.29370
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...     0.6146    0.74160

# %% [markdown]
# Validation scores for Method 5

# %%
# Left leaning model (considering average) has lower score and right leaning model (considering rank average) has higher score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.4564399999999999 0.5526207999999999

# %% [markdown]
# ### *Method 6 - Take RANK average of 5 for L-leaning and average of 5 for R-leaning*

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # L_top_most_scores.append(preds[0]['score'])
  # L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  L_top_most_scores.append(temp_score)
  L_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'} 5
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'} 5
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."} 5
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'} 5
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'} 5
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."} 5
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # R_top_most_scores.append(preds[0]['score'])
  # R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  R_top_most_scores.append(temp_score)
  R_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...
# 1   [0.32672545313835144, 0.047891635447740555, 0....
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...
# 4   [0.11232783645391464, 0.058183617889881134, 0....
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...
# 26  [0.027731070294976234, 0.025310203433036804, 0...
# 27  [0.032828718423843384, 0.01814362034201622, 0....
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...
# 30  [0.23603211343288422, 0.061422985047101974, 0....
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...
# 38  [0.188589945435524, 0.17262092232704163, 0.103...
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...
# 41  [0.18249012529850006, 0.133339062333107, 0.111...
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...
# 44  [0.040398839861154556, 0.03771699592471123, 0....
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for words in R_top_most_predictions:
  avg_sum = 0
  for word in words:
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += lexicon_dictionary[lemmatized_word]
  R_lexicon_word_valence_list.append(avg_sum/5)

for words in L_top_most_predictions:
  avg_sum = 0
  ranks = [1.4, 1.3, 1.2, 1.1, 1]
  for i, word in enumerate(words):
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += (lexicon_dictionary[lemmatized_word] * ranks[i])
  L_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob  L_lexicon  R_lexicon
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...    0.38384     0.4394
# 1   [0.32672545313835144, 0.047891635447740555, 0....    0.40118     0.3316
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...    0.93836     0.7938
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...    0.67268     0.5506
# 4   [0.11232783645391464, 0.058183617889881134, 0....    0.49744     0.4340
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...    0.64740     0.5502
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...    0.63984     0.5124
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...    0.40072     0.3758
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...    0.00000     0.0000
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...    0.31096     0.4128
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...    0.58004     0.4794
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...    0.66390     0.4810
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...    0.73400     0.6024
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...    0.77922     0.7378
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...    0.46310     0.5090
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...    0.47784     0.4732
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...    0.56624     0.5018
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...    0.64740     0.5502
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...    0.71214     0.6616
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...    0.84884     0.7016
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...    0.29756     0.2560
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...    0.26692     0.1438
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...    0.15488     0.1408
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...    0.36724     0.3350
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...    0.87990     0.7492
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...    0.83796     0.6448
# 26  [0.027731070294976234, 0.025310203433036804, 0...    0.00000     0.1286
# 27  [0.032828718423843384, 0.01814362034201622, 0....    0.00000     0.0000
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...    0.00000     0.0000
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...    0.71910     0.5682
# 30  [0.23603211343288422, 0.061422985047101974, 0....    0.74988     0.4492
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...    0.63360     0.5052
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...    0.63360     0.5358
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...    0.64552     0.5530
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...    0.96954     0.8184
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...    0.66208     0.6148
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...    0.75578     0.6280
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...    0.33044     0.2976
# 38  [0.188589945435524, 0.17262092232704163, 0.103...    0.60410     0.4680
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...    0.66560     0.5708
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...    0.54502     0.4662
# 41  [0.18249012529850006, 0.133339062333107, 0.111...    0.55646     0.4766
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...    0.88082     0.6918
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...    0.58656     0.5620
# 44  [0.040398839861154556, 0.03771699592471123, 0....    0.46248     0.3526
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...    0.49450     0.4152
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...    0.26734     0.2306
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...    0.32626     0.3204
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...    0.31430     0.2642
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...    0.33424     0.2410
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...    0.72096     0.6146

# %% [markdown]
# Validation scores for Method 6

# %%
# Left leaning model (considering RANK average) has higher score and right leaning model (considering average) has higher score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.5405556 0.46281999999999995

# %% [markdown]
# ### *Method 7 - Take RANK average of 5 for L-leaning and RANK average of 5 for R-leaning*

# %%
## TESTING
import numpy as np
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []

## TESTING

for prediction in validation_sentences_df['Masked Sentences']:
  inputs = tokenizer(prediction, return_tensors="np")
  token_logits = left_leaning_model(**inputs).logits
  # Find the location of [MASK] and extract its logits
  mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  mask_token_logits = token_logits[0, mask_token_index, :]
  # Pick the [MASK] candidates with the highest logits
  # We negate the array before argsort to get the largest, not the smallest, logits
  top_5_tokens = np.argsort(-mask_token_logits)[:5].tolist()

  for token in top_5_tokens:
    print(f">>> {prediction.replace(tokenizer.mask_token, tokenizer.decode([token]))}")
  # all_tokens = np.argsort(-mask_token_logits).tolist()
  print()

  # word_probability_dict = {}
  # for index, val in enumerate(mask_token_logits):
  #   word = tokenizer.decode([index])
  #   word_probability_dict[word] = val.numpy()
  # print('Prediction:', prediction)
  # print("Democrats prob. score:", word_probability_dict['democrats'])
  # print("Republicans prob. score:", word_probability_dict['republicans'])
  # print("Trump prob. score:", word_probability_dict['trump'])
  # print()
  # L_democrats_prob_score.append(word_probability_dict['democrats'])
  # L_republicans_prob_score.append(word_probability_dict['republicans'])
  # L_trump_prob_score.append(word_probability_dict['trump'])
# Out:
# >>> Trump delivered the sad news on Monday in the press briefing.
# >>> Trump told the sad news on Monday in the press briefing.
# >>> Trump said the sad news on Monday in the press briefing.
# >>> Trump shared the sad news on Monday in the press briefing.
# >>> Trump made the sad news on Monday in the press briefing.
#
# >>> Trump called the elections after the results yesterday.
# >>> Trump won the elections after the results yesterday.
# >>> Trump lost the elections after the results yesterday.
# >>> Trump entered the elections after the results yesterday.
# >>> Trump canceled the elections after the results yesterday.
#
# >>> Biden predicted the victory of Obama in 2012.
# >>> Biden praised the victory of Obama in 2012.
# >>> Biden supported the victory of Obama in 2012.
# >>> Biden celebrated the victory of Obama in 2012.
# >>> Biden after the victory of Obama in 2012.
#
# >>> Trump was reelected after the win of Obama.
# >>> Trump was elected after the win of Obama.
# >>> Trump was fired after the win of Obama.
# >>> Trump was named after the win of Obama.
# >>> Trump was released after the win of Obama.
#
# >>> Trump ##s tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Trump posted tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Trump used tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Trump made tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Trump released tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# >>> Trump considering the coronavirus guidelines amid growing economic fallout.
# >>> Trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Trump considering new coronavirus guidelines amid growing economic fallout.
# >>> Trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> Trump considering changing coronavirus guidelines amid growing economic fallout.
#
# >>> Biden considering the coronavirus guidelines amid growing economic fallout.
# >>> Biden considering new coronavirus guidelines amid growing economic fallout.
# >>> Biden considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> Biden considering changing coronavirus guidelines amid growing economic fallout.
#
# >>> Trump intends to leave country amid growing coronavirus cases.
# >>> Trump intends to exit country amid growing coronavirus cases.
# >>> Trump intends to rebuild country amid growing coronavirus cases.
# >>> Trump intends to abandon country amid growing coronavirus cases.
# >>> Trump intends to the country amid growing coronavirus cases.
#
# >>> Biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> Biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> Biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> Biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> Biden says he intendes to a country to prevent rise of coronavirus cases.
#
# >>> California blamed trump for medical supply shortages.
# >>> California criticized trump for medical supply shortages.
# >>> California fired trump for medical supply shortages.
# >>> California sued trump for medical supply shortages.
# >>> California supports trump for medical supply shortages.
#
# >>> California endorsed Biden irrespective of election outcome.
# >>> California chose Biden irrespective of election outcome.
# >>> California chooses Biden irrespective of election outcome.
# >>> California defeated Biden irrespective of election outcome.
# >>> California supports Biden irrespective of election outcome.
#
# >>> Biden says it's time for Trump to try and make it right.
# >>> Biden says it's time for Trump to go and make it right.
# >>> Biden says it's time for Trump to come and make it right.
# >>> Biden says it's time for Trump to act and make it right.
# >>> Biden says it's time for Trump to change and make it right.
#
# >>> Trump says it's time for Biden to try and make it right.
# >>> Trump says it's time for Biden to go and make it right.
# >>> Trump says it's time for Biden to come and make it right.
# >>> Trump says it's time for Biden to act and make it right.
# >>> Trump says it's time for Biden to vote and make it right.
#
# >>> Biden supports Trump after republicans block covid relief funds.
# >>> Biden supported Trump after republicans block covid relief funds.
# >>> Biden endorsed Trump after republicans block covid relief funds.
# >>> Biden opposes Trump after republicans block covid relief funds.
# >>> Biden backed Trump after republicans block covid relief funds.
#
# >>> Trump wants to restart the US economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> Trump plans to restart the US economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> Trump hopes to restart the US economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> Trump promised to restart the US economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> Trump vowed to restart the US economy because he's afraid the tanking stock market will hurt his reelection chances
#
# >>> Biden introduces new bill specially directed in light of the rising gun violence in the US.
# >>> Biden introduces new bill specially directed in recognition of the rising gun violence in the US.
# >>> Biden introduces new bill specially directed in protest of the rising gun violence in the US.
# >>> Biden introduces new bill specially directed in support of the rising gun violence in the US.
# >>> Biden introduces new bill specially directed in wake of the rising gun violence in the US.
#
# >>> Trump introduces new bill specially directed in light of the rising gun violence in the US.
# >>> Trump introduces new bill specially directed in recognition of the rising gun violence in the US.
# >>> Trump introduces new bill specially directed in support of the rising gun violence in the US.
# >>> Trump introduces new bill specially directed in protest of the rising gun violence in the US.
# >>> Trump introduces new bill specially directed in wake of the rising gun violence in the US.
#
# >>> Trump administration has shown little interest in restoring government funding for Gun violence research.
# >>> Trump administration has shown no interest in restoring government funding for Gun violence research.
# >>> Trump administration has shown an interest in restoring government funding for Gun violence research.
# >>> Trump administration has shown renewed interest in restoring government funding for Gun violence research.
# >>> Trump administration has shown strong interest in restoring government funding for Gun violence research.
#
# >>> Biden administration has shown renewed interest in restoring government funding for Gun violence research.
# >>> Biden administration has shown an interest in restoring government funding for Gun violence research.
# >>> Biden administration has shown no interest in restoring government funding for Gun violence research.
# >>> Biden administration has shown little interest in restoring government funding for Gun violence research.
# >>> Biden administration has shown strong interest in restoring government funding for Gun violence research.
#
# >>> Trump considering the coronavirus guidelines amid growing economic fallout.
# >>> Trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Trump considering new coronavirus guidelines amid growing economic fallout.
# >>> Trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> Trump considering changing coronavirus guidelines amid growing economic fallout.
#
# >>> Biden considering the coronavirus guidelines amid growing economic fallout.
# >>> Biden considering new coronavirus guidelines amid growing economic fallout.
# >>> Biden considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> Biden considering changing coronavirus guidelines amid growing economic fallout.
#
# >>> Trump extended the mask mandate after reducing coronavirus cases.
# >>> Trump expanded the mask mandate after reducing coronavirus cases.
# >>> Trump renewed the mask mandate after reducing coronavirus cases.
# >>> Trump withdrew the mask mandate after reducing coronavirus cases.
# >>> Trump lifted the mask mandate after reducing coronavirus cases.
#
# >>> Biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> Biden added the mask mandate inspite of reducing coronavirus cases.
# >>> Biden called the mask mandate inspite of reducing coronavirus cases.
# >>> Biden used the mask mandate inspite of reducing coronavirus cases.
# >>> Biden said the mask mandate inspite of reducing coronavirus cases.
#
# >>> Trump sought unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Trump began unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Trump received unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Trump took unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Trump refused unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
#
# >>> Biden received unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Biden sought unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Biden took unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Biden began unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Biden refused unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
#
# >>> Trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Trump's favorite hosts , are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Trump's favorite hosts trump are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# >>> Biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Biden's favorite hosts , are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# >>> The Trump administration wants to protect the power over the people to protect the crashing economy.
# >>> The Trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> The Trump administration wants to protect the people over the people to protect the crashing economy.
# >>> The Trump administration wants to protect the economy over the people to protect the crashing economy.
# >>> The Trump administration wants to protect the world over the people to protect the crashing economy.
#
# >>> The Biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> The Biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> The Biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> The Biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> The Biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
#
# >>> Biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> Biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> Biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> Biden begins broadcasting from washington in response to coronavirus crisis.
# >>> Biden begins broadcasting from houston in response to coronavirus crisis.
#
# >>> Trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> Trump begins broadcasting from washington in response to coronavirus crisis.
# >>> Trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> Trump begins broadcasting from nashville in response to coronavirus crisis.
# >>> Trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# >>> Trump continues to broadcast from the inspite of coronavirus crisis.
# >>> Trump continues to broadcast from this inspite of coronavirus crisis.
# >>> Trump continues to broadcast from an inspite of coronavirus crisis.
# >>> Trump continues to broadcast from every inspite of coronavirus crisis.
# >>> Trump continues to broadcast from that inspite of coronavirus crisis.
#
# >>> Trump says businesses should start soon while fighting coronavirus.
# >>> Trump says businesses should close soon while fighting coronavirus.
# >>> Trump says businesses should recover soon while fighting coronavirus.
# >>> Trump says businesses should open soon while fighting coronavirus.
# >>> Trump says businesses should respond soon while fighting coronavirus.
#
# >>> Biden says businesses should close soon due to rising covid cases.
# >>> Biden says businesses should move soon due to rising covid cases.
# >>> Biden says businesses should recover soon due to rising covid cases.
# >>> Biden says businesses should disappear soon due to rising covid cases.
# >>> Biden says businesses should return soon due to rising covid cases.
#
# >>> Trump decided to remove his mask during the press conference.
# >>> Trump decided to wear his mask during the press conference.
# >>> Trump decided to drop his mask during the press conference.
# >>> Trump decided to don his mask during the press conference.
# >>> Trump decided to change his mask during the press conference.
#
# >>> Biden decided to remove his mask during the press conference.
# >>> Biden decided to wear his mask during the press conference.
# >>> Biden decided to don his mask during the press conference.
# >>> Biden decided to drop his mask during the press conference.
# >>> Biden decided to change his mask during the press conference.
#
# >>> Trump administration were moving towards banning abortion in states across the US.
# >>> Trump administration were pushing towards banning abortion in states across the US.
# >>> Trump administration were working towards banning abortion in states across the US.
# >>> Trump administration were pushed towards banning abortion in states across the US.
# >>> Trump administration were leaning towards banning abortion in states across the US.
#
# >>> Biden administration are defending the abortion rights of the democratic states.
# >>> Biden administration are protecting the abortion rights of the democratic states.
# >>> Biden administration are promoting the abortion rights of the democratic states.
# >>> Biden administration are supporting the abortion rights of the democratic states.
# >>> Biden administration are advancing the abortion rights of the democratic states.
#
# >>> Biden urged Trump to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Biden asked Trump to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Biden convinced Trump to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Biden urges Trump to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Biden and Trump to drop the ObamaCare lawsuit amid growing coronavirus crisis
#
# >>> Biden hosts his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Biden conducts his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Biden attends his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Biden holds his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Biden makes his own coronavirus briefings, as he fights to return from 'sideline'
#
# >>> Republicans and Trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> Republicans and Trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> Republicans and Trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> Republicans and Trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> Republicans and Trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# >>> Biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# >>> President Biden looking to pass an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> President Biden looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> President Biden looking to implement an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> President Biden looking to get an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> President Biden looking to sign an Executive Order on securing access to Abortion and to defend women's fundamental rights.
#
# >>> Trump looking to pass an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Trump looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Trump looking to implement an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Trump looking to get an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Trump looking to sign an Executive Order on securing access to Abortion and to defend women's fundamental rights.
#
# >>> Democrats opposed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats oppose the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats challenged the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats appealed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats supported the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
#
# >>> Republicans challenged the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans opposed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans oppose the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans overturned the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans appealed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
#
# >>> Democrats work with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats deal with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats continue with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats identify with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats collaborate with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
#
# >>> Republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have lifted numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# >>> Democrat led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have lifted numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# >>> Republicans ' attacks on gay and transgender community.
# >>> Republicans make attacks on gay and transgender community.
# >>> Republicans include attacks on gay and transgender community.
# >>> Republicans hate attacks on gay and transgender community.
# >>> Republicans in attacks on gay and transgender community.
#
# >>> Democrats believe that we should end gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should curb gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should prevent gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should reduce gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should stop gun violence while respecting the rights of responsible gun owners.
#
# >>> Republicans believe that we should end gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should curb gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should prevent gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should stop gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should reduce gun violence while respecting the rights of responsible gun owners.
#
# >>> Biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> Biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> Biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
# >>> Biden and the democrats rank crime and gun violence as one of the greatest issues in the country.
# >>> Biden and the democrats rank crime and gun violence as one of the major issues in the country.
#
# >>> Trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> Trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> Trump and the republicans maintain that there are other pressing issues than gun violence.
# >>> Trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> Trump and the republicans maintain that there are bigger pressing issues than gun violence.
#
# >>> Biden says that there are no greater issues than gun violence.
# >>> Biden says that there are many greater issues than gun violence.
# >>> Biden says that there are even greater issues than gun violence.
# >>> Biden says that there are far greater issues than gun violence.
# >>> Biden says that there are much greater issues than gun violence.
#
# >>> Trump resigned by top doctor after increasing false claims over Twitter.
# >>> Trump won by top doctor after increasing false claims over Twitter.
# >>> Trump responded by top doctor after increasing false claims over Twitter.
# >>> Trump voted by top doctor after increasing false claims over Twitter.
# >>> Trump declined by top doctor after increasing false claims over Twitter.
#
# >>> Biden warned the nation on coronavirus in a quickly-constructed home studio
# >>> Biden advised the nation on coronavirus in a quickly-constructed home studio
# >>> Biden addressed the nation on coronavirus in a quickly-constructed home studio
# >>> Biden addresses the nation on coronavirus in a quickly-constructed home studio
# >>> Biden represented the nation on coronavirus in a quickly-constructed home studio

# %%
import numpy as np

## TESTING

for prediction in validation_sentences_df['Masked Sentences']:
  inputs = tokenizer(prediction, return_tensors="np")
  token_logits = left_leaning_model(**inputs).logits
  # Find the location of [MASK] and extract its logits
  mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  mask_token_logits = token_logits[0, mask_token_index, :]
  # Pick the [MASK] candidates with the highest logits
  # We negate the array before argsort to get the largest, not the smallest, logits
  top_5_tokens = np.argsort(-mask_token_logits)[:5].tolist()

  for token in top_5_tokens:
    print(f">>> {prediction.replace(tokenizer.mask_token, tokenizer.decode([token]))}")

  print()
# Out:
# >>> Republicans shared the sad news on Monday in the press briefing.
# >>> Republicans broke the sad news on Monday in the press briefing.
# >>> Republicans delivered the sad news on Monday in the press briefing.
# >>> Republicans welcomed the sad news on Monday in the press briefing.
# >>> Republicans repeated the sad news on Monday in the press briefing.
#
# >>> Republicans won the elections after the results yesterday.
# >>> Republicans entered the elections after the results yesterday.
# >>> Republicans lost the elections after the results yesterday.
# >>> Republicans called the elections after the results yesterday.
# >>> Republicans dominated the elections after the results yesterday.
#
# >>> Democrats support the victory of Obama in 2012.
# >>> Democrats supported the victory of Obama in 2012.
# >>> Democrats recognize the victory of Obama in 2012.
# >>> Democrats predicted the victory of Obama in 2012.
# >>> Democrats praised the victory of Obama in 2012.
#
# >>> Republicans was formed after the win of Obama.
# >>> Republicans was elected after the win of Obama.
# >>> Republicans was added after the win of Obama.
# >>> Republicans was founded after the win of Obama.
# >>> Republicans was dissolved after the win of Obama.
#
# >>> Republicans remove tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Republicans send tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Republicans posted tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Republicans continue tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> Republicans use tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# >>> Republicans considering the coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering changing coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering extending coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering new coronavirus guidelines amid growing economic fallout.
#
# >>> Democrats considering changing coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering the coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering extending coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering adopting coronavirus guidelines amid growing economic fallout.
#
# >>> Republicans intends to leave country amid growing coronavirus cases.
# >>> Republicans intends to exit country amid growing coronavirus cases.
# >>> Republicans intends to flee country amid growing coronavirus cases.
# >>> Republicans intends to abandon country amid growing coronavirus cases.
# >>> Republicans intends to the country amid growing coronavirus cases.
#
# >>> Democrats says he intendes to the country to prevent rise of coronavirus cases.
# >>> Democrats says he intendes to this country to prevent rise of coronavirus cases.
# >>> Democrats says he intendes to another country to prevent rise of coronavirus cases.
# >>> Democrats says he intendes to his country to prevent rise of coronavirus cases.
# >>> Democrats says he intendes to a country to prevent rise of coronavirus cases.
#
# >>> California blamed Republicans for medical supply shortages.
# >>> California criticized Republicans for medical supply shortages.
# >>> California blame Republicans for medical supply shortages.
# >>> California blaming Republicans for medical supply shortages.
# >>> California supports Republicans for medical supply shortages.
#
# >>> California house Democrats irrespective of election outcome.
# >>> California registered Democrats irrespective of election outcome.
# >>> California senate Democrats irrespective of election outcome.
# >>> California and Democrats irrespective of election outcome.
# >>> California . Democrats irrespective of election outcome.
#
# >>> Democrats plan to damage the US economy due to rising covid cases.
# >>> Democrats plan to cut the US economy due to rising covid cases.
# >>> Democrats plan to harm the US economy due to rising covid cases.
# >>> Democrats plan to boost the US economy due to rising covid cases.
# >>> Democrats plan to stabilize the US economy due to rising covid cases.
#
# >>> Republicans plan to damage the US economy due to rising covid cases.
# >>> Republicans plan to cut the US economy due to rising covid cases.
# >>> Republicans plan to boost the US economy due to rising covid cases.
# >>> Republicans plan to harm the US economy due to rising covid cases.
# >>> Republicans plan to stabilize the US economy due to rising covid cases.
#
# >>> Democrats introduces new bill specially directed in light of the rising gun violence in the US.
# >>> Democrats introduces new bill specially directed in recognition of the rising gun violence in the US.
# >>> Democrats introduces new bill specially directed in support of the rising gun violence in the US.
# >>> Democrats introduces new bill specially directed in response of the rising gun violence in the US.
# >>> Democrats introduces new bill specially directed in protest of the rising gun violence in the US.
#
# >>> Republicans introduces new bill specially directed in light of the rising gun violence in the US.
# >>> Republicans introduces new bill specially directed in recognition of the rising gun violence in the US.
# >>> Republicans introduces new bill specially directed in support of the rising gun violence in the US.
# >>> Republicans introduces new bill specially directed in protest of the rising gun violence in the US.
# >>> Republicans introduces new bill specially directed in response of the rising gun violence in the US.
#
# >>> Republicans administration has shown little interest in restoring government funding for Gun violence research.
# >>> Republicans administration has shown no interest in restoring government funding for Gun violence research.
# >>> Republicans administration has shown an interest in restoring government funding for Gun violence research.
# >>> Republicans administration has shown renewed interest in restoring government funding for Gun violence research.
# >>> Republicans administration has shown strong interest in restoring government funding for Gun violence research.
#
# >>> Democrats administration has shown little interest in restoring government funding for Gun violence research.
# >>> Democrats administration has shown no interest in restoring government funding for Gun violence research.
# >>> Democrats administration has shown an interest in restoring government funding for Gun violence research.
# >>> Democrats administration has shown renewed interest in restoring government funding for Gun violence research.
# >>> Democrats administration has shown strong interest in restoring government funding for Gun violence research.
#
# >>> Republicans considering the coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering changing coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering extending coronavirus guidelines amid growing economic fallout.
# >>> Republicans considering new coronavirus guidelines amid growing economic fallout.
#
# >>> Democrats considering changing coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering expanding coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering the coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering extending coronavirus guidelines amid growing economic fallout.
# >>> Democrats considering adopting coronavirus guidelines amid growing economic fallout.
#
# >>> Republicans extended the mask mandate after reducing coronavirus cases.
# >>> Republicans dropped the mask mandate after reducing coronavirus cases.
# >>> Republicans withdrew the mask mandate after reducing coronavirus cases.
# >>> Republicans lifted the mask mandate after reducing coronavirus cases.
# >>> Republicans extend the mask mandate after reducing coronavirus cases.
#
# >>> Democrats use the mask mandate inspite of reducing coronavirus cases.
# >>> Democrats called the mask mandate inspite of reducing coronavirus cases.
# >>> Democrats used the mask mandate inspite of reducing coronavirus cases.
# >>> Democrats cut the mask mandate inspite of reducing coronavirus cases.
# >>> Democrats removed the mask mandate inspite of reducing coronavirus cases.
#
# >>> Republicans began unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Republicans sought unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Republicans took unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Republicans refused unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Republicans received unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
#
# >>> Democrats began unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Democrats sought unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Democrats took unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Democrats received unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# >>> Democrats refused unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
#
# >>> Republicans's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Republicans's favorite hosts , are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Republicans's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Republicans's favorite hosts trump are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> Republicans's favorite hosts and are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# >>> Democrats's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Democrats's favorite hosts , are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Democrats's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Democrats's favorite hosts that are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> Democrats's favorite hosts also are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# >>> The Republicans administration wants to protect the power over the people to protect the crashing economy.
# >>> The Republicans administration wants to protect the authority over the people to protect the crashing economy.
# >>> The Republicans administration wants to protect the people over the people to protect the crashing economy.
# >>> The Republicans administration wants to protect the economy over the people to protect the crashing economy.
# >>> The Republicans administration wants to protect the government over the people to protect the crashing economy.
#
# >>> The Democrats administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> The Democrats administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> The Democrats administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> The Democrats administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> The Democrats administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
#
# >>> Democrats begins broadcasting from atlanta in response to coronavirus crisis.
# >>> Democrats begins broadcasting from washington in response to coronavirus crisis.
# >>> Democrats begins broadcasting from cnn in response to coronavirus crisis.
# >>> Democrats begins broadcasting from campus in response to coronavirus crisis.
# >>> Democrats begins broadcasting from philadelphia in response to coronavirus crisis.
#
# >>> Republicans begins broadcasting from washington in response to coronavirus crisis.
# >>> Republicans begins broadcasting from cnn in response to coronavirus crisis.
# >>> Republicans begins broadcasting from atlanta in response to coronavirus crisis.
# >>> Republicans begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> Republicans begins broadcasting from campus in response to coronavirus crisis.
#
# >>> Republicans continues to broadcast from the inspite of coronavirus crisis.
# >>> Republicans continues to broadcast from this inspite of coronavirus crisis.
# >>> Republicans continues to broadcast from an inspite of coronavirus crisis.
# >>> Republicans continues to broadcast from every inspite of coronavirus crisis.
# >>> Republicans continues to broadcast from that inspite of coronavirus crisis.
#
# >>> Republicans says businesses should close soon while fighting coronavirus.
# >>> Republicans says businesses should start soon while fighting coronavirus.
# >>> Republicans says businesses should open soon while fighting coronavirus.
# >>> Republicans says businesses should recover soon while fighting coronavirus.
# >>> Republicans says businesses should be soon while fighting coronavirus.
#
# >>> Democrats says businesses should close soon due to rising covid cases.
# >>> Democrats says businesses should open soon due to rising covid cases.
# >>> Democrats says businesses should move soon due to rising covid cases.
# >>> Democrats says businesses should recover soon due to rising covid cases.
# >>> Democrats says businesses should grow soon due to rising covid cases.
#
# >>> Republicans decided to remove their mask during the press conference.
# >>> Republicans decided to wear their mask during the press conference.
# >>> Republicans decided to drop their mask during the press conference.
# >>> Republicans decided to change their mask during the press conference.
# >>> Republicans decided to lift their mask during the press conference.
#
# >>> Democrats decided to remove their mask during the press conference.
# >>> Democrats decided to wear their mask during the press conference.
# >>> Democrats decided to drop their mask during the press conference.
# >>> Democrats decided to change their mask during the press conference.
# >>> Democrats decided to lift their mask during the press conference.
#
# >>> Republicans administration were moving towards banning abortion in states across the US.
# >>> Republicans administration were pushing towards banning abortion in states across the US.
# >>> Republicans administration were working towards banning abortion in states across the US.
# >>> Republicans administration were leaning towards banning abortion in states across the US.
# >>> Republicans administration were pushed towards banning abortion in states across the US.
#
# >>> Democrats administration are defending the abortion rights of the democratic states.
# >>> Democrats administration are protecting the abortion rights of the democratic states.
# >>> Democrats administration are promoting the abortion rights of the democratic states.
# >>> Democrats administration are supporting the abortion rights of the democratic states.
# >>> Democrats administration are advancing the abortion rights of the democratic states.
#
# >>> Democrats voted to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Democrats vote to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Democrats seek to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Democrats chose to drop the ObamaCare lawsuit amid growing coronavirus crisis
# >>> Democrats pledged to drop the ObamaCare lawsuit amid growing coronavirus crisis
#
# >>> Democrats hold his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Democrats attend his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Democrats run his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Democrats in his own coronavirus briefings, as he fights to return from 'sideline'
# >>> Democrats conduct his own coronavirus briefings, as he fights to return from 'sideline'
#
# >>> Republicans looking to a new bill that would increase production of firearms to licensed americans.
# >>> Republicans looking to the new bill that would increase production of firearms to licensed americans.
# >>> Republicans looking to pass new bill that would increase production of firearms to licensed americans.
# >>> Republicans looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> Republicans looking to draft new bill that would increase production of firearms to licensed americans.
#
# >>> Democrats and their administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Democrats and their administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Democrats and their administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Democrats and their administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> Democrats and their administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# >>> Democrats looking to pass an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Democrats looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Democrats looking to get an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Democrats looking to implement an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Democrats looking to sign an Executive Order on securing access to Abortion and to defend women's fundamental rights.
#
# >>> Republicans looking to pass an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Republicans looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Republicans looking to get an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Republicans looking to implement an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# >>> Republicans looking to sign an Executive Order on securing access to Abortion and to defend women's fundamental rights.
#
# >>> Democrats opposed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats oppose the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats challenged the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats appealed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Democrats supported the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
#
# >>> Republicans challenged the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans opposed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans oppose the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans overturned the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# >>> Republicans appealed the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
#
# >>> Democrats work with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats deal with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats continue with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats identify with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# >>> Democrats collaborate with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
#
# >>> Republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Republican led states have lifted numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# >>> Democrat led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> Democrat led states have lifted numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# >>> Republicans ' attacks on gay and transgender community.
# >>> Republicans make attacks on gay and transgender community.
# >>> Republicans include attacks on gay and transgender community.
# >>> Republicans hate attacks on gay and transgender community.
# >>> Republicans in attacks on gay and transgender community.
#
# >>> Democrats believe that we should end gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should curb gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should prevent gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should reduce gun violence while respecting the rights of responsible gun owners.
# >>> Democrats believe that we should stop gun violence while respecting the rights of responsible gun owners.
#
# >>> Republicans believe that we should end gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should curb gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should prevent gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should stop gun violence while respecting the rights of responsible gun owners.
# >>> Republicans believe that we should reduce gun violence while respecting the rights of responsible gun owners.
#
# >>> Democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> Democrats rank crime and gun violence as one of the worst issues in the country.
# >>> Democrats rank crime and gun violence as one of the major issues in the country.
# >>> Democrats rank crime and gun violence as one of the hardest issues in the country.
# >>> Democrats rank crime and gun violence as one of the key issues in the country.
#
# >>> Republicans maintain that there are more pressing issues than gun violence.
# >>> Republicans maintain that there are less pressing issues than gun violence.
# >>> Republicans maintain that there are fewer pressing issues than gun violence.
# >>> Republicans maintain that there are bigger pressing issues than gun violence.
# >>> Republicans maintain that there are other pressing issues than gun violence.
#
# >>> Democrats says that there are no greater issues than gun violence.
# >>> Democrats says that there are even greater issues than gun violence.
# >>> Democrats says that there are far greater issues than gun violence.
# >>> Democrats says that there are many greater issues than gun violence.
# >>> Democrats says that there are still greater issues than gun violence.
#
# >>> Republicans won by top doctor after increasing false claims over Twitter.
# >>> Republicans voted by top doctor after increasing false claims over Twitter.
# >>> Republicans responded by top doctor after increasing false claims over Twitter.
# >>> Republicans resigned by top doctor after increasing false claims over Twitter.
# >>> Republicans led by top doctor after increasing false claims over Twitter.
#
# >>> Democrats lead the nation on coronavirus in a quickly-constructed home studio
# >>> Democrats warned the nation on coronavirus in a quickly-constructed home studio
# >>> Democrats of the nation on coronavirus in a quickly-constructed home studio
# >>> Democrats educate the nation on coronavirus in a quickly-constructed home studio
# >>> Democrats led the nation on coronavirus in a quickly-constructed home studio

# %%
L_top_most_scores = []
L_top_most_predictions = []
L_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = L_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # L_top_most_scores.append(preds[0]['score'])
  # L_top_most_predictions.append(preds[0]['token_str'])
  L_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  L_top_most_scores.append(temp_score)
  L_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.08138512074947357, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump said the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
#
# {'score': 0.34503334760665894, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump lost the elections after the results yesterday.
# >>> trump named the elections after the results yesterday.
#
# {'score': 0.20589497685432434, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
#
# {'score': 0.07329434156417847, 'token': 2700, 'token_str': 'elected', 'sequence': 'trump was elected after the win of obama.'} 5
# >>> trump was elected after the win of obama.
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was released after the win of obama.
#
# {'score': 0.18212540447711945, 'token': 2015, 'token_str': '##s', 'sequence': 'trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump has tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.13971394300460815, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering expanding coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.30816951394081116, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to the country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
#
# {'score': 0.6364176869392395, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
#
# {'score': 0.5015187859535217, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
# >>> california fired trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
#
# {'score': 0.185824453830719, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.32077473402023315, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to vote and make it right.
#
# {'score': 0.1804586797952652, 'token': 6753, 'token_str': 'supports', 'sequence': 'biden supports trump after republicans block covid relief funds.'} 5
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden defeated trump after republicans block covid relief funds.
#
# {'score': 0.428376704454422, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump has to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.23873110115528107, 'token': 1005, 'token_str': "'", 'sequence': "biden'new bill specially directed towards the rising gun violence in the us."} 5
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden a new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.157856285572052, 'token': 2019, 'token_str': 'an', 'sequence': 'trump administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown little interest in restoring government funding for gun violence research.
#
# {'score': 0.16340991854667664, 'token': 2019, 'token_str': 'an', 'sequence': 'biden administration has shown an interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.11568285524845123, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08619348704814911, 'token': 3668, 'token_str': 'extended', 'sequence': 'trump extended the mask mandate after reducing coronavirus cases.'} 5
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump removed the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.13648876547813416, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden used the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.1121138334274292, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump requested unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.19125279784202576, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.38528311252593994, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts that are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts often are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.37732696533203125, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts often are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.38997113704681396, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the control over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the right over the people to protect the crashing economy.
#
# {'score': 0.36533260345458984, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the influence over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the power over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.03241858258843422, 'token': 2899, 'token_str': 'washington', 'sequence': 'biden begins broadcasting from washington in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from washington in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> biden begins broadcasting from atlanta in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
#
# {'score': 0.041604600846767426, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from atlanta in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
# >>> trump begins broadcasting from california in response to coronavirus crisis.
#
# {'score': 0.9120039939880371, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
#
# {'score': 0.12141679972410202, 'token': 2707, 'token_str': 'start', 'sequence': 'trump says businesses should start soon while fighting coronavirus.'} 5
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should open soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
#
# {'score': 0.36450302600860596, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should open soon due to rising covid cases.
# >>> biden says businesses should return soon due to rising covid cases.
#
# {'score': 0.7898169755935669, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to don his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
#
# {'score': 0.7261218428611755, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.21348243951797485, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were leaning towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
#
# {'score': 0.47674453258514404, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
#
# {'score': 0.31571298837661743, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden urges trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.05605851486325264, 'token': 3084, 'token_str': 'makes', 'sequence': "biden makes his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8575072288513184, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.18308378756046295, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stem the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.46116048097610474, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.15492363274097443, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.13851293921470642, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19803355634212494, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats engage with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3440225422382355, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have removed numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.05898619443178177, 'token': 1005, 'token_str': "'", 'sequence': "republicans'attacks on gay and transgender community."} 5
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans make attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.21552608907222748, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.28692349791526794, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9593712687492371, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are other pressing issues than gun violence.
#
# {'score': 0.44995036721229553, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
#
# {'score': 0.253000944852829, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump replaced by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
#
# {'score': 0.1359003335237503, 'token': 7420, 'token_str': 'warned', 'sequence': 'biden warned the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
R_top_most_scores = []
R_top_most_predictions = []
R_top_most_sentences = []
for prediction in validation_sentences_df['Masked Sentences']:
  preds = R_mask_filler(prediction)
  print(preds[0], len(preds))
  temp_score = []
  temp_prediction = []
  # R_top_most_scores.append(preds[0]['score'])
  # R_top_most_predictions.append(preds[0]['token_str'])
  R_top_most_sentences.append(preds[0]['sequence'])

  for pred in preds:
    temp_score.append(pred['score'])
    temp_prediction.append(pred['token_str'])

    print(f">>> {pred['sequence']}")
    # print(pred)
  R_top_most_scores.append(temp_score)
  R_top_most_predictions.append(temp_prediction)
  print()
# Out:
# {'score': 0.07356075942516327, 'token': 5359, 'token_str': 'delivered', 'sequence': 'trump delivered the sad news on monday in the press briefing.'} 5
# >>> trump delivered the sad news on monday in the press briefing.
# >>> trump told the sad news on monday in the press briefing.
# >>> trump addressed the sad news on monday in the press briefing.
# >>> trump described the sad news on monday in the press briefing.
# >>> trump mentioned the sad news on monday in the press briefing.
#
# {'score': 0.32672545313835144, 'token': 2170, 'token_str': 'called', 'sequence': 'trump called the elections after the results yesterday.'} 5
# >>> trump called the elections after the results yesterday.
# >>> trump canceled the elections after the results yesterday.
# >>> trump won the elections after the results yesterday.
# >>> trump cancelled the elections after the results yesterday.
# >>> trump announced the elections after the results yesterday.
#
# {'score': 0.2542664706707001, 'token': 10173, 'token_str': 'predicted', 'sequence': 'biden predicted the victory of obama in 2012.'} 5
# >>> biden predicted the victory of obama in 2012.
# >>> biden supported the victory of obama in 2012.
# >>> biden praised the victory of obama in 2012.
# >>> biden endorsed the victory of obama in 2012.
# >>> biden supports the victory of obama in 2012.
#
# {'score': 0.06306461989879608, 'token': 20847, 'token_str': 'reelected', 'sequence': 'trump was reelected after the win of obama.'} 5
# >>> trump was reelected after the win of obama.
# >>> trump was fired after the win of obama.
# >>> trump was elected after the win of obama.
# >>> trump was named after the win of obama.
# >>> trump was appointed after the win of obama.
#
# {'score': 0.11232783645391464, 'token': 6866, 'token_str': 'posted', 'sequence': 'trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread'} 5
# >>> trump posted tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trumps tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump used tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump released tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# >>> trump made tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.11761776357889175, 'token': 1996, 'token_str': 'the', 'sequence': 'biden considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> biden considering the coronavirus guidelines amid growing economic fallout.
# >>> biden considering implementing coronavirus guidelines amid growing economic fallout.
# >>> biden considering adopting coronavirus guidelines amid growing economic fallout.
# >>> biden considering new coronavirus guidelines amid growing economic fallout.
# >>> biden considering changing coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.33007100224494934, 'token': 2681, 'token_str': 'leave', 'sequence': 'trump intends to leave country amid growing coronavirus cases.'} 5
# >>> trump intends to leave country amid growing coronavirus cases.
# >>> trump intends to reform country amid growing coronavirus cases.
# >>> trump intends to exit country amid growing coronavirus cases.
# >>> trump intends to rebuild country amid growing coronavirus cases.
# >>> trump intends to abandon country amid growing coronavirus cases.
#
# {'score': 0.46060705184936523, 'token': 1996, 'token_str': 'the', 'sequence': 'biden says he intendes to the country to prevent rise of coronavirus cases.'} 5
# >>> biden says he intendes to the country to prevent rise of coronavirus cases.
# >>> biden says he intendes to another country to prevent rise of coronavirus cases.
# >>> biden says he intendes to this country to prevent rise of coronavirus cases.
# >>> biden says he intendes to his country to prevent rise of coronavirus cases.
# >>> biden says he intendes to a country to prevent rise of coronavirus cases.
#
# {'score': 0.49254390597343445, 'token': 11248, 'token_str': 'blamed', 'sequence': 'california blamed trump for medical supply shortages.'} 5
# >>> california blamed trump for medical supply shortages.
# >>> california criticized trump for medical supply shortages.
# >>> california endorsed trump for medical supply shortages.
# >>> california supports trump for medical supply shortages.
# >>> california sued trump for medical supply shortages.
#
# {'score': 0.0945819765329361, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'california endorsed biden irrespective of election outcome.'} 5
# >>> california endorsed biden irrespective of election outcome.
# >>> california represents biden irrespective of election outcome.
# >>> california chose biden irrespective of election outcome.
# >>> california defeated biden irrespective of election outcome.
# >>> california nominated biden irrespective of election outcome.
#
# {'score': 0.21682237088680267, 'token': 3046, 'token_str': 'try', 'sequence': "biden says it's time for trump to try and make it right."} 5
# >>> biden says it's time for trump to try and make it right.
# >>> biden says it's time for trump to go and make it right.
# >>> biden says it's time for trump to intervene and make it right.
# >>> biden says it's time for trump to come and make it right.
# >>> biden says it's time for trump to resign and make it right.
#
# {'score': 0.34109559655189514, 'token': 11763, 'token_str': 'endorsed', 'sequence': 'biden endorsed trump after republicans block covid relief funds.'} 5
# >>> biden endorsed trump after republicans block covid relief funds.
# >>> biden supported trump after republicans block covid relief funds.
# >>> biden supports trump after republicans block covid relief funds.
# >>> biden opposes trump after republicans block covid relief funds.
# >>> biden criticized trump after republicans block covid relief funds.
#
# {'score': 0.4751662611961365, 'token': 4122, 'token_str': 'wants', 'sequence': "trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances"} 5
# >>> trump wants to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump promised to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump hopes to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump plans to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
# >>> trump vowed to restart the us economy because he's afraid the tanking stock market will hurt his reelection chances
#
# {'score': 0.41499513387680054, 'token': 3107, 'token_str': 'introduced', 'sequence': 'biden introduced new bill specially directed towards the rising gun violence in the us.'} 5
# >>> biden introduced new bill specially directed towards the rising gun violence in the us.
# >>> biden sponsored new bill specially directed towards the rising gun violence in the us.
# >>> biden signed new bill specially directed towards the rising gun violence in the us.
# >>> biden'new bill specially directed towards the rising gun violence in the us.
# >>> biden proposed new bill specially directed towards the rising gun violence in the us.
#
# {'score': 0.16109494864940643, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> trump administration has shown renewed interest in restoring government funding for gun violence research.
# >>> trump administration has shown an interest in restoring government funding for gun violence research.
# >>> trump administration has shown strong interest in restoring government funding for gun violence research.
# >>> trump administration has shown no interest in restoring government funding for gun violence research.
# >>> trump administration has shown increasing interest in restoring government funding for gun violence research.
#
# {'score': 0.19267551600933075, 'token': 9100, 'token_str': 'renewed', 'sequence': 'biden administration has shown renewed interest in restoring government funding for gun violence research.'} 5
# >>> biden administration has shown renewed interest in restoring government funding for gun violence research.
# >>> biden administration has shown an interest in restoring government funding for gun violence research.
# >>> biden administration has shown strong interest in restoring government funding for gun violence research.
# >>> biden administration has shown no interest in restoring government funding for gun violence research.
# >>> biden administration has shown significant interest in restoring government funding for gun violence research.
#
# {'score': 0.09981061518192291, 'token': 1996, 'token_str': 'the', 'sequence': 'trump considering the coronavirus guidelines amid growing economic fallout.'} 5
# >>> trump considering the coronavirus guidelines amid growing economic fallout.
# >>> trump considering implementing coronavirus guidelines amid growing economic fallout.
# >>> trump considering adopting coronavirus guidelines amid growing economic fallout.
# >>> trump considering expanding coronavirus guidelines amid growing economic fallout.
# >>> trump considering new coronavirus guidelines amid growing economic fallout.
#
# {'score': 0.08253582566976547, 'token': 9100, 'token_str': 'renewed', 'sequence': 'trump renewed the mask mandate after reducing coronavirus cases.'} 5
# >>> trump renewed the mask mandate after reducing coronavirus cases.
# >>> trump extended the mask mandate after reducing coronavirus cases.
# >>> trump expanded the mask mandate after reducing coronavirus cases.
# >>> trump reinstated the mask mandate after reducing coronavirus cases.
# >>> trump dropped the mask mandate after reducing coronavirus cases.
#
# {'score': 0.17404693365097046, 'token': 2881, 'token_str': 'designed', 'sequence': 'biden designed the mask mandate inspite of reducing coronavirus cases.'} 5
# >>> biden designed the mask mandate inspite of reducing coronavirus cases.
# >>> biden created the mask mandate inspite of reducing coronavirus cases.
# >>> biden added the mask mandate inspite of reducing coronavirus cases.
# >>> biden called the mask mandate inspite of reducing coronavirus cases.
# >>> biden expanded the mask mandate inspite of reducing coronavirus cases.
#
# {'score': 0.09098333865404129, 'token': 2211, 'token_str': 'began', 'sequence': 'trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> trump began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump discontinued unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> trump declined unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.22917234897613525, 'token': 2363, 'token_str': 'received', 'sequence': 'biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.'} 5
# >>> biden received unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden began unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden sought unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden underwent unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# >>> biden took unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
#
# {'score': 0.3475826382637024, 'token': 2040, 'token_str': 'who', 'sequence': "trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic"} 5
# >>> trump's favorite hosts who are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts, are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts'are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts reportedly are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# >>> trump's favorite hosts may are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
#
# {'score': 0.3192075192928314, 'token': 2040, 'token_str': 'who', 'sequence': "biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic."} 5
# >>> biden's favorite hosts who are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts, are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts today are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts personally are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# >>> biden's favorite hosts'are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
#
# {'score': 0.23804284632205963, 'token': 2373, 'token_str': 'power', 'sequence': 'the trump administration wants to protect the power over the people to protect the crashing economy.'} 5
# >>> the trump administration wants to protect the power over the people to protect the crashing economy.
# >>> the trump administration wants to protect the authority over the people to protect the crashing economy.
# >>> the trump administration wants to protect the state over the people to protect the crashing economy.
# >>> the trump administration wants to protect the sovereignty over the people to protect the crashing economy.
# >>> the trump administration wants to protect the economy over the people to protect the crashing economy.
#
# {'score': 0.12790729105472565, 'token': 2491, 'token_str': 'control', 'sequence': 'the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.'} 5
# >>> the biden administration wants to protect the control over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the environment over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the state over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the economy over the economy by increasing the coronavirus prevention measures.
# >>> the biden administration wants to protect the authority over the economy by increasing the coronavirus prevention measures.
#
# {'score': 0.027731070294976234, 'token': 5631, 'token_str': 'miami', 'sequence': 'biden begins broadcasting from miami in response to coronavirus crisis.'} 5
# >>> biden begins broadcasting from miami in response to coronavirus crisis.
# >>> biden begins broadcasting from seattle in response to coronavirus crisis.
# >>> biden begins broadcasting from chicago in response to coronavirus crisis.
# >>> biden begins broadcasting from boston in response to coronavirus crisis.
# >>> biden begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.032828718423843384, 'token': 13229, 'token_str': 'cnn', 'sequence': 'trump begins broadcasting from cnn in response to coronavirus crisis.'} 5
# >>> trump begins broadcasting from cnn in response to coronavirus crisis.
# >>> trump begins broadcasting from washington in response to coronavirus crisis.
# >>> trump begins broadcasting from twitter in response to coronavirus crisis.
# >>> trump begins broadcasting from chicago in response to coronavirus crisis.
# >>> trump begins broadcasting from philadelphia in response to coronavirus crisis.
#
# {'score': 0.9026199579238892, 'token': 1996, 'token_str': 'the', 'sequence': 'trump continues to broadcast from the inspite of coronavirus crisis.'} 5
# >>> trump continues to broadcast from the inspite of coronavirus crisis.
# >>> trump continues to broadcast from an inspite of coronavirus crisis.
# >>> trump continues to broadcast from this inspite of coronavirus crisis.
# >>> trump continues to broadcast from his inspite of coronavirus crisis.
# >>> trump continues to broadcast from every inspite of coronavirus crisis.
#
# {'score': 0.10454166680574417, 'token': 6869, 'token_str': 'respond', 'sequence': 'trump says businesses should respond soon while fighting coronavirus.'} 5
# >>> trump says businesses should respond soon while fighting coronavirus.
# >>> trump says businesses should start soon while fighting coronavirus.
# >>> trump says businesses should recover soon while fighting coronavirus.
# >>> trump says businesses should die soon while fighting coronavirus.
# >>> trump says businesses should heal soon while fighting coronavirus.
#
# {'score': 0.23603211343288422, 'token': 2485, 'token_str': 'close', 'sequence': 'biden says businesses should close soon due to rising covid cases.'} 5
# >>> biden says businesses should close soon due to rising covid cases.
# >>> biden says businesses should move soon due to rising covid cases.
# >>> biden says businesses should disappear soon due to rising covid cases.
# >>> biden says businesses should retire soon due to rising covid cases.
# >>> biden says businesses should relocate soon due to rising covid cases.
#
# {'score': 0.7841013073921204, 'token': 6366, 'token_str': 'remove', 'sequence': 'trump decided to remove his mask during the press conference.'} 5
# >>> trump decided to remove his mask during the press conference.
# >>> trump decided to wear his mask during the press conference.
# >>> trump decided to drop his mask during the press conference.
# >>> trump decided to change his mask during the press conference.
# >>> trump decided to reveal his mask during the press conference.
#
# {'score': 0.7135180234909058, 'token': 6366, 'token_str': 'remove', 'sequence': 'biden decided to remove his mask during the press conference.'} 5
# >>> biden decided to remove his mask during the press conference.
# >>> biden decided to wear his mask during the press conference.
# >>> biden decided to drop his mask during the press conference.
# >>> biden decided to don his mask during the press conference.
# >>> biden decided to change his mask during the press conference.
#
# {'score': 0.16965404152870178, 'token': 3048, 'token_str': 'moving', 'sequence': 'trump administration were moving towards banning abortion in states across the us.'} 5
# >>> trump administration were moving towards banning abortion in states across the us.
# >>> trump administration were pushing towards banning abortion in states across the us.
# >>> trump administration were working towards banning abortion in states across the us.
# >>> trump administration were vocal towards banning abortion in states across the us.
# >>> trump administration were campaigning towards banning abortion in states across the us.
#
# {'score': 0.4814637303352356, 'token': 6984, 'token_str': 'defending', 'sequence': 'biden administration are defending the abortion rights of the democratic states.'} 5
# >>> biden administration are defending the abortion rights of the democratic states.
# >>> biden administration are protecting the abortion rights of the democratic states.
# >>> biden administration are promoting the abortion rights of the democratic states.
# >>> biden administration are supporting the abortion rights of the democratic states.
# >>> biden administration are advancing the abortion rights of the democratic states.
#
# {'score': 0.3563581109046936, 'token': 9720, 'token_str': 'urged', 'sequence': 'biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis'} 5
# >>> biden urged trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden convinced trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden asked trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden persuaded trump to drop the obamacare lawsuit amid growing coronavirus crisis
# >>> biden advised trump to drop the obamacare lawsuit amid growing coronavirus crisis
#
# {'score': 0.06757715344429016, 'token': 17976, 'token_str': 'conducts', 'sequence': "biden conducts his own coronavirus briefings, as he fights to return from'sideline '"} 5
# >>> biden conducts his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden attends his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden makes his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden holds his own coronavirus briefings, as he fights to return from'sideline '
# >>> biden hosts his own coronavirus briefings, as he fights to return from'sideline '
#
# {'score': 0.8252859711647034, 'token': 1037, 'token_str': 'a', 'sequence': 'republicans and trump looking to a new bill that would increase production of firearms to licensed americans.'} 5
# >>> republicans and trump looking to a new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to introduce new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to the new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to draft new bill that would increase production of firearms to licensed americans.
# >>> republicans and trump looking to pass new bill that would increase production of firearms to licensed americans.
#
# {'score': 0.188589945435524, 'token': 4337, 'token_str': 'combat', 'sequence': 'biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.'} 5
# >>> biden and his democratic administration aim to combat the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to address the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to stop the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# >>> biden and his democratic administration aim to counter the increasing gun violence by passing a new bill to prevent selling of firearms.
#
# {'score': 0.3552539050579071, 'token': 3413, 'token_str': 'pass', 'sequence': "president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights."} 5
# >>> president biden looking to pass an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to issue an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to implement an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to get an executive order on securing access to abortion and to defend women's fundamental rights.
# >>> president biden looking to sign an executive order on securing access to abortion and to defend women's fundamental rights.
#
# {'score': 0.1845882087945938, 'token': 4941, 'token_str': 'opposed', 'sequence': 'democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> democrats opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> democrats oppose the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.18249012529850006, 'token': 4941, 'token_str': 'opposed', 'sequence': 'republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.'} 5
# >>> republicans opposed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans supported the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans overturned the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans challenged the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# >>> republicans appealed the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
#
# {'score': 0.19798345863819122, 'token': 2147, 'token_str': 'work', 'sequence': 'democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.'} 5
# >>> democrats work with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats collaborate with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats identify with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats continue with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
# >>> democrats deal with the lgbtq community ’ s fight for equality, anti - bullying and anti - violence.
#
# {'score': 0.3461085557937622, 'token': 9770, 'token_str': 'imposed', 'sequence': 'republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.'} 5
# >>> republican led states have imposed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have enacted numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have placed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# >>> republican led states have implemented numerous restrictions on transgender young people and on school discussions of sexual orientation.
#
# {'score': 0.040398839861154556, 'token': 4888, 'token_str': 'launch', 'sequence': 'republicans launch attacks on gay and transgender community.'} 5
# >>> republicans launch attacks on gay and transgender community.
# >>> republicans'attacks on gay and transgender community.
# >>> republicans launched attacks on gay and transgender community.
# >>> republicans include attacks on gay and transgender community.
# >>> republicans hate attacks on gay and transgender community.
#
# {'score': 0.19151851534843445, 'token': 5547, 'token_str': 'reduce', 'sequence': 'democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.'} 5
# >>> democrats believe that we can reduce gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can prevent gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can stop gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can end gun violence while respecting the rights of responsible gun owners.
# >>> democrats believe that we can curb gun violence while respecting the rights of responsible gun owners.
#
# {'score': 0.2305496782064438, 'token': 5221, 'token_str': 'biggest', 'sequence': 'biden and the democrats rank crime and gun violence as one of the biggest issues in the country.'} 5
# >>> biden and the democrats rank crime and gun violence as one of the biggest issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the worst issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the major issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the key issues in the country.
# >>> biden and the democrats rank crime and gun violence as one of the hardest issues in the country.
#
# {'score': 0.9529081583023071, 'token': 2062, 'token_str': 'more', 'sequence': 'trump and the republicans maintain that there are more pressing issues than gun violence.'} 5
# >>> trump and the republicans maintain that there are more pressing issues than gun violence.
# >>> trump and the republicans maintain that there are less pressing issues than gun violence.
# >>> trump and the republicans maintain that there are fewer pressing issues than gun violence.
# >>> trump and the republicans maintain that there are bigger pressing issues than gun violence.
# >>> trump and the republicans maintain that there are greater pressing issues than gun violence.
#
# {'score': 0.5283384323120117, 'token': 2053, 'token_str': 'no', 'sequence': 'biden says that there are no greater issues than gun violence.'} 5
# >>> biden says that there are no greater issues than gun violence.
# >>> biden says that there are still greater issues than gun violence.
# >>> biden says that there are far greater issues than gun violence.
# >>> biden says that there are much greater issues than gun violence.
# >>> biden says that there are even greater issues than gun violence.
#
# {'score': 0.46489229798316956, 'token': 5295, 'token_str': 'resigned', 'sequence': 'trump resigned by top doctor after increasing false claims over twitter.'} 5
# >>> trump resigned by top doctor after increasing false claims over twitter.
# >>> trump responded by top doctor after increasing false claims over twitter.
# >>> trump won by top doctor after increasing false claims over twitter.
# >>> trump declined by top doctor after increasing false claims over twitter.
# >>> trump fired by top doctor after increasing false claims over twitter.
#
# {'score': 0.13187651336193085, 'token': 9449, 'token_str': 'advised', 'sequence': 'biden advised the nation on coronavirus in a quickly - constructed home studio'} 5
# >>> biden advised the nation on coronavirus in a quickly - constructed home studio
# >>> biden advises the nation on coronavirus in a quickly - constructed home studio
# >>> biden warned the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectured the nation on coronavirus in a quickly - constructed home studio
# >>> biden lectures the nation on coronavirus in a quickly - constructed home studio

# %%
validation_df = pd.DataFrame()
validation_df['L_mask_word_prediction'] = L_top_most_predictions
validation_df['L_sentence'] = L_top_most_sentences
validation_df['L_prediction_prob'] = L_top_most_scores
validation_df['R_mask_word_prediction'] = R_top_most_predictions
validation_df['R_sentence'] = R_top_most_sentences
validation_df['R_prediction_prob'] = R_top_most_scores

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...
# 1   [0.32672545313835144, 0.047891635447740555, 0....
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...
# 4   [0.11232783645391464, 0.058183617889881134, 0....
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...
# 26  [0.027731070294976234, 0.025310203433036804, 0...
# 27  [0.032828718423843384, 0.01814362034201622, 0....
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...
# 30  [0.23603211343288422, 0.061422985047101974, 0....
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...
# 38  [0.188589945435524, 0.17262092232704163, 0.103...
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...
# 41  [0.18249012529850006, 0.133339062333107, 0.111...
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...
# 44  [0.040398839861154556, 0.03771699592471123, 0....
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...

# %%
L_lexicon_word_valence_list = []
R_lexicon_word_valence_list = []
words_not_in_lexicon_dict = []

for words in L_top_most_predictions:
  avg_sum = 0
  ranks = [1.4, 1.3, 1.2, 1.1, 1]
  for i, word in enumerate(words):
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += (lexicon_dictionary[lemmatized_word] * ranks[i])
  L_lexicon_word_valence_list.append(avg_sum/5)

for words in R_top_most_predictions:
  avg_sum = 0
  ranks = [1.4, 1.3, 1.2, 1.1, 1]
  for i, word in enumerate(words):
    lemmatized_word = lemmatizer.lemmatize(word)
    stemmed_word = ps.stem(word)
    lemmatized_word = stemmed_word
    if lemmatized_word not in lexicon_dictionary:
      continue
    else:
      avg_sum += (lexicon_dictionary[lemmatized_word] * ranks[i])
  R_lexicon_word_valence_list.append(avg_sum/5)

# %%
validation_df['L_lexicon'] = L_lexicon_word_valence_list
validation_df['R_lexicon'] = R_lexicon_word_valence_list

# %%
validation_df
# Out:
#                                L_mask_word_prediction  \
# 0       [delivered, told, said, addressed, described]
# 1                [called, won, canceled, lost, named]
# 2   [predicted, supported, praised, supports, endo...
# 3        [elected, reelected, fired, named, released]
# 4                  [##s, posted, used, has, released]
# 5       [the, new, expanding, implementing, changing]
# 6       [the, new, changing, implementing, expanding]
# 7                 [leave, the, rebuild, reform, exit]
# 8                        [the, this, another, a, his]
# 9         [blamed, criticized, sued, fired, supports]
# 10  [endorsed, chose, represents, defeated, nomina...
# 11                   [try, go, intervene, come, vote]
# 12  [supports, endorsed, supported, opposes, defea...
# 13               [wants, hopes, plans, promised, has]
# 14              [', introduced, signed, sponsored, a]
# 15                  [an, renewed, no, strong, little]
# 16             [an, renewed, no, strong, significant]
# 17      [the, new, expanding, implementing, changing]
# 18    [extended, renewed, expanded, removed, dropped]
# 19           [designed, called, added, created, used]
# 20         [began, sought, received, took, requested]
# 21          [received, sought, began, took, declined]
# 22                         [who, ,, that, may, often]
# 23                 [who, ,, today, often, personally]
# 24    [power, authority, control, sovereignty, right]
# 25      [control, authority, influence, power, state]
# 26  [washington, seattle, philadelphia, atlanta, c...
# 27  [cnn, washington, atlanta, philadelphia, calif...
# 28                        [the, an, this, every, his]
# 29               [start, respond, open, recover, die]
# 30                [close, move, retire, open, return]
# 31                  [remove, wear, drop, don, change]
# 32                  [remove, wear, drop, don, change]
# 33         [moving, pushing, working, leaning, vocal]
# 34  [defending, protecting, promoting, advancing, ...
# 35        [urged, convinced, asked, persuaded, urges]
# 36           [makes, holds, attends, hosts, conducts]
# 37                   [a, the, introduce, pass, draft]
# 38                [combat, address, stop, stem, curb]
# 39                [pass, issue, sign, implement, get]
# 40  [opposed, challenged, supported, oppose, appea...
# 41  [opposed, challenged, supported, overturned, a...
# 42        [work, collaborate, identify, deal, engage]
# 43        [imposed, enacted, passed, placed, removed]
# 44                   [', launch, include, make, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47                 [more, less, bigger, fewer, other]
# 48                       [no, even, far, still, much]
# 49     [resigned, responded, won, replaced, declined]
# 50     [warned, advised, advises, lectured, lectures]
#
#                                            L_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3           trump was elected after the win of obama.
# 4   trumps tweets as us tackles coronavirus, inclu...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden supports trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden'new bill specially directed towards the ...
# 15  trump administration has shown an interest in ...
# 16  biden administration has shown an interest in ...
# 17  trump considering the coronavirus guidelines a...
# 18  trump extended the mask mandate after reducing...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from washington in r...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should start soon while ...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden makes his own coronavirus briefings, as ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans'attacks on gay and transgender com...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden warned the nation on coronavirus in a qu...
#
#                                     L_prediction_prob  \
# 0   [0.08138512074947357, 0.06628639250993729, 0.0...
# 1   [0.34503334760665894, 0.08206091821193695, 0.0...
# 2   [0.20589497685432434, 0.11232000589370728, 0.0...
# 3   [0.07329434156417847, 0.06654732674360275, 0.0...
# 4   [0.18212540447711945, 0.06540976464748383, 0.0...
# 5   [0.11568285524845123, 0.07287382334470749, 0.0...
# 6   [0.13971394300460815, 0.05805186554789543, 0.0...
# 7   [0.30816951394081116, 0.046250008046627045, 0....
# 8   [0.6364176869392395, 0.0911860540509224, 0.072...
# 9   [0.5015187859535217, 0.09938707947731018, 0.05...
# 10  [0.185824453830719, 0.12864677608013153, 0.058...
# 11  [0.32077473402023315, 0.09621737152338028, 0.0...
# 12  [0.1804586797952652, 0.1795153021812439, 0.157...
# 13  [0.428376704454422, 0.08888009190559387, 0.057...
# 14  [0.23873110115528107, 0.1467435359954834, 0.06...
# 15  [0.157856285572052, 0.1030479371547699, 0.0948...
# 16  [0.16340991854667664, 0.13243705034255981, 0.0...
# 17  [0.11568285524845123, 0.07287382334470749, 0.0...
# 18  [0.08619348704814911, 0.060386717319488525, 0....
# 19  [0.13648876547813416, 0.039417702704668045, 0....
# 20  [0.1121138334274292, 0.06951527297496796, 0.05...
# 21  [0.19125279784202576, 0.08809471130371094, 0.0...
# 22  [0.38528311252593994, 0.17831841111183167, 0.0...
# 23  [0.37732696533203125, 0.17801767587661743, 0.0...
# 24  [0.38997113704681396, 0.08923307061195374, 0.0...
# 25  [0.36533260345458984, 0.055797625333070755, 0....
# 26  [0.03241858258843422, 0.02699933759868145, 0.0...
# 27  [0.041604600846767426, 0.03158263489603996, 0....
# 28  [0.9120039939880371, 0.03574091196060181, 0.01...
# 29  [0.12141679972410202, 0.0733269527554512, 0.04...
# 30  [0.36450302600860596, 0.07115985453128815, 0.0...
# 31  [0.7898169755935669, 0.07473918795585632, 0.02...
# 32  [0.7261218428611755, 0.1114303469657898, 0.034...
# 33  [0.21348243951797485, 0.1958346962928772, 0.09...
# 34  [0.47674453258514404, 0.18303123116493225, 0.0...
# 35  [0.31571298837661743, 0.1136237308382988, 0.09...
# 36  [0.05605851486325264, 0.05553332716226578, 0.0...
# 37  [0.8575072288513184, 0.03672188147902489, 0.01...
# 38  [0.18308378756046295, 0.13840320706367493, 0.0...
# 39  [0.46116048097610474, 0.09755484759807587, 0.0...
# 40  [0.15492363274097443, 0.12165883928537369, 0.1...
# 41  [0.13851293921470642, 0.1379692256450653, 0.10...
# 42  [0.19803355634212494, 0.07203716784715652, 0.0...
# 43  [0.3440225422382355, 0.20665332674980164, 0.13...
# 44  [0.05898619443178177, 0.04150316119194031, 0.0...
# 45  [0.21552608907222748, 0.15063618123531342, 0.1...
# 46  [0.28692349791526794, 0.12581166625022888, 0.1...
# 47  [0.9593712687492371, 0.02280590310692787, 0.00...
# 48  [0.44995036721229553, 0.10202356427907944, 0.0...
# 49  [0.253000944852829, 0.07957673072814941, 0.059...
# 50  [0.1359003335237503, 0.09958899021148682, 0.08...
#
#                                R_mask_word_prediction  \
# 0   [delivered, told, addressed, described, mentio...
# 1       [called, canceled, won, cancelled, announced]
# 2   [predicted, supported, praised, endorsed, supp...
# 3       [reelected, fired, elected, named, appointed]
# 4                 [posted, ##s, used, released, made]
# 5       [the, implementing, adopting, expanding, new]
# 6        [the, implementing, adopting, new, changing]
# 7             [leave, reform, exit, rebuild, abandon]
# 8                        [the, another, this, his, a]
# 9      [blamed, criticized, endorsed, supports, sued]
# 10  [endorsed, represents, chose, defeated, nomina...
# 11                 [try, go, intervene, come, resign]
# 12  [endorsed, supported, supports, opposes, criti...
# 13             [wants, promised, hopes, plans, vowed]
# 14       [introduced, sponsored, signed, ', proposed]
# 15              [renewed, an, strong, no, increasing]
# 16             [renewed, an, strong, no, significant]
# 17      [the, implementing, adopting, expanding, new]
# 18  [renewed, extended, expanded, reinstated, drop...
# 19       [designed, created, added, called, expanded]
# 20  [began, received, sought, discontinued, declined]
# 21         [received, began, sought, underwent, took]
# 22                       [who, ,, ', reportedly, may]
# 23                     [who, ,, today, personally, ']
# 24    [power, authority, state, sovereignty, economy]
# 25  [control, environment, state, economy, authority]
# 26    [miami, seattle, chicago, boston, philadelphia]
# 27  [cnn, washington, twitter, chicago, philadelphia]
# 28                        [the, an, this, his, every]
# 29               [respond, start, recover, die, heal]
# 30         [close, move, disappear, retire, relocate]
# 31               [remove, wear, drop, change, reveal]
# 32                  [remove, wear, drop, don, change]
# 33     [moving, pushing, working, vocal, campaigning]
# 34  [defending, protecting, promoting, supporting,...
# 35      [urged, convinced, asked, persuaded, advised]
# 36           [conducts, attends, makes, holds, hosts]
# 37                   [a, introduce, the, draft, pass]
# 38             [combat, address, stop, curb, counter]
# 39                [pass, issue, implement, get, sign]
# 40  [opposed, supported, challenged, appealed, opp...
# 41  [opposed, supported, overturned, challenged, a...
# 42      [work, collaborate, identify, continue, deal]
# 43    [imposed, enacted, passed, placed, implemented]
# 44               [launch, ', launched, include, hate]
# 45                 [reduce, prevent, stop, end, curb]
# 46              [biggest, worst, major, key, hardest]
# 47               [more, less, fewer, bigger, greater]
# 48                       [no, still, far, much, even]
# 49        [resigned, responded, won, declined, fired]
# 50     [advised, advises, warned, lectured, lectures]
#
#                                            R_sentence  \
# 0   trump delivered the sad news on monday in the ...
# 1   trump called the elections after the results y...
# 2       biden predicted the victory of obama in 2012.
# 3         trump was reelected after the win of obama.
# 4   trump posted tweets as us tackles coronavirus,...
# 5   trump considering the coronavirus guidelines a...
# 6   biden considering the coronavirus guidelines a...
# 7   trump intends to leave country amid growing co...
# 8   biden says he intendes to the country to preve...
# 9   california blamed trump for medical supply sho...
# 10  california endorsed biden irrespective of elec...
# 11  biden says it's time for trump to try and make...
# 12  biden endorsed trump after republicans block c...
# 13  trump wants to restart the us economy because ...
# 14  biden introduced new bill specially directed t...
# 15  trump administration has shown renewed interes...
# 16  biden administration has shown renewed interes...
# 17  trump considering the coronavirus guidelines a...
# 18  trump renewed the mask mandate after reducing ...
# 19  biden designed the mask mandate inspite of red...
# 20  trump began unproven coronavirus treatment hou...
# 21  biden received unproven coronavirus treatment ...
# 22  trump's favorite hosts who are pushing him to ...
# 23  biden's favorite hosts who are advising him to...
# 24  the trump administration wants to protect the ...
# 25  the biden administration wants to protect the ...
# 26  biden begins broadcasting from miami in respon...
# 27  trump begins broadcasting from cnn in response...
# 28  trump continues to broadcast from the inspite ...
# 29  trump says businesses should respond soon whil...
# 30  biden says businesses should close soon due to...
# 31  trump decided to remove his mask during the pr...
# 32  biden decided to remove his mask during the pr...
# 33  trump administration were moving towards banni...
# 34  biden administration are defending the abortio...
# 35  biden urged trump to drop the obamacare lawsui...
# 36  biden conducts his own coronavirus briefings, ...
# 37  republicans and trump looking to a new bill th...
# 38  biden and his democratic administration aim to...
# 39  president biden looking to pass an executive o...
# 40  democrats opposed the decision by the supreme ...
# 41  republicans opposed the decision by the suprem...
# 42  democrats work with the lgbtq community ’ s fi...
# 43  republican led states have imposed numerous re...
# 44  republicans launch attacks on gay and transgen...
# 45  democrats believe that we can reduce gun viole...
# 46  biden and the democrats rank crime and gun vio...
# 47  trump and the republicans maintain that there ...
# 48  biden says that there are no greater issues th...
# 49  trump resigned by top doctor after increasing ...
# 50  biden advised the nation on coronavirus in a q...
#
#                                     R_prediction_prob  L_lexicon  R_lexicon
# 0   [0.07356075942516327, 0.06047539412975311, 0.0...    0.38384    0.51728
# 1   [0.32672545313835144, 0.047891635447740555, 0....    0.40118    0.39816
# 2   [0.2542664706707001, 0.15217866003513336, 0.08...    0.93836    0.93754
# 3   [0.06306461989879608, 0.06057732552289963, 0.0...    0.67268    0.64298
# 4   [0.11232783645391464, 0.058183617889881134, 0....    0.49744    0.52472
# 5   [0.09981061518192291, 0.06872966885566711, 0.0...    0.64740    0.62984
# 6   [0.11761776357889175, 0.05123515799641609, 0.0...    0.63984    0.59164
# 7   [0.33007100224494934, 0.09021633863449097, 0.0...    0.40072    0.45048
# 8   [0.46060705184936523, 0.18179969489574432, 0.1...    0.00000    0.00000
# 9   [0.49254390597343445, 0.10445214062929153, 0.0...    0.31096    0.48726
# 10  [0.0945819765329361, 0.0825297087430954, 0.073...    0.58004    0.59596
# 11  [0.21682237088680267, 0.10627017915248871, 0.0...    0.66390    0.58890
# 12  [0.34109559655189514, 0.16034574806690216, 0.1...    0.73400    0.76038
# 13  [0.4751662611961365, 0.09223148226737976, 0.04...    0.77922    0.89130
# 14  [0.41499513387680054, 0.0884423702955246, 0.04...    0.46310    0.62490
# 15  [0.16109494864940643, 0.14663973450660706, 0.0...    0.47784    0.57128
# 16  [0.19267551600933075, 0.14418458938598633, 0.0...    0.56624    0.59988
# 17  [0.09981061518192291, 0.06872966885566711, 0.0...    0.64740    0.62984
# 18  [0.08253582566976547, 0.07060585916042328, 0.0...    0.71214    0.80238
# 19  [0.17404693365097046, 0.02854636125266552, 0.0...    0.84884    0.84676
# 20  [0.09098333865404129, 0.0843048021197319, 0.05...    0.29756    0.30380
# 21  [0.22917234897613525, 0.06656605750322342, 0.0...    0.26692    0.20132
# 22  [0.3475826382637024, 0.0890871211886406, 0.031...    0.15488    0.14080
# 23  [0.3192075192928314, 0.09911710768938065, 0.03...    0.36724    0.38462
# 24  [0.23804284632205963, 0.06703928858041763, 0.0...    0.87990    0.91070
# 25  [0.12790729105472565, 0.09844446927309036, 0.0...    0.83796    0.76252
# 26  [0.027731070294976234, 0.025310203433036804, 0...    0.00000    0.14146
# 27  [0.032828718423843384, 0.01814362034201622, 0....    0.00000    0.00000
# 28  [0.9026199579238892, 0.03818743675947189, 0.02...    0.00000    0.00000
# 29  [0.10454166680574417, 0.0943572074174881, 0.06...    0.71910    0.68268
# 30  [0.23603211343288422, 0.061422985047101974, 0....    0.74988    0.55646
# 31  [0.7841013073921204, 0.06431331485509872, 0.03...    0.63360    0.60150
# 32  [0.7135180234909058, 0.09986534714698792, 0.04...    0.63360    0.63360
# 33  [0.16965404152870178, 0.11253170669078827, 0.0...    0.64552    0.65778
# 34  [0.4814637303352356, 0.1260632872581482, 0.054...    0.96954    0.96846
# 35  [0.3563581109046936, 0.12395305931568146, 0.09...    0.66208    0.72748
# 36  [0.06757715344429016, 0.06222150847315788, 0.0...    0.75578    0.74880
# 37  [0.8252859711647034, 0.042054012417793274, 0.0...    0.33044    0.34188
# 38  [0.188589945435524, 0.17262092232704163, 0.103...    0.60410    0.56604
# 39  [0.3552539050579071, 0.06381998211145401, 0.06...    0.66560    0.67000
# 40  [0.1845882087945938, 0.14704351127147675, 0.09...    0.54502    0.56368
# 41  [0.18249012529850006, 0.133339062333107, 0.111...    0.55646    0.56208
# 42  [0.19798345863819122, 0.07686340063810349, 0.0...    0.88082    0.83740
# 43  [0.3461085557937622, 0.27613765001296997, 0.13...    0.58656    0.66316
# 44  [0.040398839861154556, 0.03771699592471123, 0....    0.46248    0.42540
# 45  [0.19151851534843445, 0.1447947919368744, 0.13...    0.49450    0.49450
# 46  [0.2305496782064438, 0.17579048871994019, 0.12...    0.26734    0.26734
# 47  [0.9529081583023071, 0.03334579989314079, 0.00...    0.32626    0.38286
# 48  [0.5283384323120117, 0.06792425364255905, 0.06...    0.31430    0.30794
# 49  [0.46489229798316956, 0.08426260948181152, 0.0...    0.33424    0.29370
# 50  [0.13187651336193085, 0.08612474054098129, 0.0...    0.72096    0.74160

# %% [markdown]
# Validation scores for Method 7

# %%
# Left leaning model (considering RANK average) has lower score and right leaning model (considering RANK average) has slightly higher score
print(validation_df['L_lexicon'].sum()/50, validation_df['R_lexicon'].sum()/50)
# Out:
# 0.5405556 0.5526207999999999

# %% [markdown]
# ### Method 8 - Checking scores for "democrats" and "republicans"

# %%
import numpy as np
L_democrats_prob_score = []
L_republicans_prob_score = []
L_trump_prob_score = []

## TESTING

for prediction in validation_sentences_df['Target Masked Sentences']:
  inputs = tokenizer(prediction, return_tensors="np")
  token_logits = left_leaning_model(**inputs).logits
  # Find the location of [MASK] and extract its logits
  mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  mask_token_logits = token_logits[0, mask_token_index, :]
  # Pick the [MASK] candidates with the highest logits
  # We negate the array before argsort to get the largest, not the smallest, logits
  all_tokens = np.argsort(-mask_token_logits).tolist()

  word_probability_dict = {}
  for index, val in enumerate(mask_token_logits):
    word = tokenizer.decode([index])
    word_probability_dict[word] = val.numpy()
  print('Prediction:', prediction)
  print("Democrats prob. score:", word_probability_dict['democrats'])
  print("Republicans prob. score:", word_probability_dict['republicans'])
  print("Trump prob. score:", word_probability_dict['trump'])
  print()
  L_democrats_prob_score.append(word_probability_dict['democrats'])
  L_republicans_prob_score.append(word_probability_dict['republicans'])
  L_trump_prob_score.append(word_probability_dict['trump'])
# Out:
# Prediction: [MASK] announced the sad news on Monday in the press briefing.
# Democrats prob. score: 2.707
# Republicans prob. score: 2.41
# Trump prob. score: 7.035
#
# Prediction: [MASK] won the elections after the results yesterday.
# Democrats prob. score: 5.188
# Republicans prob. score: 5.19
# Trump prob. score: 5.254
#
# Prediction: [MASK] celebrated the victory of Obama in 2012.
# Democrats prob. score: 3.035
# Republicans prob. score: 2.74
# Trump prob. score: 5.066
#
# Prediction: [MASK] was dissappointed after the win of Obama
# Democrats prob. score: 1.718
# Republicans prob. score: 1.511
# Trump prob. score: 6.953
#
# Prediction: [MASK] fires-off tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# Democrats prob. score: 0.1963
# Republicans prob. score: 0.005127
# Trump prob. score: 4.043
#
# Prediction: [MASK] considering loosening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 3.848
# Republicans prob. score: 3.041
# Trump prob. score: 1.65
#
# Prediction: [MASK] considering strengthening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 3.8
# Republicans prob. score: 3.03
# Trump prob. score: 1.643
#
# Prediction: [MASK] intends to open country amid growing coronavirus cases.
# Democrats prob. score: 2.234
# Republicans prob. score: 1.433
# Trump prob. score: 6.375
#
# Prediction: [MASK] says he intends to lockdown country to prevent rise of coronavirus cases.
# Democrats prob. score: 0.9717
# Republicans prob. score: 0.55
# Trump prob. score: 8.12
#
# Prediction: California blames [MASK] for medical supply shortages.
# Democrats prob. score: 5.496
# Republicans prob. score: 5.195
# Trump prob. score: 6.105
#
# Prediction: California supports [MASK] irrespective of election outcome.
# Democrats prob. score: 6.96
# Republicans prob. score: 6.43
# Trump prob. score: 7.688
#
# Prediction: [MASK] says it's time for [MASK] to step-up and make it right.
# Democrats prob. score: -1.347
# Republicans prob. score: -1.239
# Trump prob. score: 3.037
#
# Prediction: [MASK] says it's time for [MASK] to resign and make it right.
# Democrats prob. score: 1.27
# Republicans prob. score: 1.533
# Trump prob. score: 5.688
#
# Prediction: [MASK] blames [MASK] after [MASK] block covid relief funds.
# Democrats prob. score: 1.025
# Republicans prob. score: 1.028
# Trump prob. score: 5.29
#
# Prediction: [MASK] wants to restart the US economy because he's afraid the tanking stock market will hurt his reelection changes.
# Democrats prob. score: 3.137
# Republicans prob. score: 3.367
# Trump prob. score: 8.914
#
# Prediction: [MASK] introduces new bill specially directed in opposition of the rising gun violence in the US.
# Democrats prob. score: 3.746
# Republicans prob. score: 3.479
# Trump prob. score: 5.844
#
# Prediction: [MASK] introduces new bill specially directed in support of the rising gun violence in the US.
# Democrats prob. score: 3.566
# Republicans prob. score: 3.303
# Trump prob. score: 5.758
#
# Prediction: [MASK] administration has shown no interest in restoring government funding for Gun violence research.
# Democrats prob. score: 2.148
# Republicans prob. score: 1.973
# Trump prob. score: 9.81
#
# Prediction: [MASK] administration has shown great interest in restoring government funding for Gun violence research.
# Democrats prob. score: 2.023
# Republicans prob. score: 1.879
# Trump prob. score: 9.67
#
# Prediction: [MASK] considering loosening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 3.848
# Republicans prob. score: 3.041
# Trump prob. score: 1.65
#
# Prediction: [MASK] considering strengthening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 3.8
# Republicans prob. score: 3.03
# Trump prob. score: 1.643
#
# Prediction: [MASK] removes the mask mandate after reducing coronavirus cases.
# Democrats prob. score: 1.72
# Republicans prob. score: 0.663
# Trump prob. score: 4.21
#
# Prediction: [MASK] keeps the mandate inspite of reducing coronavirus cases.
# Democrats prob. score: 1.021
# Republicans prob. score: 0.7266
# Trump prob. score: 4.02
#
# Prediction: [MASK] touts unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it
# Democrats prob. score: 1.325
# Republicans prob. score: 0.4832
# Trump prob. score: 2.885
#
# Prediction: [MASK] impedes unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# Democrats prob. score: 2.508
# Republicans prob. score: 1.542
# Trump prob. score: 5.906
#
# Prediction: [MASK]'s favorite hosts Fox News are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# Democrats prob. score: 2.133
# Republicans prob. score: 1.943
# Trump prob. score: 9.74
#
# Prediction: [MASK]'s favorite hosts CNN are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# Democrats prob. score: 0.2251
# Republicans prob. score: 0.3845
# Trump prob. score: 9.055
#
# Prediction: The [MASK] administration wants to protect the economy over the people to protect the crashing economy.
# Democrats prob. score: 2.398
# Republicans prob. score: 1.658
# Trump prob. score: 11.66
#
# Prediction: The [MASK] administration wants to protect the people over the economy by increasing the coronavirus prevention measures.
# Democrats prob. score: 2.465
# Republicans prob. score: 1.648
# Trump prob. score: 12.41
#
# Prediction: [MASK] begins broadcasting from home in response to coronavirus crisis
# Democrats prob. score: -1.909
# Republicans prob. score: -2.633
# Trump prob. score: -0.0748
#
# Prediction: [MASK] begins broadcasting from home in response to coronavirus crisis
# Democrats prob. score: -1.909
# Republicans prob. score: -2.633
# Trump prob. score: -0.0748
#
# Prediction: [MASK] continues to broadcast from office inspite of coronavirus crisis.
# Democrats prob. score: -1.697
# Republicans prob. score: -3.05
# Trump prob. score: 0.01831
#
# Prediction: [MASK] says businesses should reopen soon while fighting coronavirus.
# Democrats prob. score: 0.708
# Republicans prob. score: 0.0779
# Trump prob. score: 6.42
#
# Prediction: [MASK] says businesses should close soon due to rising covid cases.
# Democrats prob. score: 0.46
# Republicans prob. score: -0.3015
# Trump prob. score: 5.598
#
# Prediction: [MASK] decided to remove his mask during the press conference.
# Democrats prob. score: 0.6167
# Republicans prob. score: 0.6826
# Trump prob. score: 6.766
#
# Prediction: [MASK] decided to wear his mask during the press conference.
# Democrats prob. score: 0.09424
# Republicans prob. score: 0.2732
# Trump prob. score: 6.418
#
# Prediction: [MASK] administration were pushing towards banning abortion in states across the US.
# Democrats prob. score: 3.637
# Republicans prob. score: 3.084
# Trump prob. score: 9.95
#
# Prediction: [MASK] administration are protecting the abortion rights of the democratic states.
# Democrats prob. score: 3.98
# Republicans prob. score: 3.215
# Trump prob. score: 8.98
#
# Prediction: [MASK] urges [MASK] to drop the ObamaCare lawsuit amid growing coronavirus crisis
# Democrats prob. score: 3.328
# Republicans prob. score: 2.963
# Trump prob. score: 7.17
#
# Prediction: [MASK] launching his own coronavirus briefings, as he fights to return from 'sideline'
# Democrats prob. score: -1.409
# Republicans prob. score: -1.366
# Trump prob. score: 0.4019
#
# Prediction: [MASK] and [MASK] looking to pass new bill that would increase production of firearms to licensed americans.
# Democrats prob. score: 4.855
# Republicans prob. score: 4.77
# Trump prob. score: 4.836
#
# Prediction: [MASK] and his democratic administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# Democrats prob. score: 3.777
# Republicans prob. score: 4.52
# Trump prob. score: 10.09
#
# Prediction: [MASK] looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# Democrats prob. score: 4.96
# Republicans prob. score: 4.81
# Trump prob. score: 2.305
#
# Prediction: [MASK] looking to cancel an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# Democrats prob. score: 6.04
# Republicans prob. score: 6.047
# Trump prob. score: 2.88
#
# Prediction: [MASK] applaud the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# Democrats prob. score: 5.13
# Republicans prob. score: 5.137
# Trump prob. score: 6.95
#
# Prediction: [MASK] criticize the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# Democrats prob. score: 6.895
# Republicans prob. score: 7.105
# Trump prob. score: 4.137
#
# Prediction: [MASK] stand with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# Democrats prob. score: 4.664
# Republicans prob. score: 4.19
# Trump prob. score: 2.51
#
# Prediction: [MASK] led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Democrats prob. score: 4.895
# Republicans prob. score: 3.816
# Trump prob. score: 4.773
#
# Prediction: [MASK] led states have prohibited numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Democrats prob. score: 4.023
# Republicans prob. score: 2.586
# Trump prob. score: 4.258
#
# Prediction: [MASK] sharpen attacks on gay and transgender community.
# Democrats prob. score: 1.43
# Republicans prob. score: 0.792
# Trump prob. score: 0.8755
#
# Prediction: [MASK] believe that we should reduce gun violence while respecting the rights of responsible gun owners.
# Democrats prob. score: 8.484
# Republicans prob. score: 9.12
# Trump prob. score: 2.467
#
# Prediction: [MASK] believe that we should increase gun violence while respecting the rights of responsible gun owners.
# Democrats prob. score: 8.58
# Republicans prob. score: 9.25
# Trump prob. score: 2.64
#
# Prediction: [MASK] and the [MASK] rank crime and gun violence as one of the top issues in the country.
# Democrats prob. score: 2.945
# Republicans prob. score: 2.664
# Trump prob. score: 3.338
#
# Prediction: [MASK] and the [MASK] maintain that there are more pressing issues than gun violence.
# Democrats prob. score: 4.254
# Republicans prob. score: 4.61
# Trump prob. score: 6.12
#
# Prediction: [MASK] says that there are no greater issues than gun violence.
# Democrats prob. score: 1.528
# Republicans prob. score: 1.625
# Trump prob. score: 6.83
#
# Prediction: [MASK] fact-checked by top doctor after increasing false claims over Twitter.
# Democrats prob. score: -1.553
# Republicans prob. score: -2.5
# Trump prob. score: 0.713
#
# Prediction: [MASK] addresses the nation on coronavirus in a quickly-constructed home studio
# Democrats prob. score: -0.4482
# Republicans prob. score: -0.4722
# Trump prob. score: 4.938

# %%
print(len(L_republicans_prob_score))
print(len(L_trump_prob_score))
# Out:
# 57
# 57

# %%
validation_df = pd.DataFrame()
validation_df['org_sentence'] = validation_sentences_df['Target Masked Sentences']
validation_df['L_democrats_prob_score'] = L_democrats_prob_score
validation_df['L_republicans_prob_score'] = L_republicans_prob_score
validation_df['L_trump_prob_score'] = L_trump_prob_score
print(validation_df)
# Out:
#                                          org_sentence  L_democrats_prob_score  \
# 0   [MASK] announced the sad news on Monday in the...                2.707031
# 1   [MASK] won the elections after the results yes...                5.187500
# 2     [MASK] celebrated the victory of Obama in 2012.                3.035156
# 3     [MASK] was dissappointed after the win of Obama                1.717773
# 4   [MASK] fires-off tweets as US tackles coronavi...                0.196289
# 5   [MASK] considering loosening coronavirus guide...                3.847656
# 6   [MASK] considering strengthening coronavirus g...                3.800781
# 7   [MASK] intends to open country amid growing co...                2.234375
# 8   [MASK] says he intends to lockdown country to ...                0.971680
# 9   California blames [MASK] for medical supply sh...                5.496094
# 10  California supports [MASK] irrespective of ele...                6.960938
# 11  [MASK] says it's time for [MASK] to step-up an...               -1.346680
# 12  [MASK] says it's time for [MASK] to resign and...                1.269531
# 13  [MASK] blames [MASK] after [MASK] block covid ...                1.025391
# 14  [MASK] wants to restart the US economy because...                3.136719
# 15  [MASK] introduces new bill specially directed ...                3.746094
# 16  [MASK] introduces new bill specially directed ...                3.566406
# 17  [MASK] administration has shown no interest in...                2.148438
# 18  [MASK] administration has shown great interest...                2.023438
# 19  [MASK] considering loosening coronavirus guide...                3.847656
# 20  [MASK] considering strengthening coronavirus g...                3.800781
# 21  [MASK] removes the mask mandate after reducing...                1.719727
# 22  [MASK] keeps the mandate inspite of reducing c...                1.021484
# 23  [MASK] touts unproven coronavirus treatment ho...                1.325195
# 24  [MASK] impedes unproven coronavirus treatment ...                2.507812
# 25  [MASK]'s favorite hosts Fox News are pushing h...                2.132812
# 26  [MASK]'s favorite hosts CNN are advising him t...                0.225098
# 27  The [MASK] administration wants to protect the...                2.398438
# 28  The [MASK] administration wants to protect the...                2.464844
# 29  [MASK] begins broadcasting from home in respon...               -1.909180
# 30  [MASK] begins broadcasting from home in respon...               -1.909180
# 31  [MASK] continues to broadcast from office insp...               -1.697266
# 32  [MASK] says businesses should reopen soon whil...                0.708008
# 33  [MASK] says businesses should close soon due t...                0.459961
# 34  [MASK] decided to remove his mask during the p...                0.616699
# 35  [MASK] decided to wear his mask during the pre...                0.094238
# 36  [MASK] administration were pushing towards ban...                3.636719
# 37  [MASK] administration are protecting the abort...                3.980469
# 38  [MASK] urges [MASK] to drop the ObamaCare laws...                3.328125
# 39  [MASK] launching his own coronavirus briefings...               -1.409180
# 40  [MASK] and [MASK] looking to pass new bill tha...                4.855469
# 41  [MASK] and his democratic administration aim t...                3.777344
# 42  [MASK] looking to issue an Executive Order on ...                4.960938
# 43  [MASK] looking to cancel an Executive Order on...                6.039062
# 44  [MASK] applaud the decision by the Supreme Cou...                5.128906
# 45  [MASK] criticize the decision by the Supreme C...                6.894531
# 46  [MASK] stand with the LGBTQ community’s fight ...                4.664062
# 47  [MASK] led states have passed numerous restric...                4.894531
# 48  [MASK] led states have prohibited numerous res...                4.023438
# 49  [MASK] sharpen attacks on gay and transgender ...                1.429688
# 50  [MASK] believe that we should reduce gun viole...                8.484375
# 51  [MASK] believe that we should increase gun vio...                8.578125
# 52  [MASK] and the [MASK] rank crime and gun viole...                2.945312
# 53  [MASK] and the [MASK] maintain that there are ...                4.253906
# 54  [MASK] says that there are no greater issues t...                1.528320
# 55  [MASK] fact-checked by top doctor after increa...               -1.552734
# 56  [MASK] addresses the nation on coronavirus in ...               -0.448242
#
#     L_republicans_prob_score  L_trump_prob_score
# 0                   2.410156            7.035156
# 1                   5.191406            5.253906
# 2                   2.740234            5.066406
# 3                   1.510742            6.953125
# 4                   0.005127            4.042969
# 5                   3.041016            1.650391
# 6                   3.029297            1.642578
# 7                   1.432617            6.375000
# 8                   0.549805            8.117188
# 9                   5.195312            6.105469
# 10                  6.429688            7.687500
# 11                 -1.239258            3.037109
# 12                  1.533203            5.687500
# 13                  1.028320            5.289062
# 14                  3.367188            8.914062
# 15                  3.478516            5.843750
# 16                  3.302734            5.757812
# 17                  1.972656            9.812500
# 18                  1.878906            9.671875
# 19                  3.041016            1.650391
# 20                  3.029297            1.642578
# 21                  0.663086            4.210938
# 22                  0.726562            4.019531
# 23                  0.483154            2.884766
# 24                  1.541992            5.906250
# 25                  1.943359            9.742188
# 26                  0.384521            9.054688
# 27                  1.658203           11.656250
# 28                  1.648438           12.406250
# 29                 -2.632812           -0.074829
# 30                 -2.632812           -0.074829
# 31                 -3.050781            0.018311
# 32                  0.077881            6.421875
# 33                 -0.301514            5.597656
# 34                  0.682617            6.765625
# 35                  0.273193            6.417969
# 36                  3.083984            9.953125
# 37                  3.214844            8.976562
# 38                  2.962891            7.171875
# 39                 -1.366211            0.401855
# 40                  4.769531            4.835938
# 41                  4.519531           10.093750
# 42                  4.808594            2.304688
# 43                  6.046875            2.880859
# 44                  5.136719            6.949219
# 45                  7.105469            4.136719
# 46                  4.191406            2.509766
# 47                  3.816406            4.773438
# 48                  2.585938            4.257812
# 49                  0.791992            0.875488
# 50                  9.117188            2.466797
# 51                  9.250000            2.640625
# 52                  2.664062            3.337891
# 53                  4.609375            6.121094
# 54                  1.625000            6.828125
# 55                 -2.500000            0.712891
# 56                 -0.472168            4.937500

# %%
validation_df.to_csv (r'export_validation_df.csv', index = False, header=True)

# %% [markdown]
# ### Method 9 - Target and Prior probability

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
import numpy as np
L_target_democrats = []
L_target_republicans = []
L_target_trump = []

## TESTING

for prediction in validation_sentences_df['Target Masked Sentences']:
  inputs = tokenizer(prediction, return_tensors="np")
  token_logits = model(**inputs).logits
  # Find the location of [MASK] and extract its logits
  mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  mask_token_logits = token_logits[0, mask_token_index, :]
  # Pick the [MASK] candidates with the highest logits
  # We negate the array before argsort to get the largest, not the smallest, logits
  all_tokens = np.argsort(-mask_token_logits).tolist()

  word_probability_dict = {}
  for index, val in enumerate(mask_token_logits):
    word = tokenizer.decode([index])
    word_probability_dict[word] = val.numpy()
  print('Prediction:', prediction)
  print("Democrats prob. score:", word_probability_dict['democrats'])
  print("Republicans prob. score:", word_probability_dict['republicans'])
  print("Trump prob. score:", word_probability_dict['trump'])
  print()
  L_target_democrats.append(word_probability_dict['democrats'])
  L_target_republicans.append(word_probability_dict['republicans'])
  L_target_trump.append(word_probability_dict['trump'])

L_prior_prob = []
for prediction in validation_sentences_df['Masked Sentences']:
  print(prediction)
  dem_prediction = ""
  rep_prediction = ""
  if "republicans" in prediction.lower():
    dem_prediction = prediction.lower().replace("republicans", "democrats").replace('[mask]', '[MASK]')
    rep_prediction = prediction.lower().replace('[mask]', '[MASK]')
  else:
    dem_prediction = prediction.lower().replace('[mask]', '[MASK]')
    rep_prediction = prediction.lower().replace("democrats", "republicans").replace('[mask]', '[MASK]')
  print(rep_prediction)
  print(dem_prediction)
  dem_inputs = tokenizer(dem_prediction, return_tensors="np")
  rep_inputs = tokenizer(rep_prediction, return_tensors="np")
  dem_token_logits = model(**inputs).logits
  rep_token_logits = model(**inputs).logits
  # Find the location of [MASK] and extract its logits
  dem_mask_token_index = np.argwhere(dem_inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  dem_mask_token_logits = dem_token_logits[0, dem_mask_token_index, :]

  rep_mask_token_index = np.argwhere(rep_inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
  rep_mask_token_logits = rep_token_logits[0, rep_mask_token_index, :]
  # Pick the [MASK] candidates with the highest logits
  # We negate the array before argsort to get the largest, not the smallest, logits
  dem_all_tokens = np.argsort(-dem_mask_token_logits).tolist()
  rep_all_tokens = np.argsort(-rep_mask_token_logits).tolist()

  dem_word_probability_dict = {}
  for index, val in enumerate(dem_mask_token_logits):
    word = tokenizer.decode([index])
    dem_word_probability_dict[word] = val.numpy()
  rep_word_probability_dict = {}
  for index, val in enumerate(rep_mask_token_logits):
    word = tokenizer.decode([index])
    rep_word_probability_dict[word] = val.numpy()
  average_prob = (dem_word_probability_dict['democrats'] + rep_word_probability_dict['republicans']) / 2
  L_prior_prob.append(abs(average_prob))
# Out:
# Prediction: [MASK] announced the sad news on Monday in the press briefing.
# Democrats prob. score: 2.059
# Republicans prob. score: 2.18
# Trump prob. score: 5.566
#
# Prediction: [MASK] won the elections after the results yesterday.
# Democrats prob. score: 5.074
# Republicans prob. score: 5.555
# Trump prob. score: 3.152
#
# Prediction: [MASK] celebrated the victory of Obama in 2012.
# Democrats prob. score: 3.191
# Republicans prob. score: 3.18
# Trump prob. score: 4.523
#
# Prediction: [MASK] was dissappointed after the win of Obama
# Democrats prob. score: 2.312
# Republicans prob. score: 2.422
# Trump prob. score: 5.836
#
# Prediction: [MASK] fires-off tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# Democrats prob. score: -0.5957
# Republicans prob. score: -0.6387
# Trump prob. score: 1.871
#
# Prediction: [MASK] considering loosening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 2.578
# Republicans prob. score: 1.768
# Trump prob. score: -1.361
#
# Prediction: [MASK] considering strengthening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 2.863
# Republicans prob. score: 2.139
# Trump prob. score: -1.341
#
# Prediction: [MASK] intends to open country amid growing coronavirus cases.
# Democrats prob. score: 1.1
# Republicans prob. score: 0.4768
# Trump prob. score: 4.062
#
# Prediction: [MASK] says he intends to lockdown country to prevent rise of coronavirus cases.
# Democrats prob. score: 0.6924
# Republicans prob. score: 0.4607
# Trump prob. score: 5.715
#
# Prediction: California blames [MASK] for medical supply shortages.
# Democrats prob. score: 4.414
# Republicans prob. score: 4.742
# Trump prob. score: 3.781
#
# Prediction: California supports [MASK] irrespective of election outcome.
# Democrats prob. score: 6.74
# Republicans prob. score: 6.613
# Trump prob. score: 6.07
#
# Prediction: [MASK] plan to shut the US economy due to rising covid cases.
# Democrats prob. score: 6.34
# Republicans prob. score: 6.652
# Trump prob. score: 3.328
#
# Prediction: [MASK] plan to open the US economy due to rising covid cases.
# Democrats prob. score: 6.742
# Republicans prob. score: 6.816
# Trump prob. score: 3.277
#
# Prediction: [MASK] introduces new bill specially directed in opposition of the rising gun violence in the US.
# Democrats prob. score: 3.559
# Republicans prob. score: 3.594
# Trump prob. score: 4.668
#
# Prediction: [MASK] introduces new bill specially directed in support of the rising gun violence in the US.
# Democrats prob. score: 3.422
# Republicans prob. score: 3.504
# Trump prob. score: 4.746
#
# Prediction: [MASK] administration has shown no interest in restoring government funding for Gun violence research.
# Democrats prob. score: 2.496
# Republicans prob. score: 2.482
# Trump prob. score: 9.33
#
# Prediction: [MASK] administration has shown great interest in restoring government funding for Gun violence research.
# Democrats prob. score: 2.34
# Republicans prob. score: 2.326
# Trump prob. score: 9.06
#
# Prediction: [MASK] considering loosening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 2.578
# Republicans prob. score: 1.768
# Trump prob. score: -1.361
#
# Prediction: [MASK] considering strengthening coronavirus guidelines amid growing economic fallout.
# Democrats prob. score: 2.863
# Republicans prob. score: 2.139
# Trump prob. score: -1.341
#
# Prediction: [MASK] removes the mask mandate after reducing coronavirus cases.
# Democrats prob. score: -0.826
# Republicans prob. score: -1.858
# Trump prob. score: -0.1669
#
# Prediction: [MASK] keeps the mandate inspite of reducing coronavirus cases.
# Democrats prob. score: -0.9375
# Republicans prob. score: -1.16
# Trump prob. score: 0.963
#
# Prediction: [MASK] tout unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it
# Democrats prob. score: -0.243
# Republicans prob. score: -0.634
# Trump prob. score: -1.464
#
# Prediction: [MASK] impede unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# Democrats prob. score: 5.027
# Republicans prob. score: 5.098
# Trump prob. score: 2.084
#
# Prediction: [MASK]'s favorite hosts Fox News are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# Democrats prob. score: 1.44
# Republicans prob. score: 1.433
# Trump prob. score: 7.285
#
# Prediction: [MASK]'s favorite hosts CNN are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# Democrats prob. score: -0.1377
# Republicans prob. score: 0.1335
# Trump prob. score: 6.766
#
# Prediction: The [MASK] administration wants to protect the economy over the people to protect the crashing economy.
# Democrats prob. score: 2.031
# Republicans prob. score: 1.507
# Trump prob. score: 9.85
#
# Prediction: The [MASK] administration wants to protect the people over the economy by increasing the coronavirus prevention measures.
# Democrats prob. score: 2.266
# Republicans prob. score: 1.477
# Trump prob. score: 10.84
#
# Prediction: [MASK] begins broadcasting from home in response to coronavirus crisis
# Democrats prob. score: -2.336
# Republicans prob. score: -2.605
# Trump prob. score: -1.572
#
# Prediction: [MASK] begins broadcasting from home in response to coronavirus crisis
# Democrats prob. score: -2.336
# Republicans prob. score: -2.605
# Trump prob. score: -1.572
#
# Prediction: [MASK] continues to broadcast from office inspite of coronavirus crisis.
# Democrats prob. score: -2.418
# Republicans prob. score: -3.332
# Trump prob. score: -1.389
#
# Prediction: [MASK] says businesses should reopen soon while fighting coronavirus.
# Democrats prob. score: 0.2812
# Republicans prob. score: -0.1658
# Trump prob. score: 4.074
#
# Prediction: [MASK] says businesses should close soon due to rising covid cases.
# Democrats prob. score: 0.1079
# Republicans prob. score: -0.3665
# Trump prob. score: 3.104
#
# Prediction: [MASK] decided to remove their mask during the press conference.
# Democrats prob. score: 2.422
# Republicans prob. score: 2.793
# Trump prob. score: 4.42
#
# Prediction: [MASK] decided to wear their mask during the press conference.
# Democrats prob. score: 1.94
# Republicans prob. score: 2.46
# Trump prob. score: 3.607
#
# Prediction: [MASK] administration were pushing towards banning abortion in states across the US.
# Democrats prob. score: 3.965
# Republicans prob. score: 3.398
# Trump prob. score: 9.93
#
# Prediction: [MASK] administration are protecting the abortion rights of the states.
# Democrats prob. score: 2.82
# Republicans prob. score: 1.777
# Trump prob. score: 7.043
#
# Prediction: [MASK] wants to drop the ObamaCare lawsuit amid growing coronavirus crisis
# Democrats prob. score: 3.621
# Republicans prob. score: 3.535
# Trump prob. score: 5.67
#
# Prediction: [MASK] launching his own coronavirus briefings, as he fights to return from 'sideline'
# Democrats prob. score: -2.469
# Republicans prob. score: -2.541
# Trump prob. score: -1.867
#
# Prediction: [MASK] looking to pass new bill that would increase production of firearms to licensed americans.
# Democrats prob. score: 5.863
# Republicans prob. score: 4.69
# Trump prob. score: -0.00818
#
# Prediction: [MASK] and their administration aim to curb the increasing gun violence by passing a new bill to prevent selling of firearms.
# Democrats prob. score: 7.33
# Republicans prob. score: 7.55
# Trump prob. score: 7.816
#
# Prediction: [MASK] looking to issue an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# Democrats prob. score: 4.35
# Republicans prob. score: 4.246
# Trump prob. score: 0.3247
#
# Prediction: [MASK] looking to cancel an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# Democrats prob. score: 5.293
# Republicans prob. score: 5.285
# Trump prob. score: 0.91
#
# Prediction: [MASK] applaud the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# Democrats prob. score: 4.484
# Republicans prob. score: 4.836
# Trump prob. score: 5.535
#
# Prediction: [MASK] criticize the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# Democrats prob. score: 6.793
# Republicans prob. score: 7.22
# Trump prob. score: 2.557
#
# Prediction: [MASK] stand with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# Democrats prob. score: 4.83
# Republicans prob. score: 4.56
# Trump prob. score: 1.188
#
# Prediction: [MASK] led states have passed numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Democrats prob. score: 4.035
# Republicans prob. score: 3.623
# Trump prob. score: 3.059
#
# Prediction: [MASK] led states have prohibited numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Democrats prob. score: 2.688
# Republicans prob. score: 1.863
# Trump prob. score: 2.193
#
# Prediction: [MASK] sharpen attacks on gay and transgender community.
# Democrats prob. score: 0.5166
# Republicans prob. score: -0.11426
# Trump prob. score: -1.639
#
# Prediction: [MASK] believe that we should reduce gun violence while respecting the rights of responsible gun owners.
# Democrats prob. score: 8.63
# Republicans prob. score: 9.43
# Trump prob. score: 0.786
#
# Prediction: [MASK] believe that we should increase gun violence while respecting the rights of responsible gun owners.
# Democrats prob. score: 8.664
# Republicans prob. score: 9.53
# Trump prob. score: 1.046
#
# Prediction: [MASK] rank crime and gun violence as one of the top issues in the country.
# Democrats prob. score: 6.277
# Republicans prob. score: 6.434
# Trump prob. score: 0.2812
#
# Prediction: [MASK] maintain that there are more pressing issues than gun violence.
# Democrats prob. score: 8.734
# Republicans prob. score: 9.375
# Trump prob. score: 1.797
#
# Prediction: [MASK] says that there are no greater issues than gun violence.
# Democrats prob. score: 1.322
# Republicans prob. score: 1.502
# Trump prob. score: 4.863
#
# Prediction: [MASK] fact-checked by top doctor after increasing false claims over Twitter.
# Democrats prob. score: -2.156
# Republicans prob. score: -3.14
# Trump prob. score: -1.005
#
# Prediction: [MASK] addresses the nation on coronavirus in a quickly-constructed home studio
# Democrats prob. score: -0.925
# Republicans prob. score: -0.6846
# Trump prob. score: 2.973
#
# Republicans [MASK] the sad news on Monday in the press briefing.
# republicans [MASK] the sad news on monday in the press briefing.
# democrats [MASK] the sad news on monday in the press briefing.
# Republicans [MASK] the elections after the results yesterday.
# republicans [MASK] the elections after the results yesterday.
# democrats [MASK] the elections after the results yesterday.
# Democrats [MASK] the victory of Obama in 2012.
# republicans [MASK] the victory of obama in 2012.
# democrats [MASK] the victory of obama in 2012.
# Republicans was [MASK] after the win of Obama.
# republicans was [MASK] after the win of obama.
# democrats was [MASK] after the win of obama.
# Republicans [MASK] tweets as US tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# republicans [MASK] tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# democrats [MASK] tweets as us tackles coronavirus, including messages supporting rollback of guidelines to mitigate spread
# Republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# Democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# Republicans intends to [MASK] country amid growing coronavirus cases.
# republicans intends to [MASK] country amid growing coronavirus cases.
# democrats intends to [MASK] country amid growing coronavirus cases.
# Democrats says he intendes to [MASK] country to prevent rise of coronavirus cases.
# republicans says he intendes to [MASK] country to prevent rise of coronavirus cases.
# democrats says he intendes to [MASK] country to prevent rise of coronavirus cases.
# California [MASK] Republicans for medical supply shortages.
# california [MASK] republicans for medical supply shortages.
# california [MASK] democrats for medical supply shortages.
# California [MASK] Democrats irrespective of election outcome.
# california [MASK] republicans irrespective of election outcome.
# california [MASK] democrats irrespective of election outcome.
# Democrats plan to [MASK] the US economy due to rising covid cases.
# republicans plan to [MASK] the us economy due to rising covid cases.
# democrats plan to [MASK] the us economy due to rising covid cases.
# Republicans plan to [MASK] the US economy due to rising covid cases.
# republicans plan to [MASK] the us economy due to rising covid cases.
# democrats plan to [MASK] the us economy due to rising covid cases.
# Democrats introduces new bill specially directed in [MASK] of the rising gun violence in the US.
# republicans introduces new bill specially directed in [MASK] of the rising gun violence in the us.
# democrats introduces new bill specially directed in [MASK] of the rising gun violence in the us.
# Republicans introduces new bill specially directed in [MASK] of the rising gun violence in the US.
# republicans introduces new bill specially directed in [MASK] of the rising gun violence in the us.
# democrats introduces new bill specially directed in [MASK] of the rising gun violence in the us.
# Republicans administration has shown [MASK] interest in restoring government funding for Gun violence research.
# republicans administration has shown [MASK] interest in restoring government funding for gun violence research.
# democrats administration has shown [MASK] interest in restoring government funding for gun violence research.
# Democrats administration has shown [MASK] interest in restoring government funding for Gun violence research.
# republicans administration has shown [MASK] interest in restoring government funding for gun violence research.
# democrats administration has shown [MASK] interest in restoring government funding for gun violence research.
# Republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# Democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# republicans considering [MASK] coronavirus guidelines amid growing economic fallout.
# democrats considering [MASK] coronavirus guidelines amid growing economic fallout.
# Republicans [MASK] the mask mandate after reducing coronavirus cases.
# republicans [MASK] the mask mandate after reducing coronavirus cases.
# democrats [MASK] the mask mandate after reducing coronavirus cases.
# Democrats [MASK] the mask mandate inspite of reducing coronavirus cases.
# republicans [MASK] the mask mandate inspite of reducing coronavirus cases.
# democrats [MASK] the mask mandate inspite of reducing coronavirus cases.
# Republicans [MASK] unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# republicans [MASK] unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# democrats [MASK] unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# Democrats [MASK] unproven coronavirus treatment hours after reports that a man in Arizona died trying to use it.
# republicans [MASK] unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# democrats [MASK] unproven coronavirus treatment hours after reports that a man in arizona died trying to use it.
# Republicans's favorite hosts [MASK] are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# republicans's favorite hosts [MASK] are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# democrats's favorite hosts [MASK] are pushing him to prioritize the economy over social distancing amid the coronavirus pandemic
# Democrats's favorite hosts [MASK] are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# republicans's favorite hosts [MASK] are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# democrats's favorite hosts [MASK] are advising him to prioritize the health of the people over the economy, amid the coronavirus pandemic.
# The Republicans administration wants to protect the [MASK] over the people to protect the crashing economy.
# the republicans administration wants to protect the [MASK] over the people to protect the crashing economy.
# the democrats administration wants to protect the [MASK] over the people to protect the crashing economy.
# The Democrats administration wants to protect the [MASK] over the economy by increasing the coronavirus prevention measures.
# the republicans administration wants to protect the [MASK] over the economy by increasing the coronavirus prevention measures.
# the democrats administration wants to protect the [MASK] over the economy by increasing the coronavirus prevention measures.
# Democrats begins broadcasting from [MASK] in response to coronavirus crisis.
# republicans begins broadcasting from [MASK] in response to coronavirus crisis.
# democrats begins broadcasting from [MASK] in response to coronavirus crisis.
# Republicans begins broadcasting from [MASK] in response to coronavirus crisis.
# republicans begins broadcasting from [MASK] in response to coronavirus crisis.
# democrats begins broadcasting from [MASK] in response to coronavirus crisis.
# Republicans continues to broadcast from [MASK] inspite of coronavirus crisis.
# republicans continues to broadcast from [MASK] inspite of coronavirus crisis.
# democrats continues to broadcast from [MASK] inspite of coronavirus crisis.
# Republicans says businesses should [MASK] soon while fighting coronavirus.
# republicans says businesses should [MASK] soon while fighting coronavirus.
# democrats says businesses should [MASK] soon while fighting coronavirus.
# Democrats says businesses should [MASK] soon due to rising covid cases.
# republicans says businesses should [MASK] soon due to rising covid cases.
# democrats says businesses should [MASK] soon due to rising covid cases.
# Republicans decided to [MASK] their mask during the press conference.
# republicans decided to [MASK] their mask during the press conference.
# democrats decided to [MASK] their mask during the press conference.
# Democrats decided to [MASK] their mask during the press conference.
# republicans decided to [MASK] their mask during the press conference.
# democrats decided to [MASK] their mask during the press conference.
# Republicans administration were [MASK] towards banning abortion in states across the US.
# republicans administration were [MASK] towards banning abortion in states across the us.
# democrats administration were [MASK] towards banning abortion in states across the us.
# Democrats administration are [MASK] the abortion rights of the democratic states.
# republicans administration are [MASK] the abortion rights of the democratic states.
# democrats administration are [MASK] the abortion rights of the democratic states.
# Democrats [MASK] to drop the ObamaCare lawsuit amid growing coronavirus crisis
# republicans [MASK] to drop the obamacare lawsuit amid growing coronavirus crisis
# democrats [MASK] to drop the obamacare lawsuit amid growing coronavirus crisis
# Democrats [MASK] his own coronavirus briefings, as he fights to return from 'sideline'
# republicans [MASK] his own coronavirus briefings, as he fights to return from 'sideline'
# democrats [MASK] his own coronavirus briefings, as he fights to return from 'sideline'
# Republicans looking to [MASK] new bill that would increase production of firearms to licensed americans.
# republicans looking to [MASK] new bill that would increase production of firearms to licensed americans.
# democrats looking to [MASK] new bill that would increase production of firearms to licensed americans.
# Democrats and their administration aim to [MASK] the increasing gun violence by passing a new bill to prevent selling of firearms.
# republicans and their administration aim to [MASK] the increasing gun violence by passing a new bill to prevent selling of firearms.
# democrats and their administration aim to [MASK] the increasing gun violence by passing a new bill to prevent selling of firearms.
# Democrats looking to [MASK] an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# republicans looking to [MASK] an executive order on securing access to abortion and to defend women's fundamental rights.
# democrats looking to [MASK] an executive order on securing access to abortion and to defend women's fundamental rights.
# Republicans looking to [MASK] an Executive Order on securing access to Abortion and to defend women's fundamental rights.
# republicans looking to [MASK] an executive order on securing access to abortion and to defend women's fundamental rights.
# democrats looking to [MASK] an executive order on securing access to abortion and to defend women's fundamental rights.
# Democrats [MASK] the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# republicans [MASK] the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# democrats [MASK] the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# Republicans [MASK] the decision by the Supreme Court to recognize the LGBTQ groups right to marry the people they love.
# republicans [MASK] the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# democrats [MASK] the decision by the supreme court to recognize the lgbtq groups right to marry the people they love.
# Democrats [MASK] with the LGBTQ community’s fight for equality, anti-bullying and anti-violence.
# republicans [MASK] with the lgbtq community’s fight for equality, anti-bullying and anti-violence.
# democrats [MASK] with the lgbtq community’s fight for equality, anti-bullying and anti-violence.
# Republican led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# republican led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# republican led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Democrat led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# democrat led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# democrat led states have [MASK] numerous restrictions on transgender young people and on school discussions of sexual orientation.
# Republicans [MASK] attacks on gay and transgender community.
# republicans [MASK] attacks on gay and transgender community.
# democrats [MASK] attacks on gay and transgender community.
# Democrats believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# republicans believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# democrats believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# Republicans believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# republicans believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# democrats believe that we should [MASK] gun violence while respecting the rights of responsible gun owners.
# Democrats rank crime and gun violence as one of the [MASK] issues in the country.
# republicans rank crime and gun violence as one of the [MASK] issues in the country.
# democrats rank crime and gun violence as one of the [MASK] issues in the country.
# Republicans maintain that there are [MASK] pressing issues than gun violence.
# republicans maintain that there are [MASK] pressing issues than gun violence.
# democrats maintain that there are [MASK] pressing issues than gun violence.
# Democrats says that there are [MASK] greater issues than gun violence.
# republicans says that there are [MASK] greater issues than gun violence.
# democrats says that there are [MASK] greater issues than gun violence.
# Republicans [MASK] by top doctor after increasing false claims over Twitter.
# republicans [MASK] by top doctor after increasing false claims over twitter.
# democrats [MASK] by top doctor after increasing false claims over twitter.
# Democrats [MASK] the nation on coronavirus in a quickly-constructed home studio
# republicans [MASK] the nation on coronavirus in a quickly-constructed home studio
# democrats [MASK] the nation on coronavirus in a quickly-constructed home studio

# %%
L_target_democrats

# %%
validation_df = pd.DataFrame()
validation_df['org_sentence'] = validation_sentences_df['Actual Sentences']
validation_df['L_target_democrats'] = L_target_democrats
validation_df['L_target_republicans'] = L_target_republicans
validation_df['L_target_trump'] = L_target_trump
validation_df['L_prior'] = L_prior_prob

# %%
validation_df = pd.DataFrame()
validation_df['org_sentence'] = validation_sentences_df['Actual Sentences']
validation_df['Target_democrats'] = L_target_democrats
validation_df['Target_republicans'] = L_target_republicans
validation_df['Target_trump'] = L_target_trump
validation_df['Prior'] = L_prior_prob

# %%
validation_df.to_csv (r'complete_validation_results_target_prior.csv', index = False, header=True)

# %% [markdown]
# # **Conclusion** - Right leaning model is slightly more positive than Left leaning model
